# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import gmaps
import requests
# Import the API key.
from config import g_key
from config import weather_api_key

# %%
# 3. Create a new set of 2,000 random latitudes and longitudes
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
for coordinate in coordinates:
    print(citipy.nearest_city(coordinate[0], coordinate[1]).city_name,
          citipy.nearest_city(coordinate[0], coordinate[1]).country_code)
# Out:
# avarua ck
# berlevag no
# kodiak us
# laguna br
# avarua ck
# san jeronimo mx
# bredasdorp za
# cherepanovo ru
# laguna br
# taolanaro mg
# iqaluit ca
# mayya ru
# severo-kurilsk ru
# linxia cn
# poum nc
# georgetown sh
# berlevag no
# illoqqortoormiut gl
# ushuaia ar
# narsaq gl
# kapaa us
# touros br
# nikolskoye ru
# sao filipe cv
# thompson ca
# ushuaia ar
# thompson ca
# tonj sd
# anadyr ru
# vaitupu wf
# constitucion mx
# waipawa nz
# taolanaro mg
# rikitea pf
# sao jose da coroa grande br
# severnoye ru
# drayton valley ca
# arraial do cabo br
# port elizabeth za
# rikitea pf
# kulynychi ua
# karpogory ru
# tabukiniberu ki
# nanortalik gl
# provideniya ru
# yellowknife ca
# karratha au
# ilulissat gl
# plainview us
# bethel us
# bredasdorp za
# kampala ug
# mahebourg mu
# sentyabrskiy ru
# katsuura jp
# vaitupu wf
# tasiilaq gl
# aktash ru
# jijiga et
# zaykovo ru
# arlit ne
# vaini to
# cape town za
# esperance au
# leona vicario mx
# nizhneyansk ru
# urdoma ru
# pevek ru
# punta arenas cl
# thompson ca
# avarua ck
# georgetown sh
# carnarvon au
# meulaboh id
# rikitea pf
# sanming cn
# mar del plata ar
# nanortalik gl
# saint george bm
# nikolskoye ru
# yulara au
# atuona pf
# punta arenas cl
# busselton au
# bengkulu id
# cape town za
# colac au
# rikitea pf
# cape town za
# kapaa us
# belushya guba ru
# anqing cn
# taolanaro mg
# mandalgovi mn
# gusau ng
# dekoa cf
# albany au
# airai pw
# taolanaro mg
# sao filipe cv
# brae gb
# georgetown sh
# klaksvik fo
# esperance au
# ngukurr au
# kovdor ru
# port alfred za
# fare pf
# yellowknife ca
# mys shmidta ru
# kamenka ru
# copperas cove us
# rajgarh in
# saint-joseph re
# quatre cocos mu
# rikitea pf
# altamira br
# bredasdorp za
# rikitea pf
# bocaiuva br
# qaanaaq gl
# taolanaro mg
# punta arenas cl
# taolanaro mg
# east london za
# shetpe kz
# puerto ayora ec
# khani ru
# aloleng ph
# belushya guba ru
# sunamganj bd
# rikitea pf
# salinopolis br
# tuktoyaktuk ca
# alofi nu
# lufilufi ws
# busselton au
# grand river south east mu
# saskylakh ru
# vaini to
# pevek ru
# yunjinghong cn
# hobart au
# hirara jp
# sao joao da barra br
# puerto ayora ec
# busselton au
# rocha uy
# vaini to
# nikolskoye ru
# bilma ne
# mataura pf
# punta arenas cl
# busselton au
# mataura pf
# saskylakh ru
# brindisi it
# farah af
# albany au
# dutse ng
# liberty us
# iskateley ru
# khatanga ru
# vila velha br
# verkhnevilyuysk ru
# cape town za
# piryion gr
# mar del plata ar
# west plains us
# tasiilaq gl
# hervey bay au
# mayor pablo lagerenza py
# nikolskoye ru
# minudasht ir
# butaritari ki
# las matas de farfan do
# busselton au
# bud no
# karratha au
# bluff nz
# bengkulu id
# talara pe
# kavieng pg
# mataura pf
# hermanus za
# rikitea pf
# potiskum ng
# kodiak us
# taolanaro mg
# hamilton bm
# saint george bm
# bambous virieux mu
# aragarcas br
# mataura pf
# pacific grove us
# tabiauea ki
# taolanaro mg
# gobabis na
# hornepayne ca
# tuktoyaktuk ca
# bluff nz
# albany au
# sioux lookout ca
# pisco pe
# tiksi ru
# isa khel pk
# menongue ao
# mahebourg mu
# touros br
# carnarvon au
# pratapgarh in
# clyde river ca
# clarence town bs
# mar del plata ar
# muroto jp
# thinadhoo mv
# nikolskoye ru
# nizhneyansk ru
# iqaluit ca
# huntsville us
# leningradskiy ru
# rikitea pf
# barrow us
# kruisfontein za
# luderitz na
# nikolskoye ru
# schonenwerd ch
# gravdal no
# east london za
# esperance au
# lompoc us
# albany au
# rio grande br
# bekovo ru
# punta arenas cl
# sitka us
# roros no
# ribeira grande pt
# gokak in
# paamiut gl
# yellowknife ca
# cabo san lucas mx
# new norfolk au
# puerto ayora ec
# mandla in
# kaitangata nz
# athens us
# bahia blanca ar
# mataura pf
# deputatskiy ru
# barrow us
# hailar cn
# kemijarvi fi
# fairbanks us
# shuangyang cn
# rikitea pf
# candolim in
# ponta do sol cv
# tiksi ru
# dezhou cn
# hilo us
# avarua ck
# dikson ru
# port alfred za
# kande tg
# lebu cl
# shimoda jp
# taolanaro mg
# punta arenas cl
# bambous virieux mu
# namibe ao
# albany au
# constitucion mx
# bogande bf
# esperance au
# barrow us
# muzhi ru
# atuona pf
# avarua ck
# guerrero negro mx
# lebu cl
# clarence town bs
# hobart au
# sumbe ao
# busselton au
# tuatapere nz
# fairbanks us
# mar del plata ar
# puerto penasco mx
# vaini to
# albany au
# vardo no
# hithadhoo mv
# hermanus za
# yatou cn
# kloulklubed pw
# cape town za
# butaritari ki
# albany au
# ponta do sol cv
# punta arenas cl
# taolanaro mg
# avarua ck
# beausejour ca
# punta arenas cl
# victoria sc
# busselton au
# lagoa pt
# grand river south east mu
# port alfred za
# laguna br
# codrington ag
# busselton au
# jamestown sh
# hermanus za
# bambous virieux mu
# college us
# ushuaia ar
# kapaa us
# atuona pf
# rikitea pf
# pevek ru
# hofn is
# qaanaaq gl
# ushuaia ar
# bambous virieux mu
# jamestown sh
# ushuaia ar
# bluff nz
# kiunga pg
# mar del plata ar
# hovd mn
# tsihombe mg
# mnogovershinnyy ru
# attawapiskat ca
# tuktoyaktuk ca
# georgetown sh
# cape canaveral us
# georgetown sh
# umm lajj sa
# ribeira grande pt
# dunedin nz
# killybegs ie
# asayita et
# busselton au
# cape town za
# rikitea pf
# mataura pf
# letnica bg
# vila do maio cv
# taolanaro mg
# jamestown sh
# vestmannaeyjar is
# sao felix do xingu br
# samarai pg
# hobart au
# cape town za
# vestmanna fo
# vuktyl ru
# cape town za
# mataura pf
# bluff nz
# punta arenas cl
# san cristobal ec
# sistranda no
# barrow us
# grootfontein na
# bluff nz
# louisbourg ca
# nizwa om
# severo-kurilsk ru
# khonsa in
# qaanaaq gl
# ushuaia ar
# punta arenas cl
# cherskiy ru
# punta arenas cl
# pisco pe
# marawi sd
# oromocto ca
# nabire id
# vardo no
# nizhneyansk ru
# east london za
# barrow us
# atuona pf
# dongfeng cn
# sinegorye ru
# saint-philippe re
# atambua id
# kloulklubed pw
# broken hill au
# don sak th
# mataura pf
# kruisfontein za
# ponta do sol cv
# grand river south east mu
# mareeba au
# punta arenas cl
# faya td
# choya ru
# sigli id
# albany au
# castro cl
# punta arenas cl
# yellowknife ca
# tambovka ru
# hithadhoo mv
# prince rupert ca
# busselton au
# east london za
# mataura pf
# padang id
# hermanus za
# tabas ir
# rikitea pf
# bluff nz
# hithadhoo mv
# mar del plata ar
# nizhniy kuranakh ru
# omboue ga
# hobart au
# rikitea pf
# kapaa us
# hermanus za
# albany au
# hauterive ca
# vostok ru
# synya ru
# zyryanka ru
# wolfenbuttel de
# talcahuano cl
# northam au
# arraial do cabo br
# punta arenas cl
# kigoma tz
# taolanaro mg
# east london za
# albany au
# vao nc
# saldanha za
# nove mesto na morave cz
# kruisfontein za
# ponta do sol cv
# illoqqortoormiut gl
# ushuaia ar
# kahului us
# svetlogorsk ru
# hithadhoo mv
# sobolevo ru
# banning us
# tuktoyaktuk ca
# albany au
# mataura pf
# hermanus za
# bredasdorp za
# provideniya ru
# davila ph
# boguchany ru
# guerrero negro mx
# albany au
# lidkoping se
# ambulu id
# gore et
# saint george bm
# nikolskoye ru
# kurilsk ru
# chokurdakh ru
# tungor ru
# yaan cn
# gurgan az
# taolanaro mg
# vagay ru
# cockburn town tc
# bluff nz
# nguiu au
# port alfred za
# nanortalik gl
# busselton au
# panama city us
# bambanglipuro id
# tetouan ma
# balkhash kz
# nikolskoye ru
# mataura pf
# castro cl
# bandarbeyla so
# tumannyy ru
# busselton au
# rikitea pf
# hilo us
# hermanus za
# leninskoye ru
# amderma ru
# guerrero negro mx
# north bend us
# hithadhoo mv
# birjand ir
# samusu ws
# boende cd
# vestmannaeyjar is
# busselton au
# balarampur in
# vaini to
# jamestown sh
# buala sb
# port alfred za
# rabo de peixe pt
# lolua tv
# victoria sc
# atuona pf
# vaini to
# albany au
# portland au
# bluff nz
# encruzilhada do sul br
# khatanga ru
# kulhudhuffushi mv
# hellin es
# mahibadhoo mv
# illoqqortoormiut gl
# atuona pf
# ust-kuyga ru
# ahuimanu us
# barentsburg sj
# rikitea pf
# avarua ck
# punta arenas cl
# north platte us
# saleaula ws
# itaqui br
# rikitea pf
# matagami ca
# port blair in
# rio gallegos ar
# butaritari ki
# dingle ie
# mataura pf
# cape town za
# pisco pe
# rikitea pf
# ushuaia ar
# san patricio mx
# kapaa us
# saint-philippe re
# punta arenas cl
# penzance gb
# biak id
# jamestown sh
# vaini to
# albany au
# busselton au
# lata sb
# sandovo ru
# shingu jp
# rikitea pf
# mount gambier au
# bilibino ru
# bengkulu id
# rikitea pf
# dingle ie
# alofi nu
# hamilton bm
# kortkeros ru
# abu dhabi ae
# palmer us
# lamu ke
# smithers ca
# ushuaia ar
# albany au
# udachnyy ru
# georgetown sh
# jamestown sh
# mar del plata ar
# cape town za
# lasa cn
# barsovo ru
# hobyo so
# el faiyum eg
# wanning cn
# halvad in
# albany au
# ribeira grande pt
# rikitea pf
# castro cl
# thompson ca
# tasiilaq gl
# georgetown sh
# cabo san lucas mx
# petropavlovsk-kamchatskiy ru
# dunedin nz
# atuona pf
# punta arenas cl
# cockburn town bs
# qaanaaq gl
# samarai pg
# port alfred za
# hithadhoo mv
# rikitea pf
# quatre cocos mu
# taolanaro mg
# hamina fi
# cidreira br
# tawkar sd
# albany au
# dong xoai vn
# batagay ru
# mys shmidta ru
# hermanus za
# sidney us
# nyurba ru
# birjand ir
# kolyvan ru
# buala sb
# hobart au
# kapaa us
# victoria sc
# chuy uy
# mataura pf
# port blair in
# cherskiy ru
# puerto ayora ec
# arlit ne
# pevek ru
# saskylakh ru
# vila velha br
# ushuaia ar
# dombas no
# san carlos uy
# usinsk ru
# xinye cn
# hermanus za
# butaritari ki
# ribeira grande pt
# mataura pf
# stykkisholmur is
# meulaboh id
# shenjiamen cn
# komsomolskiy ru
# jamestown sh
# hobart au
# marsabit ke
# bluff nz
# punta arenas cl
# ushuaia ar
# bluff nz
# ushuaia ar
# tasiilaq gl
# mar del plata ar
# tasiilaq gl
# tsihombe mg
# palabuhanratu id
# bluff nz
# albany au
# itoman jp
# tasiilaq gl
# talnakh ru
# mataura pf
# busselton au
# narsaq gl
# albany au
# roebourne au
# qaanaaq gl
# ushuaia ar
# bredasdorp za
# avarua ck
# puerto escondido mx
# ahipara nz
# busselton au
# zhigansk ru
# castro cl
# tasiilaq gl
# shingu jp
# kapaa us
# kodiak us
# hobart au
# narsaq gl
# ushuaia ar
# quatre cocos mu
# susehri tr
# belushya guba ru
# avarua ck
# ushuaia ar
# hachinohe jp
# aksarayskiy ru
# rikitea pf
# ketchikan us
# goya ar
# aklavik ca
# poum nc
# carnarvon au
# mar del plata ar
# mandalgovi mn
# hithadhoo mv
# okitipupa ng
# miyako jp
# kaitangata nz
# punta arenas cl
# dongsheng cn
# la grande us
# sucre ec
# rikitea pf
# eldikan ru
# punta arenas cl
# statesboro us
# ahipara nz
# satna in
# sechura pe
# kapaa us
# thompson ca
# tumannyy ru
# busselton au
# farrukhabad in
# atuona pf
# kodiak us
# guerrero negro mx
# punta arenas cl
# vaini to
# hithadhoo mv
# sault sainte marie ca
# rikitea pf
# cururupu br
# cidreira br
# rikitea pf
# celestun mx
# mount isa au
# vao nc
# saint anthony ca
# mar del plata ar
# ushuaia ar
# mattru sl
# east london za
# hithadhoo mv
# hobart au
# mataura pf
# antalaha mg
# rikitea pf
# vaitupu wf
# lagoa pt
# kapaa us
# carnarvon au
# busselton au
# dingle ie
# talnakh ru
# ushuaia ar
# hermanus za
# chuy uy
# hobart au
# cabo san lucas mx
# hermanus za
# ushuaia ar
# alghero it
# gemena cd
# puerto ayora ec
# saint-philippe re
# bethel us
# puerto quijarro bo
# ribeira grande pt
# yumen cn
# kavaratti in
# zhanakorgan kz
# albany au
# tumannyy ru
# rikitea pf
# miri my
# khatanga ru
# tiksi ru
# harper lr
# mataura pf
# hithadhoo mv
# san quintin mx
# itaituba br
# lebu cl
# bonwapitse bw
# georgetown sh
# homer us
# illoqqortoormiut gl
# morgan city us
# upernavik gl
# conde br
# ushuaia ar
# kieta pg
# east london za
# mattru sl
# carnarvon au
# ushuaia ar
# atuona pf
# san policarpo ph
# leh in
# paranaiba br
# olafsvik is
# baruun-urt mn
# arraial do cabo br
# hermanus za
# kano ng
# ilulissat gl
# mataura pf
# east london za
# jumla np
# mahebourg mu
# rikitea pf
# bluff nz
# kalmunai lk
# cidreira br
# saldanha za
# aragarcas br
# mataura pf
# bredasdorp za
# puerto ayora ec
# east london za
# fengrun cn
# zhitikara kz
# hilo us
# longyearbyen sj
# karratha au
# rikitea pf
# sentyabrskiy ru
# rikitea pf
# rikitea pf
# hihifo to
# taolanaro mg
# cidreira br
# warqla dz
# ballina au
# victoria sc
# albany au
# tevaitoa pf
# taoudenni ml
# boda cf
# zhanaozen kz
# butaritari ki
# saldanha za
# pleasant point nz
# grand river south east mu
# attawapiskat ca
# iqaluit ca
# chokurdakh ru
# mount isa au
# duvan ru
# tonstad no
# mataura pf
# albany au
# cape town za
# aktash ru
# campbellton ca
# chokurdakh ru
# puerto ayora ec
# paso de los toros uy
# bluff nz
# tessalit ml
# vestmannaeyjar is
# vaini to
# albany au
# yellowknife ca
# nizhneyansk ru
# chokurdakh ru
# vaini to
# rikitea pf
# tasiilaq gl
# constitucion mx
# ostrovnoy ru
# mount gambier au
# selvik no
# avarua ck
# hithadhoo mv
# trojes hn
# mar del plata ar
# mataura pf
# hithadhoo mv
# georgetown sh
# carupano ve
# rikitea pf
# pangnirtung ca
# barentsburg sj
# puerto ayora ec
# porbandar in
# lolua tv
# yellowknife ca
# rikitea pf
# cape town za
# thiadiaye sn
# grand river south east mu
# rikitea pf
# rikitea pf
# tiksi ru
# carnarvon au
# chuy uy
# kodiak us
# sao joao da barra br
# castro cl
# sergeyevka kz
# moctezuma mx
# santa fe ar
# kavieng pg
# ushuaia ar
# mahebourg mu
# ushuaia ar
# ushuaia ar
# bredasdorp za
# oksfjord no
# new norfolk au
# katsuura jp
# castro cl
# lasa cn
# ponta delgada pt
# busselton au
# beloha mg
# port alfred za
# port alfred za
# mahajanga mg
# hobart au
# jamestown sh
# mbandaka cd
# bardiyah ly
# vestmanna fo
# thompson ca
# iguape br
# mataura pf
# skjervoy no
# albany au
# xalpatlahuac mx
# taoudenni ml
# puerto escondido mx
# belushya guba ru
# galle lk
# valeggio sul mincio it
# tiksi ru
# castro cl
# grand river south east mu
# russell nz
# ushuaia ar
# nabisar pk
# rikitea pf
# rikitea pf
# perth au
# pitimbu br
# kapaa us
# castro cl
# mataura pf
# bluff nz
# port alfred za
# albany au
# iqaluit ca
# zhigansk ru
# burica pa
# tsihombe mg
# sirajganj bd
# vaitape pf
# lompoc us
# grindavik is
# ferme-neuve ca
# pousat kh
# natitingou bj
# illoqqortoormiut gl
# vaini to
# king city us
# thompson ca
# rikitea pf
# salalah om
# fortuna us
# kapaa us
# atuona pf
# rikitea pf
# barrow us
# mto wa mbu tz
# tsihombe mg
# mahebourg mu
# albert lea us
# port alfred za
# kapaa us
# thompson ca
# saint-philippe re
# punta arenas cl
# new norfolk au
# hermanus za
# ushuaia ar
# busselton au
# busselton au
# esperance au
# cabra ph
# hobart au
# port alfred za
# ribeira grande pt
# asfi ma
# ibra om
# quatre cocos mu
# cidreira br
# hay river ca
# tasiilaq gl
# mackay au
# pisco pe
# ahipara nz
# cabo san lucas mx
# ancud cl
# qaanaaq gl
# busselton au
# khatanga ru
# mount isa au
# traverse city us
# khatanga ru
# souillac mu
# rikitea pf
# bluff nz
# mataura pf
# saskylakh ru
# kismayo so
# dikson ru
# barrow us
# tasiilaq gl
# asbe teferi et
# castro cl
# tuktoyaktuk ca
# havelock nz
# mar del plata ar
# hithadhoo mv
# ribeira grande pt
# praia cv
# rocha uy
# wajima jp
# mount gambier au
# punta arenas cl
# vaini to
# atuona pf
# busselton au
# kruisfontein za
# rundu na
# champerico gt
# atuona pf
# chokurdakh ru
# ribeira grande pt
# belushya guba ru
# muisne ec
# zlocieniec pl
# kapuskasing ca
# ushuaia ar
# bluff nz
# kharitonovo ru
# rikitea pf
# noumea nc
# chokurdakh ru
# ponta do sol cv
# punta arenas cl
# hobart au
# guerrero negro mx
# laguna br
# mataura pf
# roald no
# madang pg
# jamestown sh
# katsuura jp
# cabo san lucas mx
# kapaa us
# chuy uy
# te anau nz
# rikitea pf
# manokwari id
# kununurra au
# waipawa nz
# atar mr
# atuona pf
# carnarvon au
# taolanaro mg
# taoudenni ml
# avarua ck
# alice springs au
# comodoro rivadavia ar
# den helder nl
# palmas bellas pa
# atar mr
# carnarvon au
# saint-philippe re
# barrow us
# rikitea pf
# port blair in
# qaanaaq gl
# saint-georges gf
# lorengau pg
# husavik is
# hambantota lk
# jamestown sh
# xichang cn
# pindiga ng
# new norfolk au
# north platte us
# hobart au
# cherskiy ru
# husavik is
# sentyabrskiy ru
# aykhal ru
# rikitea pf
# taltal cl
# port elizabeth za
# kapaa us
# maraa br
# taolanaro mg
# laguna br
# tomsani ro
# upernavik gl
# dinsor so
# ushuaia ar
# rikitea pf
# bredasdorp za
# la ronge ca
# hobart au
# thompson ca
# bluff nz
# buenos aires cr
# punta arenas cl
# kaffrine sn
# mataura pf
# kapaa us
# sentyabrskiy ru
# puerto ayora ec
# belaya gora ru
# cockburn town bs
# dawson creek ca
# broome au
# hobart au
# rikitea pf
# butaritari ki
# port alfred za
# hasaki jp
# rikitea pf
# gushi cn
# atuona pf
# albany au
# cape town za
# cayambe ec
# jieshi cn
# mount gambier au
# puerto ayora ec
# ushuaia ar
# carutapera br
# bluff nz
# east london za
# cherskiy ru
# zyryanka ru
# belaya gora ru
# rikitea pf
# lebu cl
# samusu ws
# avarua ck
# saint george bm
# smithers ca
# butaritari ki
# tarakan id
# port elizabeth za
# illoqqortoormiut gl
# hithadhoo mv
# atuona pf
# tampere fi
# butaritari ki
# nikolskoye ru
# san cristobal ec
# phan rang vn
# vaini to
# kapustin yar ru
# norman wells ca
# sungairaya id
# georgetown sh
# santa marta co
# pacific grove us
# hermanus za
# severomuysk ru
# karratha au
# castro cl
# hervey bay au
# busselton au
# kawalu id
# severo-kurilsk ru
# avarua ck
# saskylakh ru
# busselton au
# meulaboh id
# cabo san lucas mx
# sitka us
# montepuez mz
# isabela us
# port alfred za
# talnakh ru
# jumla np
# smidovich ru
# chokurdakh ru
# busselton au
# nikolskoye ru
# ushuaia ar
# rikitea pf
# guhagar in
# illoqqortoormiut gl
# iskateley ru
# hermanus za
# hithadhoo mv
# albany au
# luanda ao
# lipin bor ru
# sampit id
# puerto ayora ec
# ushuaia ar
# hebertville ca
# saint-philippe re
# kodiak us
# khatanga ru
# hilo us
# hilo us
# ushuaia ar
# mar del plata ar
# kapaa us
# oktyabrskiy ru
# busselton au
# venice us
# saskylakh ru
# rikitea pf
# maumere id
# faanui pf
# yellowknife ca
# torbay ca
# bluff nz
# mataura pf
# marcona pe
# korla cn
# souillac mu
# qaqortoq gl
# port moresby pg
# hobart au
# acajutla sv
# cape town za
# belushya guba ru
# thunder bay ca
# torbay ca
# homer us
# kruisfontein za
# werda bw
# kaitangata nz
# cuamba mz
# inirida co
# mys shmidta ru
# hermanus za
# shiyan cn
# ban phai th
# illoqqortoormiut gl
# ushuaia ar
# zaragoza es
# sembabule ug
# vincennes us
# aklavik ca
# puerto ayora ec
# norman wells ca
# albany au
# taolanaro mg
# illoqqortoormiut gl
# atuona pf
# mys shmidta ru
# crib point au
# honnali in
# wajir ke
# chuy uy
# new norfolk au
# dubuque us
# saskylakh ru
# mount gambier au
# sao miguel do tapuio br
# lebu cl
# dikson ru
# puerto ayora ec
# cape town za
# hermanus za
# robertsport lr
# borama so
# atuona pf
# kapaa us
# cheuskiny ru
# madison us
# little current ca
# milkovo ru
# souillac mu
# new norfolk au
# kapaa us
# rikitea pf
# victoria sc
# corrales pe
# cidreira br
# busselton au
# santa eulalia del rio es
# pangody ru
# lebu cl
# new norfolk au
# punta arenas cl
# tartus sy
# rikitea pf
# tuktoyaktuk ca
# ayan ru
# albany au
# salina cruz mx
# verkhnyaya inta ru
# asau tv
# carnarvon au
# tawnat ma
# kigoma tz
# bikapur in
# taolanaro mg
# araouane ml
# concepcion py
# atuona pf
# lagoa pt
# kapaa us
# los llanos de aridane es
# palmer us
# kaduqli sd
# longyearbyen sj
# lebu cl
# carutapera br
# ushuaia ar
# jacareacanga br
# ambilobe mg
# saint-philippe re
# new norfolk au
# ilulissat gl
# saint george bm
# hervey bay au
# lexington us
# jamestown sh
# ushuaia ar
# bubaque gw
# tokonou gn
# castro cl
# port alfred za
# yellowknife ca
# nkoteng cm
# upernavik gl
# east london za
# saskylakh ru
# kapaa us
# puerto ayora ec
# ushuaia ar
# qaanaaq gl
# albany au
# nikolskoye ru
# presidente olegario br
# kaffrine sn
# broome au
# punta arenas cl
# nicoya cr
# oussouye sn
# vaini to
# luderitz na
# alofi nu
# vaini to
# sitka us
# butaritari ki
# iqaluit ca
# chuy uy
# yuzhno-yeniseyskiy ru
# saskylakh ru
# mahebourg mu
# ushuaia ar
# ushuaia ar
# phayuha khiri th
# busselton au
# point pedro lk
# punta arenas cl
# upernavik gl
# tasiilaq gl
# hilo us
# butaritari ki
# vaini to
# qaanaaq gl
# boda cf
# baykit ru
# port alfred za
# east london za
# hilo us
# asmara er
# provideniya ru
# ushuaia ar
# butaritari ki
# klaksvik fo
# ugoofaaru mv
# yeppoon au
# bambous virieux mu
# kalemie cd
# hobart au
# magadi ke
# tuktoyaktuk ca
# cam ranh vn
# barentsburg sj
# mehamn no
# busselton au
# havelock us
# churachandpur in
# port alfred za
# port alfred za
# cubuk tr
# saint-philippe re
# hithadhoo mv
# kodiak us
# ashland us
# saint-philippe re
# port elizabeth za
# mrirt ma
# maningrida au
# oranjemund na
# taolanaro mg
# barrow us
# torbay ca
# illoqqortoormiut gl
# east london za
# lebu cl
# rikitea pf
# barrow us
# kodiak us
# klaksvik fo
# cape town za
# mys shmidta ru
# torbay ca
# kasongo cd
# tuktoyaktuk ca
# albany au
# leningradskiy ru
# shenjiamen cn
# ushuaia ar
# illoqqortoormiut gl
# laguna br
# liverpool ca
# marcona pe
# dikson ru
# hamilton bm
# upernavik gl
# korostyshiv ua
# bengkulu id
# atuona pf
# punta arenas cl
# ushuaia ar
# busselton au
# saint-francois gp
# hualmay pe
# nikel ru
# butaritari ki
# illoqqortoormiut gl
# mys shmidta ru
# busselton au
# cape town za
# punta arenas cl
# jijiga et
# paamiut gl
# nantucket us
# tateyama jp
# kaseda jp
# los llanos de aridane es
# hobart au
# clyde river ca
# mar del plata ar
# mataura pf
# kargasok ru
# novoagansk ru
# atuona pf
# taolanaro mg
# nanortalik gl
# waingapu id
# bredasdorp za
# kapaa us
# waddan ly
# rikitea pf
# amga ru
# bargal so
# riosucio co
# otukpo ng
# gazli uz
# srednekolymsk ru
# albany au
# ushuaia ar
# airai pw
# bhawanigarh in
# cape town za
# kaitangata nz
# vaini to
# makakilo city us
# ponta do sol cv
# sotouboua tg
# zhigansk ru
# qaanaaq gl
# punta arenas cl
# kaitangata nz
# rikitea pf
# taolanaro mg
# airai pw
# punta arenas cl
# nizhneyansk ru
# bluff nz
# thompson ca
# cape town za
# bengkulu id
# alofi nu
# hambantota lk
# rikitea pf
# hobart au
# illoqqortoormiut gl
# tambo pe
# taolanaro mg
# codrington ag
# hobart au
# kapaa us
# hobart au
# puerto ayora ec
# praya id
# westport ie
# jamestown sh
# okahandja na
# gurlan uz
# mataura pf
# san carlos de bariloche ar
# nikolskoye ru
# necochea ar
# rikitea pf
# taoudenni ml
# khanpur pk
# hithadhoo mv
# halalo wf
# huimilpan mx
# grand gaube mu
# samusu ws
# manoel urbano br
# torbay ca
# saleaula ws
# otyniya ua
# petropavlovsk-kamchatskiy ru
# souillac mu
# ponta do sol cv
# punta arenas cl
# koronowo pl
# esperance au
# kapaa us
# pevek ru
# seymchan ru
# albany au
# dolores gt
# ust-ilimsk ru
# seymchan ru
# albany au
# vaini to
# bredasdorp za
# coihaique cl
# kapaa us
# nanortalik gl
# coquimbo cl
# mbaiki cf
# punta arenas cl
# lebu cl
# lebu cl
# kapaa us
# nanortalik gl
# ushuaia ar
# salalah om
# port alfred za
# ojinaga mx
# pevek ru
# mar del plata ar
# vaini to
# tank pk
# rio grande br
# antofagasta cl
# busselton au
# bridgetown bb
# rosarito mx
# albany au
# inderborskiy kz
# cascais pt
# punta arenas cl
# ushuaia ar
# zastron za
# ambodifototra mg
# punta arenas cl
# paiho tw
# rikitea pf
# mataura pf
# butaritari ki
# laguna br
# jinka et
# illoqqortoormiut gl
# albany au
# marti cu
# nikolskoye ru
# qasigiannguit gl
# pangnirtung ca
# norman wells ca
# bethel us
# vila franca do campo pt
# lebu cl
# kapaa us
# vao nc
# grindavik is
# beringovskiy ru
# umm lajj sa
# ushuaia ar
# zlitan ly
# lira ug
# westlock ca
# margate za
# cherskiy ru
# ushuaia ar
# mys shmidta ru
# skerries ie
# kloulklubed pw
# bur gabo so
# tasiilaq gl
# victoria sc
# split hr
# east london za
# port alfred za
# beringovskiy ru
# taolanaro mg
# vaini to
# new norfolk au
# nuqui co
# vila franca do campo pt
# hambantota lk
# iralaya hn
# rikitea pf
# airai pw
# hobart au
# fort myers beach us
# rikitea pf
# bluff nz
# adrar dz
# illoqqortoormiut gl
# calvillo mx
# qaqortoq gl
# kargasok ru
# narsaq gl
# lagoa pt
# hilo us
# sao joao da barra br
# katsuura jp
# mys shmidta ru
# mataura pf
# saint-prosper ca
# mataura pf
# norman wells ca
# provideniya ru
# irbil iq
# hobart au
# atuona pf
# avera pf
# khatanga ru
# hobart au
# lata sb
# mehamn no
# caravelas br
# belushya guba ru
# airai pw
# nikolskoye ru
# punta arenas cl
# lamu ke
# port hardy ca
# cape town za
# qaanaaq gl
# palabuhanratu id
# ushuaia ar
# carnarvon au
# hobart au
# arak ir
# mpika zm
# caceres es
# rikitea pf
# charlestown us
# barentsburg sj
# khatanga ru
# lebu cl
# geraldton ca
# bluff nz
# jamestown sh
# east london za
# bethel us
# barbar sd
# korla cn
# mar del plata ar
# upernavik gl
# mar del plata ar
# upernavik gl
# necochea ar
# flinders au
# upernavik gl
# kavieng pg
# beringovskiy ru
# vysokaya gora ru
# comodoro rivadavia ar
# tignere cm
# mahebourg mu
# mataura pf
# bluff nz
# kathu th
# saint-philippe re
# kamenka ru
# bluff nz
# isangel vu
# lompoc us
# yinchuan cn
# hambantota lk
# rio gallegos ar
# bambous virieux mu
# hermanus za
# carnarvon au
# bredasdorp za
# oskarshamn se
# dzhusaly kz
# castro cl
# poum nc
# albany au
# berlevag no
# vaini to
# carutapera br
# barentsburg sj
# nikolskoye ru
# tetouan ma
# krasnyy kut ru
# marcona pe
# diffa ne
# mahebourg mu
# awash et
# butaritari ki
# carnarvon au
# sorland no
# rikitea pf
# punta arenas cl
# mataura pf
# hermanus za
# busselton au
# cape town za
# busselton au
# coihaique cl
# mocuba mz
# kruisfontein za
# georgetown sh
# labuhan id
# hobart au
# ponta do sol cv
# leningradskiy ru
# talakan ru
# kapaa us
# puerto ayora ec
# biltine td
# bluff nz
# yellowknife ca
# punta arenas cl
# avarua ck
# hermanus za
# mildura au
# butaritari ki
# ushuaia ar
# boa vista br
# nome us
# vaini to
# esperance au
# barrow us
# carnarvon au
# tasiilaq gl
# kapaa us
# upernavik gl
# hobart au
# zafra es
# butaritari ki
# esperance au
# montrose us
# mataura pf
# puerto ayora ec
# atuona pf
# mataura pf
# mataura pf
# banda aceh id
# barrow us
# beaumont fr
# carnarvon au
# sillod in
# jinchang cn
# punta arenas cl
# albany au
# cape town za
# kuruman za
# yumen cn
# yar-sale ru
# new norfolk au
# ville-marie ca
# airai pw
# kodiak us
# saint-philippe re
# tete mz
# mataura pf
# souillac mu
# dhanera in
# rikitea pf
# eyl so
# fairbanks us
# albany au
# port macquarie au
# bluff nz
# albany au
# saint-pierre pm
# rikitea pf
# rikitea pf
# huarmey pe
# punta arenas cl
# mukhen ru
# cape town za
# bluff nz
# grand gaube mu
# mayo ca
# atuona pf
# strezhevoy ru
# nikolskoye ru
# saskylakh ru
# ushuaia ar
# haines junction ca
# cabo san lucas mx
# kodiak us
# biak id
# harnosand se
# carnarvon au
# new norfolk au
# barrow us
# talas tr
# busselton au
# mataura pf
# punta arenas cl
# pochutla mx
# hanzhong cn
# butaritari ki
# quatre cocos mu
# upernavik gl
# koslan ru
# shelburne ca
# ushuaia ar
# rikitea pf
# rikitea pf
# east london za
# buchanan lr
# illoqqortoormiut gl
# puerto ayora ec
# ribeira grande pt
# novo aripuana br
# ushuaia ar
# rikitea pf
# neuquen ar
# cape town za
# rikitea pf
# padang id
# solovetskiy ru
# clyde river ca
# mar del plata ar
# arraial do cabo br
# motala se
# kampot kh
# butaritari ki
# busselton au
# albany au
# mezen ru
# qaanaaq gl
# upernavik gl
# port alfred za
# barrow us
# mataura pf
# vaini to
# yar-sale ru
# rumonge bi
# namibe ao
# nanortalik gl
# punta arenas cl
# taolanaro mg
# carnarvon au
# mataura pf
# albany au
# albany au
# mehamn no
# puri in
# atuona pf
# lasa cn
# kapaa us
# bengkulu id
# tigil ru
# punta arenas cl
# rikitea pf
# rikitea pf
# illoqqortoormiut gl
# ancud cl
# severo-kurilsk ru
# castro cl
# busselton au
# nizhneyansk ru
# vestmannaeyjar is
# saint-augustin ca
# taolanaro mg
# saleaula ws
# mataura pf
# barrow us
# ushuaia ar
# iqaluit ca
# puerto ayora ec
# kavieng pg
# goundam ml
# rikitea pf
# hithadhoo mv
# anadyr ru
# victoria sc
# taolanaro mg
# jamestown sh
# taolanaro mg
# mys shmidta ru
# sinazongwe zm
# gasa bt
# rikitea pf
# hasaki jp
# emet tr
# ushuaia ar
# puerto ayora ec
# busselton au
# cabo san lucas mx
# east london za
# nelson bay au
# agirish ru
# vila franca do campo pt
# sentyabrskiy ru
# camacha pt
# salalah om
# sitka us
# taolanaro mg
# faanui pf
# pasighat in
# vaitupu wf
# barrow us
# rikitea pf
# taolanaro mg
# atuona pf
# kapaa us
# albany au
# nabire id
# longyearbyen sj
# reconquista ar
# kemijarvi fi
# belushya guba ru
# khatanga ru
# kavieng pg
# souillac mu
# mocambique mz
# port hawkesbury ca
# vaini to
# kadykchan ru
# novyy urengoy ru
# ushuaia ar
# busselton au
# albany au
# fortuna us
# hilo us
# gushikawa jp
# hamilton bm
# palmaner in
# san quintin mx
# kununurra au
# srandakan id
# puerto ayora ec
# ushuaia ar
# vaini to
# rio gallegos ar
# olinda br
# chokurdakh ru
# taolanaro mg
# saskylakh ru
# hay river ca
# norman wells ca
# mimongo ga
# atuona pf
# hithadhoo mv
# rikitea pf
# ulaangom mn
# mataura pf
# samarai pg
# butaritari ki
# airai pw
# mataura pf
# mount gambier au
# ostrovnoy ru
# atuona pf
# thompson ca
# mahebourg mu
# marcona pe
# bom jesus br
# rikitea pf
# darab ir
# tiksi ru
# rikitea pf
# severo-kurilsk ru
# palabuhanratu id
# butaritari ki
# zhuanghe cn
# portland au
# mulege mx
# airai pw
# matameye ne
# cherskiy ru
# punta arenas cl
# zhigansk ru
# amderma ru
# calama cl

# %%
# 4. Get the nearest city using the citipy module.

# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 748

# %%
# 5. Perform an API call with the OpenWeatherMap
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=31796aa84bcbb3cbeeb51914e16b61e6

# %%
# 6. Perform an API call with the OpenWeatherMap.

# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Loop through all the cities in our list.
for i in range(len(cities)):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + cities[i]
    # Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_description = city_weather["weather"][0]["description"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        #city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          #"Date": city_date,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 15 | avarua
# Processing Record 2 of Set 15 | berlevag
# Processing Record 3 of Set 15 | kodiak
# Processing Record 4 of Set 15 | laguna
# Processing Record 5 of Set 15 | san jeronimo
# Processing Record 6 of Set 15 | bredasdorp
# Processing Record 7 of Set 15 | cherepanovo
# Processing Record 8 of Set 15 | taolanaro
# City not found. Skipping...
# Processing Record 9 of Set 15 | iqaluit
# Processing Record 10 of Set 15 | mayya
# Processing Record 11 of Set 15 | severo-kurilsk
# Processing Record 12 of Set 15 | linxia
# Processing Record 13 of Set 15 | poum
# Processing Record 14 of Set 15 | georgetown
# Processing Record 15 of Set 15 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 16 of Set 15 | ushuaia
# Processing Record 17 of Set 15 | narsaq
# Processing Record 18 of Set 15 | kapaa
# Processing Record 19 of Set 15 | touros
# Processing Record 20 of Set 15 | nikolskoye
# Processing Record 21 of Set 15 | sao filipe
# Processing Record 22 of Set 15 | thompson
# Processing Record 23 of Set 15 | tonj
# Processing Record 24 of Set 15 | anadyr
# Processing Record 25 of Set 15 | vaitupu
# City not found. Skipping...
# Processing Record 26 of Set 15 | constitucion
# Processing Record 27 of Set 15 | waipawa
# Processing Record 28 of Set 15 | rikitea
# Processing Record 29 of Set 15 | sao jose da coroa grande
# Processing Record 30 of Set 15 | severnoye
# Processing Record 31 of Set 15 | drayton valley
# Processing Record 32 of Set 15 | arraial do cabo
# Processing Record 33 of Set 15 | port elizabeth
# Processing Record 34 of Set 15 | kulynychi
# Processing Record 35 of Set 15 | karpogory
# Processing Record 36 of Set 15 | tabukiniberu
# City not found. Skipping...
# Processing Record 37 of Set 15 | nanortalik
# Processing Record 38 of Set 15 | provideniya
# Processing Record 39 of Set 15 | yellowknife
# Processing Record 40 of Set 15 | karratha
# Processing Record 41 of Set 15 | ilulissat
# Processing Record 42 of Set 15 | plainview
# Processing Record 43 of Set 15 | bethel
# Processing Record 44 of Set 15 | kampala
# Processing Record 45 of Set 15 | mahebourg
# Processing Record 46 of Set 15 | sentyabrskiy
# City not found. Skipping...
# Processing Record 47 of Set 15 | katsuura
# Processing Record 48 of Set 15 | tasiilaq
# Processing Record 49 of Set 15 | aktash
# Processing Record 50 of Set 15 | jijiga
# Processing Record 1 of Set 16 | zaykovo
# Processing Record 2 of Set 16 | arlit
# Processing Record 3 of Set 16 | vaini
# Processing Record 4 of Set 16 | cape town
# Processing Record 5 of Set 16 | esperance
# Processing Record 6 of Set 16 | leona vicario
# Processing Record 7 of Set 16 | nizhneyansk
# City not found. Skipping...
# Processing Record 8 of Set 16 | urdoma
# Processing Record 9 of Set 16 | pevek
# Processing Record 10 of Set 16 | punta arenas
# Processing Record 11 of Set 16 | carnarvon
# Processing Record 12 of Set 16 | meulaboh
# Processing Record 13 of Set 16 | sanming
# Processing Record 14 of Set 16 | mar del plata
# Processing Record 15 of Set 16 | saint george
# Processing Record 16 of Set 16 | yulara
# Processing Record 17 of Set 16 | atuona
# Processing Record 18 of Set 16 | busselton
# Processing Record 19 of Set 16 | bengkulu
# Processing Record 20 of Set 16 | colac
# Processing Record 21 of Set 16 | belushya guba
# City not found. Skipping...
# Processing Record 22 of Set 16 | anqing
# Processing Record 23 of Set 16 | mandalgovi
# Processing Record 24 of Set 16 | gusau
# Processing Record 25 of Set 16 | dekoa
# City not found. Skipping...
# Processing Record 26 of Set 16 | albany
# Processing Record 27 of Set 16 | airai
# Processing Record 28 of Set 16 | brae
# Processing Record 29 of Set 16 | klaksvik
# Processing Record 30 of Set 16 | ngukurr
# City not found. Skipping...
# Processing Record 31 of Set 16 | kovdor
# Processing Record 32 of Set 16 | port alfred
# Processing Record 33 of Set 16 | fare
# Processing Record 34 of Set 16 | mys shmidta
# City not found. Skipping...
# Processing Record 35 of Set 16 | kamenka
# Processing Record 36 of Set 16 | copperas cove
# Processing Record 37 of Set 16 | rajgarh
# Processing Record 38 of Set 16 | saint-joseph
# Processing Record 39 of Set 16 | quatre cocos
# Processing Record 40 of Set 16 | altamira
# Processing Record 41 of Set 16 | bocaiuva
# Processing Record 42 of Set 16 | qaanaaq
# Processing Record 43 of Set 16 | east london
# Processing Record 44 of Set 16 | shetpe
# Processing Record 45 of Set 16 | puerto ayora
# Processing Record 46 of Set 16 | khani
# Processing Record 47 of Set 16 | aloleng
# Processing Record 48 of Set 16 | sunamganj
# City not found. Skipping...
# Processing Record 49 of Set 16 | salinopolis
# Processing Record 50 of Set 16 | tuktoyaktuk
# Processing Record 1 of Set 17 | alofi
# Processing Record 2 of Set 17 | lufilufi
# Processing Record 3 of Set 17 | grand river south east
# City not found. Skipping...
# Processing Record 4 of Set 17 | saskylakh
# Processing Record 5 of Set 17 | yunjinghong
# City not found. Skipping...
# Processing Record 6 of Set 17 | hobart
# Processing Record 7 of Set 17 | hirara
# Processing Record 8 of Set 17 | sao joao da barra
# Processing Record 9 of Set 17 | rocha
# Processing Record 10 of Set 17 | bilma
# Processing Record 11 of Set 17 | mataura
# Processing Record 12 of Set 17 | brindisi
# Processing Record 13 of Set 17 | farah
# Processing Record 14 of Set 17 | dutse
# Processing Record 15 of Set 17 | liberty
# Processing Record 16 of Set 17 | iskateley
# Processing Record 17 of Set 17 | khatanga
# Processing Record 18 of Set 17 | vila velha
# Processing Record 19 of Set 17 | verkhnevilyuysk
# Processing Record 20 of Set 17 | piryion
# City not found. Skipping...
# Processing Record 21 of Set 17 | west plains
# Processing Record 22 of Set 17 | hervey bay
# Processing Record 23 of Set 17 | mayor pablo lagerenza
# Processing Record 24 of Set 17 | minudasht
# Processing Record 25 of Set 17 | butaritari
# Processing Record 26 of Set 17 | las matas de farfan
# Processing Record 27 of Set 17 | bud
# Processing Record 28 of Set 17 | bluff
# Processing Record 29 of Set 17 | talara
# Processing Record 30 of Set 17 | kavieng
# Processing Record 31 of Set 17 | hermanus
# Processing Record 32 of Set 17 | potiskum
# Processing Record 33 of Set 17 | hamilton
# Processing Record 34 of Set 17 | bambous virieux
# Processing Record 35 of Set 17 | aragarcas
# Processing Record 36 of Set 17 | pacific grove
# Processing Record 37 of Set 17 | tabiauea
# City not found. Skipping...
# Processing Record 38 of Set 17 | gobabis
# Processing Record 39 of Set 17 | hornepayne
# Processing Record 40 of Set 17 | sioux lookout
# Processing Record 41 of Set 17 | pisco
# Processing Record 42 of Set 17 | tiksi
# Processing Record 43 of Set 17 | isa khel
# Processing Record 44 of Set 17 | menongue
# Processing Record 45 of Set 17 | pratapgarh
# Processing Record 46 of Set 17 | clyde river
# Processing Record 47 of Set 17 | clarence town
# Processing Record 48 of Set 17 | muroto
# Processing Record 49 of Set 17 | thinadhoo
# Processing Record 50 of Set 17 | huntsville
# Processing Record 1 of Set 18 | leningradskiy
# Processing Record 2 of Set 18 | barrow
# Processing Record 3 of Set 18 | kruisfontein
# Processing Record 4 of Set 18 | luderitz
# Processing Record 5 of Set 18 | schonenwerd
# Processing Record 6 of Set 18 | gravdal
# Processing Record 7 of Set 18 | lompoc
# Processing Record 8 of Set 18 | rio grande
# Processing Record 9 of Set 18 | bekovo
# Processing Record 10 of Set 18 | sitka
# Processing Record 11 of Set 18 | roros
# Processing Record 12 of Set 18 | ribeira grande
# Processing Record 13 of Set 18 | gokak
# Processing Record 14 of Set 18 | paamiut
# Processing Record 15 of Set 18 | cabo san lucas
# Processing Record 16 of Set 18 | new norfolk
# Processing Record 17 of Set 18 | mandla
# Processing Record 18 of Set 18 | kaitangata
# Processing Record 19 of Set 18 | athens
# Processing Record 20 of Set 18 | bahia blanca
# Processing Record 21 of Set 18 | deputatskiy
# Processing Record 22 of Set 18 | hailar
# Processing Record 23 of Set 18 | kemijarvi
# Processing Record 24 of Set 18 | fairbanks
# Processing Record 25 of Set 18 | shuangyang
# Processing Record 26 of Set 18 | candolim
# Processing Record 27 of Set 18 | ponta do sol
# Processing Record 28 of Set 18 | dezhou
# Processing Record 29 of Set 18 | hilo
# Processing Record 30 of Set 18 | dikson
# Processing Record 31 of Set 18 | kande
# Processing Record 32 of Set 18 | lebu
# Processing Record 33 of Set 18 | shimoda
# Processing Record 34 of Set 18 | namibe
# Processing Record 35 of Set 18 | bogande
# Processing Record 36 of Set 18 | muzhi
# Processing Record 37 of Set 18 | guerrero negro
# Processing Record 38 of Set 18 | sumbe
# Processing Record 39 of Set 18 | tuatapere
# Processing Record 40 of Set 18 | puerto penasco
# Processing Record 41 of Set 18 | vardo
# Processing Record 42 of Set 18 | hithadhoo
# Processing Record 43 of Set 18 | yatou
# Processing Record 44 of Set 18 | kloulklubed
# Processing Record 45 of Set 18 | beausejour
# Processing Record 46 of Set 18 | victoria
# Processing Record 47 of Set 18 | lagoa
# Processing Record 48 of Set 18 | codrington
# Processing Record 49 of Set 18 | jamestown
# Processing Record 50 of Set 18 | college
# Processing Record 1 of Set 19 | hofn
# Processing Record 2 of Set 19 | kiunga
# Processing Record 3 of Set 19 | hovd
# Processing Record 4 of Set 19 | tsihombe
# City not found. Skipping...
# Processing Record 5 of Set 19 | mnogovershinnyy
# Processing Record 6 of Set 19 | attawapiskat
# City not found. Skipping...
# Processing Record 7 of Set 19 | cape canaveral
# Processing Record 8 of Set 19 | umm lajj
# Processing Record 9 of Set 19 | dunedin
# Processing Record 10 of Set 19 | killybegs
# Processing Record 11 of Set 19 | asayita
# City not found. Skipping...
# Processing Record 12 of Set 19 | letnica
# Processing Record 13 of Set 19 | vila do maio
# Processing Record 14 of Set 19 | vestmannaeyjar
# Processing Record 15 of Set 19 | sao felix do xingu
# Processing Record 16 of Set 19 | samarai
# Processing Record 17 of Set 19 | vestmanna
# Processing Record 18 of Set 19 | vuktyl
# Processing Record 19 of Set 19 | san cristobal
# Processing Record 20 of Set 19 | sistranda
# Processing Record 21 of Set 19 | grootfontein
# Processing Record 22 of Set 19 | louisbourg
# City not found. Skipping...
# Processing Record 23 of Set 19 | nizwa
# Processing Record 24 of Set 19 | khonsa
# Processing Record 25 of Set 19 | cherskiy
# Processing Record 26 of Set 19 | marawi
# Processing Record 27 of Set 19 | oromocto
# Processing Record 28 of Set 19 | nabire
# Processing Record 29 of Set 19 | dongfeng
# Processing Record 30 of Set 19 | sinegorye
# Processing Record 31 of Set 19 | saint-philippe
# Processing Record 32 of Set 19 | atambua
# Processing Record 33 of Set 19 | broken hill
# Processing Record 34 of Set 19 | don sak
# Processing Record 35 of Set 19 | mareeba
# Processing Record 36 of Set 19 | faya
# Processing Record 37 of Set 19 | choya
# Processing Record 38 of Set 19 | sigli
# Processing Record 39 of Set 19 | castro
# Processing Record 40 of Set 19 | tambovka
# Processing Record 41 of Set 19 | prince rupert
# Processing Record 42 of Set 19 | padang
# Processing Record 43 of Set 19 | tabas
# Processing Record 44 of Set 19 | nizhniy kuranakh
# Processing Record 45 of Set 19 | omboue
# Processing Record 46 of Set 19 | hauterive
# Processing Record 47 of Set 19 | vostok
# Processing Record 48 of Set 19 | synya
# Processing Record 49 of Set 19 | zyryanka
# Processing Record 50 of Set 19 | wolfenbuttel
# Processing Record 1 of Set 20 | talcahuano
# Processing Record 2 of Set 20 | northam
# Processing Record 3 of Set 20 | kigoma
# Processing Record 4 of Set 20 | vao
# Processing Record 5 of Set 20 | saldanha
# Processing Record 6 of Set 20 | nove mesto na morave
# Processing Record 7 of Set 20 | kahului
# Processing Record 8 of Set 20 | svetlogorsk
# Processing Record 9 of Set 20 | sobolevo
# Processing Record 10 of Set 20 | banning
# Processing Record 11 of Set 20 | davila
# Processing Record 12 of Set 20 | boguchany
# Processing Record 13 of Set 20 | lidkoping
# Processing Record 14 of Set 20 | ambulu
# Processing Record 15 of Set 20 | gore
# Processing Record 16 of Set 20 | kurilsk
# Processing Record 17 of Set 20 | chokurdakh
# Processing Record 18 of Set 20 | tungor
# Processing Record 19 of Set 20 | yaan
# Processing Record 20 of Set 20 | gurgan
# City not found. Skipping...
# Processing Record 21 of Set 20 | vagay
# Processing Record 22 of Set 20 | cockburn town
# Processing Record 23 of Set 20 | nguiu
# City not found. Skipping...
# Processing Record 24 of Set 20 | panama city
# Processing Record 25 of Set 20 | bambanglipuro
# Processing Record 26 of Set 20 | tetouan
# Processing Record 27 of Set 20 | balkhash
# Processing Record 28 of Set 20 | bandarbeyla
# Processing Record 29 of Set 20 | tumannyy
# City not found. Skipping...
# Processing Record 30 of Set 20 | leninskoye
# Processing Record 31 of Set 20 | amderma
# City not found. Skipping...
# Processing Record 32 of Set 20 | north bend
# Processing Record 33 of Set 20 | birjand
# Processing Record 34 of Set 20 | samusu
# City not found. Skipping...
# Processing Record 35 of Set 20 | boende
# Processing Record 36 of Set 20 | balarampur
# Processing Record 37 of Set 20 | buala
# Processing Record 38 of Set 20 | rabo de peixe
# Processing Record 39 of Set 20 | lolua
# City not found. Skipping...
# Processing Record 40 of Set 20 | portland
# Processing Record 41 of Set 20 | encruzilhada do sul
# Processing Record 42 of Set 20 | kulhudhuffushi
# Processing Record 43 of Set 20 | hellin
# Processing Record 44 of Set 20 | mahibadhoo
# Processing Record 45 of Set 20 | ust-kuyga
# Processing Record 46 of Set 20 | ahuimanu
# Processing Record 47 of Set 20 | barentsburg
# City not found. Skipping...
# Processing Record 48 of Set 20 | north platte
# Processing Record 49 of Set 20 | saleaula
# City not found. Skipping...
# Processing Record 50 of Set 20 | itaqui
# Processing Record 1 of Set 21 | matagami
# Processing Record 2 of Set 21 | port blair
# Processing Record 3 of Set 21 | rio gallegos
# Processing Record 4 of Set 21 | dingle
# Processing Record 5 of Set 21 | san patricio
# Processing Record 6 of Set 21 | penzance
# Processing Record 7 of Set 21 | biak
# Processing Record 8 of Set 21 | lata
# Processing Record 9 of Set 21 | sandovo
# Processing Record 10 of Set 21 | shingu
# Processing Record 11 of Set 21 | mount gambier
# Processing Record 12 of Set 21 | bilibino
# Processing Record 13 of Set 21 | kortkeros
# Processing Record 14 of Set 21 | abu dhabi
# Processing Record 15 of Set 21 | palmer
# Processing Record 16 of Set 21 | lamu
# Processing Record 17 of Set 21 | smithers
# Processing Record 18 of Set 21 | udachnyy
# Processing Record 19 of Set 21 | lasa
# Processing Record 20 of Set 21 | barsovo
# Processing Record 21 of Set 21 | hobyo
# Processing Record 22 of Set 21 | el faiyum
# City not found. Skipping...
# Processing Record 23 of Set 21 | wanning
# Processing Record 24 of Set 21 | halvad
# Processing Record 25 of Set 21 | petropavlovsk-kamchatskiy
# Processing Record 26 of Set 21 | hamina
# Processing Record 27 of Set 21 | cidreira
# Processing Record 28 of Set 21 | tawkar
# City not found. Skipping...
# Processing Record 29 of Set 21 | dong xoai
# Processing Record 30 of Set 21 | batagay
# Processing Record 31 of Set 21 | sidney
# Processing Record 32 of Set 21 | nyurba
# Processing Record 33 of Set 21 | kolyvan
# Processing Record 34 of Set 21 | chuy
# Processing Record 35 of Set 21 | dombas
# Processing Record 36 of Set 21 | san carlos
# Processing Record 37 of Set 21 | usinsk
# Processing Record 38 of Set 21 | xinye
# Processing Record 39 of Set 21 | stykkisholmur
# Processing Record 40 of Set 21 | shenjiamen
# Processing Record 41 of Set 21 | komsomolskiy
# Processing Record 42 of Set 21 | marsabit
# Processing Record 43 of Set 21 | palabuhanratu
# City not found. Skipping...
# Processing Record 44 of Set 21 | itoman
# Processing Record 45 of Set 21 | talnakh
# Processing Record 46 of Set 21 | roebourne
# Processing Record 47 of Set 21 | puerto escondido
# Processing Record 48 of Set 21 | ahipara
# Processing Record 49 of Set 21 | zhigansk
# Processing Record 50 of Set 21 | susehri
# Processing Record 1 of Set 22 | hachinohe
# Processing Record 2 of Set 22 | aksarayskiy
# Processing Record 3 of Set 22 | ketchikan
# Processing Record 4 of Set 22 | goya
# Processing Record 5 of Set 22 | aklavik
# Processing Record 6 of Set 22 | okitipupa
# Processing Record 7 of Set 22 | miyako
# Processing Record 8 of Set 22 | dongsheng
# Processing Record 9 of Set 22 | la grande
# Processing Record 10 of Set 22 | sucre
# Processing Record 11 of Set 22 | eldikan
# City not found. Skipping...
# Processing Record 12 of Set 22 | statesboro
# Processing Record 13 of Set 22 | satna
# Processing Record 14 of Set 22 | sechura
# Processing Record 15 of Set 22 | farrukhabad
# Processing Record 16 of Set 22 | sault sainte marie
# Processing Record 17 of Set 22 | cururupu
# Processing Record 18 of Set 22 | celestun
# Processing Record 19 of Set 22 | mount isa
# Processing Record 20 of Set 22 | saint anthony
# Processing Record 21 of Set 22 | mattru
# Processing Record 22 of Set 22 | antalaha
# Processing Record 23 of Set 22 | alghero
# Processing Record 24 of Set 22 | gemena
# Processing Record 25 of Set 22 | puerto quijarro
# Processing Record 26 of Set 22 | yumen
# Processing Record 27 of Set 22 | kavaratti
# Processing Record 28 of Set 22 | zhanakorgan
# Processing Record 29 of Set 22 | miri
# Processing Record 30 of Set 22 | harper
# Processing Record 31 of Set 22 | san quintin
# Processing Record 32 of Set 22 | itaituba
# Processing Record 33 of Set 22 | bonwapitse
# Processing Record 34 of Set 22 | homer
# Processing Record 35 of Set 22 | morgan city
# Processing Record 36 of Set 22 | upernavik
# Processing Record 37 of Set 22 | conde
# Processing Record 38 of Set 22 | kieta
# Processing Record 39 of Set 22 | san policarpo
# Processing Record 40 of Set 22 | leh
# Processing Record 41 of Set 22 | paranaiba
# Processing Record 42 of Set 22 | olafsvik
# Processing Record 43 of Set 22 | baruun-urt
# Processing Record 44 of Set 22 | kano
# Processing Record 45 of Set 22 | jumla
# Processing Record 46 of Set 22 | kalmunai
# Processing Record 47 of Set 22 | fengrun
# Processing Record 48 of Set 22 | zhitikara
# City not found. Skipping...
# Processing Record 49 of Set 22 | longyearbyen
# Processing Record 50 of Set 22 | hihifo
# City not found. Skipping...
# Processing Record 1 of Set 23 | warqla
# City not found. Skipping...
# Processing Record 2 of Set 23 | ballina
# Processing Record 3 of Set 23 | tevaitoa
# Processing Record 4 of Set 23 | taoudenni
# Processing Record 5 of Set 23 | boda
# Processing Record 6 of Set 23 | zhanaozen
# Processing Record 7 of Set 23 | pleasant point
# Processing Record 8 of Set 23 | duvan
# Processing Record 9 of Set 23 | tonstad
# Processing Record 10 of Set 23 | campbellton
# Processing Record 11 of Set 23 | paso de los toros
# Processing Record 12 of Set 23 | tessalit
# Processing Record 13 of Set 23 | ostrovnoy
# Processing Record 14 of Set 23 | selvik
# Processing Record 15 of Set 23 | trojes
# Processing Record 16 of Set 23 | carupano
# Processing Record 17 of Set 23 | pangnirtung
# Processing Record 18 of Set 23 | porbandar
# Processing Record 19 of Set 23 | thiadiaye
# Processing Record 20 of Set 23 | sergeyevka
# Processing Record 21 of Set 23 | moctezuma
# Processing Record 22 of Set 23 | santa fe
# Processing Record 23 of Set 23 | oksfjord
# Processing Record 24 of Set 23 | ponta delgada
# Processing Record 25 of Set 23 | beloha
# Processing Record 26 of Set 23 | mahajanga
# Processing Record 27 of Set 23 | mbandaka
# Processing Record 28 of Set 23 | bardiyah
# Processing Record 29 of Set 23 | iguape
# Processing Record 30 of Set 23 | skjervoy
# Processing Record 31 of Set 23 | xalpatlahuac
# Processing Record 32 of Set 23 | galle
# Processing Record 33 of Set 23 | valeggio sul mincio
# Processing Record 34 of Set 23 | russell
# Processing Record 35 of Set 23 | nabisar
# Processing Record 36 of Set 23 | perth
# Processing Record 37 of Set 23 | pitimbu
# Processing Record 38 of Set 23 | burica
# City not found. Skipping...
# Processing Record 39 of Set 23 | sirajganj
# Processing Record 40 of Set 23 | vaitape
# Processing Record 41 of Set 23 | grindavik
# Processing Record 42 of Set 23 | ferme-neuve
# Processing Record 43 of Set 23 | pousat
# City not found. Skipping...
# Processing Record 44 of Set 23 | natitingou
# Processing Record 45 of Set 23 | king city
# Processing Record 46 of Set 23 | salalah
# Processing Record 47 of Set 23 | fortuna
# Processing Record 48 of Set 23 | mto wa mbu
# Processing Record 49 of Set 23 | albert lea
# Processing Record 50 of Set 23 | cabra
# Processing Record 1 of Set 24 | asfi
# Processing Record 2 of Set 24 | ibra
# Processing Record 3 of Set 24 | hay river
# Processing Record 4 of Set 24 | mackay
# Processing Record 5 of Set 24 | ancud
# Processing Record 6 of Set 24 | traverse city
# Processing Record 7 of Set 24 | souillac
# Processing Record 8 of Set 24 | kismayo
# Processing Record 9 of Set 24 | asbe teferi
# Processing Record 10 of Set 24 | havelock
# Processing Record 11 of Set 24 | praia
# Processing Record 12 of Set 24 | wajima
# Processing Record 13 of Set 24 | rundu
# Processing Record 14 of Set 24 | champerico
# Processing Record 15 of Set 24 | muisne
# Processing Record 16 of Set 24 | zlocieniec
# Processing Record 17 of Set 24 | kapuskasing
# Processing Record 18 of Set 24 | kharitonovo
# Processing Record 19 of Set 24 | noumea
# Processing Record 20 of Set 24 | roald
# Processing Record 21 of Set 24 | madang
# Processing Record 22 of Set 24 | te anau
# Processing Record 23 of Set 24 | manokwari
# Processing Record 24 of Set 24 | kununurra
# Processing Record 25 of Set 24 | atar
# Processing Record 26 of Set 24 | alice springs
# Processing Record 27 of Set 24 | comodoro rivadavia
# Processing Record 28 of Set 24 | den helder
# Processing Record 29 of Set 24 | palmas bellas
# Processing Record 30 of Set 24 | saint-georges
# Processing Record 31 of Set 24 | lorengau
# Processing Record 32 of Set 24 | husavik
# Processing Record 33 of Set 24 | hambantota
# Processing Record 34 of Set 24 | xichang
# Processing Record 35 of Set 24 | pindiga
# Processing Record 36 of Set 24 | aykhal
# Processing Record 37 of Set 24 | taltal
# Processing Record 38 of Set 24 | maraa
# Processing Record 39 of Set 24 | tomsani
# Processing Record 40 of Set 24 | dinsor
# City not found. Skipping...
# Processing Record 41 of Set 24 | la ronge
# Processing Record 42 of Set 24 | buenos aires
# Processing Record 43 of Set 24 | kaffrine
# Processing Record 44 of Set 24 | belaya gora
# Processing Record 45 of Set 24 | dawson creek
# Processing Record 46 of Set 24 | broome
# Processing Record 47 of Set 24 | hasaki
# Processing Record 48 of Set 24 | gushi
# Processing Record 49 of Set 24 | cayambe
# Processing Record 50 of Set 24 | jieshi
# Processing Record 1 of Set 25 | carutapera
# Processing Record 2 of Set 25 | tarakan
# Processing Record 3 of Set 25 | tampere
# Processing Record 4 of Set 25 | phan rang
# City not found. Skipping...
# Processing Record 5 of Set 25 | kapustin yar
# Processing Record 6 of Set 25 | norman wells
# Processing Record 7 of Set 25 | sungairaya
# Processing Record 8 of Set 25 | santa marta
# Processing Record 9 of Set 25 | severomuysk
# Processing Record 10 of Set 25 | kawalu
# Processing Record 11 of Set 25 | montepuez
# Processing Record 12 of Set 25 | isabela
# Processing Record 13 of Set 25 | smidovich
# Processing Record 14 of Set 25 | guhagar
# Processing Record 15 of Set 25 | luanda
# Processing Record 16 of Set 25 | lipin bor
# Processing Record 17 of Set 25 | sampit
# Processing Record 18 of Set 25 | hebertville
# City not found. Skipping...
# Processing Record 19 of Set 25 | oktyabrskiy
# Processing Record 20 of Set 25 | venice
# Processing Record 21 of Set 25 | maumere
# Processing Record 22 of Set 25 | faanui
# Processing Record 23 of Set 25 | torbay
# Processing Record 24 of Set 25 | marcona
# City not found. Skipping...
# Processing Record 25 of Set 25 | korla
# Processing Record 26 of Set 25 | qaqortoq
# Processing Record 27 of Set 25 | port moresby
# Processing Record 28 of Set 25 | acajutla
# Processing Record 29 of Set 25 | thunder bay
# Processing Record 30 of Set 25 | werda
# Processing Record 31 of Set 25 | cuamba
# Processing Record 32 of Set 25 | inirida
# Processing Record 33 of Set 25 | shiyan
# Processing Record 34 of Set 25 | ban phai
# Processing Record 35 of Set 25 | zaragoza
# Processing Record 36 of Set 25 | sembabule
# Processing Record 37 of Set 25 | vincennes
# Processing Record 38 of Set 25 | crib point
# Processing Record 39 of Set 25 | honnali
# Processing Record 40 of Set 25 | wajir
# Processing Record 41 of Set 25 | dubuque
# Processing Record 42 of Set 25 | sao miguel do tapuio
# Processing Record 43 of Set 25 | robertsport
# Processing Record 44 of Set 25 | borama
# City not found. Skipping...
# Processing Record 45 of Set 25 | cheuskiny
# City not found. Skipping...
# Processing Record 46 of Set 25 | madison
# Processing Record 47 of Set 25 | little current
# Processing Record 48 of Set 25 | milkovo
# Processing Record 49 of Set 25 | corrales
# Processing Record 50 of Set 25 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 1 of Set 26 | pangody
# Processing Record 2 of Set 26 | tartus
# Processing Record 3 of Set 26 | ayan
# Processing Record 4 of Set 26 | salina cruz
# Processing Record 5 of Set 26 | verkhnyaya inta
# Processing Record 6 of Set 26 | asau
# Processing Record 7 of Set 26 | tawnat
# City not found. Skipping...
# Processing Record 8 of Set 26 | bikapur
# Processing Record 9 of Set 26 | araouane
# Processing Record 10 of Set 26 | concepcion
# Processing Record 11 of Set 26 | los llanos de aridane
# Processing Record 12 of Set 26 | kaduqli
# Processing Record 13 of Set 26 | jacareacanga
# Processing Record 14 of Set 26 | ambilobe
# Processing Record 15 of Set 26 | lexington
# Processing Record 16 of Set 26 | bubaque
# Processing Record 17 of Set 26 | tokonou
# Processing Record 18 of Set 26 | nkoteng
# Processing Record 19 of Set 26 | presidente olegario
# Processing Record 20 of Set 26 | nicoya
# Processing Record 21 of Set 26 | oussouye
# Processing Record 22 of Set 26 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 23 of Set 26 | phayuha khiri
# Processing Record 24 of Set 26 | point pedro
# Processing Record 25 of Set 26 | baykit
# Processing Record 26 of Set 26 | asmara
# Processing Record 27 of Set 26 | ugoofaaru
# Processing Record 28 of Set 26 | yeppoon
# Processing Record 29 of Set 26 | kalemie
# Processing Record 30 of Set 26 | magadi
# Processing Record 31 of Set 26 | cam ranh
# Processing Record 32 of Set 26 | mehamn
# Processing Record 33 of Set 26 | churachandpur
# Processing Record 34 of Set 26 | cubuk
# Processing Record 35 of Set 26 | ashland
# Processing Record 36 of Set 26 | mrirt
# City not found. Skipping...
# Processing Record 37 of Set 26 | maningrida
# Processing Record 38 of Set 26 | oranjemund
# Processing Record 39 of Set 26 | kasongo
# Processing Record 40 of Set 26 | liverpool
# Processing Record 41 of Set 26 | korostyshiv
# Processing Record 42 of Set 26 | saint-francois
# Processing Record 43 of Set 26 | hualmay
# Processing Record 44 of Set 26 | nikel
# Processing Record 45 of Set 26 | nantucket
# Processing Record 46 of Set 26 | tateyama
# Processing Record 47 of Set 26 | kaseda
# Processing Record 48 of Set 26 | kargasok
# Processing Record 49 of Set 26 | novoagansk
# Processing Record 50 of Set 26 | waingapu
# Processing Record 1 of Set 27 | waddan
# Processing Record 2 of Set 27 | amga
# Processing Record 3 of Set 27 | bargal
# City not found. Skipping...
# Processing Record 4 of Set 27 | riosucio
# Processing Record 5 of Set 27 | otukpo
# Processing Record 6 of Set 27 | gazli
# Processing Record 7 of Set 27 | srednekolymsk
# Processing Record 8 of Set 27 | bhawanigarh
# Processing Record 9 of Set 27 | makakilo city
# Processing Record 10 of Set 27 | sotouboua
# Processing Record 11 of Set 27 | tambo
# Processing Record 12 of Set 27 | praya
# Processing Record 13 of Set 27 | westport
# Processing Record 14 of Set 27 | okahandja
# Processing Record 15 of Set 27 | gurlan
# Processing Record 16 of Set 27 | san carlos de bariloche
# Processing Record 17 of Set 27 | necochea
# Processing Record 18 of Set 27 | khanpur
# Processing Record 19 of Set 27 | halalo
# City not found. Skipping...
# Processing Record 20 of Set 27 | huimilpan
# Processing Record 21 of Set 27 | grand gaube
# Processing Record 22 of Set 27 | manoel urbano
# Processing Record 23 of Set 27 | otyniya
# Processing Record 24 of Set 27 | koronowo
# Processing Record 25 of Set 27 | seymchan
# Processing Record 26 of Set 27 | dolores
# Processing Record 27 of Set 27 | ust-ilimsk
# Processing Record 28 of Set 27 | coihaique
# Processing Record 29 of Set 27 | coquimbo
# Processing Record 30 of Set 27 | mbaiki
# Processing Record 31 of Set 27 | ojinaga
# Processing Record 32 of Set 27 | tank
# Processing Record 33 of Set 27 | antofagasta
# Processing Record 34 of Set 27 | bridgetown
# Processing Record 35 of Set 27 | rosarito
# Processing Record 36 of Set 27 | inderborskiy
# City not found. Skipping...
# Processing Record 37 of Set 27 | cascais
# Processing Record 38 of Set 27 | zastron
# Processing Record 39 of Set 27 | ambodifototra
# City not found. Skipping...
# Processing Record 40 of Set 27 | paiho
# City not found. Skipping...
# Processing Record 41 of Set 27 | jinka
# Processing Record 42 of Set 27 | marti
# Processing Record 43 of Set 27 | qasigiannguit
# Processing Record 44 of Set 27 | vila franca do campo
# Processing Record 45 of Set 27 | beringovskiy
# Processing Record 46 of Set 27 | zlitan
# Processing Record 47 of Set 27 | lira
# Processing Record 48 of Set 27 | westlock
# Processing Record 49 of Set 27 | margate
# Processing Record 50 of Set 27 | skerries
# Processing Record 1 of Set 28 | bur gabo
# City not found. Skipping...
# Processing Record 2 of Set 28 | split
# Processing Record 3 of Set 28 | nuqui
# Processing Record 4 of Set 28 | iralaya
# Processing Record 5 of Set 28 | fort myers beach
# Processing Record 6 of Set 28 | adrar
# Processing Record 7 of Set 28 | calvillo
# Processing Record 8 of Set 28 | saint-prosper
# Processing Record 9 of Set 28 | irbil
# Processing Record 10 of Set 28 | avera
# Processing Record 11 of Set 28 | caravelas
# Processing Record 12 of Set 28 | port hardy
# Processing Record 13 of Set 28 | arak
# Processing Record 14 of Set 28 | mpika
# Processing Record 15 of Set 28 | caceres
# Processing Record 16 of Set 28 | charlestown
# Processing Record 17 of Set 28 | geraldton
# Processing Record 18 of Set 28 | barbar
# City not found. Skipping...
# Processing Record 19 of Set 28 | flinders
# Processing Record 20 of Set 28 | vysokaya gora
# Processing Record 21 of Set 28 | tignere
# Processing Record 22 of Set 28 | kathu
# Processing Record 23 of Set 28 | isangel
# Processing Record 24 of Set 28 | yinchuan
# Processing Record 25 of Set 28 | oskarshamn
# Processing Record 26 of Set 28 | dzhusaly
# City not found. Skipping...
# Processing Record 27 of Set 28 | krasnyy kut
# Processing Record 28 of Set 28 | diffa
# Processing Record 29 of Set 28 | awash
# Processing Record 30 of Set 28 | sorland
# Processing Record 31 of Set 28 | mocuba
# Processing Record 32 of Set 28 | labuhan
# Processing Record 33 of Set 28 | talakan
# Processing Record 34 of Set 28 | biltine
# Processing Record 35 of Set 28 | mildura
# Processing Record 36 of Set 28 | boa vista
# Processing Record 37 of Set 28 | nome
# Processing Record 38 of Set 28 | zafra
# Processing Record 39 of Set 28 | montrose
# Processing Record 40 of Set 28 | banda aceh
# Processing Record 41 of Set 28 | beaumont
# Processing Record 42 of Set 28 | sillod
# Processing Record 43 of Set 28 | jinchang
# Processing Record 44 of Set 28 | kuruman
# Processing Record 45 of Set 28 | yar-sale
# Processing Record 46 of Set 28 | ville-marie
# Processing Record 47 of Set 28 | tete
# Processing Record 48 of Set 28 | dhanera
# Processing Record 49 of Set 28 | eyl
# Processing Record 50 of Set 28 | port macquarie
# Processing Record 1 of Set 29 | saint-pierre
# Processing Record 2 of Set 29 | huarmey
# Processing Record 3 of Set 29 | mukhen
# Processing Record 4 of Set 29 | mayo
# Processing Record 5 of Set 29 | strezhevoy
# Processing Record 6 of Set 29 | haines junction
# Processing Record 7 of Set 29 | harnosand
# Processing Record 8 of Set 29 | talas
# Processing Record 9 of Set 29 | pochutla
# Processing Record 10 of Set 29 | hanzhong
# Processing Record 11 of Set 29 | koslan
# Processing Record 12 of Set 29 | shelburne
# Processing Record 13 of Set 29 | buchanan
# Processing Record 14 of Set 29 | novo aripuana
# Processing Record 15 of Set 29 | neuquen
# Processing Record 16 of Set 29 | solovetskiy
# City not found. Skipping...
# Processing Record 17 of Set 29 | motala
# Processing Record 18 of Set 29 | kampot
# Processing Record 19 of Set 29 | mezen
# Processing Record 20 of Set 29 | rumonge
# Processing Record 21 of Set 29 | puri
# Processing Record 22 of Set 29 | tigil
# Processing Record 23 of Set 29 | saint-augustin
# Processing Record 24 of Set 29 | goundam
# Processing Record 25 of Set 29 | sinazongwe
# Processing Record 26 of Set 29 | gasa
# Processing Record 27 of Set 29 | emet
# Processing Record 28 of Set 29 | nelson bay
# Processing Record 29 of Set 29 | agirish
# Processing Record 30 of Set 29 | camacha
# Processing Record 31 of Set 29 | pasighat
# Processing Record 32 of Set 29 | reconquista
# Processing Record 33 of Set 29 | mocambique
# City not found. Skipping...
# Processing Record 34 of Set 29 | port hawkesbury
# Processing Record 35 of Set 29 | kadykchan
# City not found. Skipping...
# Processing Record 36 of Set 29 | novyy urengoy
# Processing Record 37 of Set 29 | gushikawa
# Processing Record 38 of Set 29 | palmaner
# Processing Record 39 of Set 29 | srandakan
# Processing Record 40 of Set 29 | olinda
# Processing Record 41 of Set 29 | mimongo
# Processing Record 42 of Set 29 | ulaangom
# Processing Record 43 of Set 29 | bom jesus
# Processing Record 44 of Set 29 | darab
# Processing Record 45 of Set 29 | zhuanghe
# Processing Record 46 of Set 29 | mulege
# Processing Record 47 of Set 29 | matameye
# City not found. Skipping...
# Processing Record 48 of Set 29 | calama
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data
# Out:
# [{'City': 'Avarua',
#   'Country': 'CK',
#   'Lat': -21.2078,
#   'Lng': -159.775,
#   'Max Temp': 77.05,
#   'Humidity': 94,
#   'Cloudiness': 97,
#   'Wind Speed': 2.3,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Berlevag',
#   'Country': 'NO',
#   'Lat': 70.8578,
#   'Lng': 29.0864,
#   'Max Temp': 37.4,
#   'Humidity': 87,
#   'Cloudiness': 44,
#   'Wind Speed': 16.46,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Kodiak',
#   'Country': 'US',
#   'Lat': 57.79,
#   'Lng': -152.4072,
#   'Max Temp': 33.31,
#   'Humidity': 47,
#   'Cloudiness': 0,
#   'Wind Speed': 8.05,
#   'Current Description': 'clear sky'},
#  {'City': 'Laguna',
#   'Country': 'US',
#   'Lat': 38.421,
#   'Lng': -121.4238,
#   'Max Temp': 64.15,
#   'Humidity': 26,
#   'Cloudiness': 0,
#   'Wind Speed': 16.11,
#   'Current Description': 'clear sky'},
#  {'City': 'San Jeronimo',
#   'Country': 'PE',
#   'Lat': -11.9472,
#   'Lng': -75.2829,
#   'Max Temp': 56.88,
#   'Humidity': 63,
#   'Cloudiness': 99,
#   'Wind Speed': 0.38,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Bredasdorp',
#   'Country': 'ZA',
#   'Lat': -34.5322,
#   'Lng': 20.0403,
#   'Max Temp': 64.94,
#   'Humidity': 86,
#   'Cloudiness': 0,
#   'Wind Speed': 14.61,
#   'Current Description': 'clear sky'},
#  {'City': 'Cherepanovo',
#   'Country': 'RU',
#   'Lat': 54.2222,
#   'Lng': 83.381,
#   'Max Temp': 17.06,
#   'Humidity': 96,
#   'Cloudiness': 51,
#   'Wind Speed': 4.83,
#   'Current Description': 'broken clouds'},
#  {'City': 'Iqaluit',
#   'Country': 'CA',
#   'Lat': 63.7506,
#   'Lng': -68.5145,
#   'Max Temp': 26.33,
#   'Humidity': 79,
#   'Cloudiness': 100,
#   'Wind Speed': 2.3,
#   'Current Description': 'light snow'},
#  {'City': 'Mayya',
#   'Country': 'RU',
#   'Lat': 61.7333,
#   'Lng': 130.2811,
#   'Max Temp': 20.52,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 4.68,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Severo-Kurilsk',
#   'Country': 'RU',
#   'Lat': 50.6789,
#   'Lng': 156.125,
#   'Max Temp': 29.7,
#   'Humidity': 78,
#   'Cloudiness': 98,
#   'Wind Speed': 17.76,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Linxia',
#   'Country': 'CN',
#   'Lat': 35.6003,
#   'Lng': 103.2064,
#   'Max Temp': 58.01,
#   'Humidity': 19,
#   'Cloudiness': 100,
#   'Wind Speed': 10.83,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Poum',
#   'Country': 'NC',
#   'Lat': -20.2333,
#   'Lng': 164.0167,
#   'Max Temp': 79.34,
#   'Humidity': 75,
#   'Cloudiness': 56,
#   'Wind Speed': 13.38,
#   'Current Description': 'broken clouds'},
#  {'City': 'Georgetown',
#   'Country': 'MY',
#   'Lat': 5.4112,
#   'Lng': 100.3354,
#   'Max Temp': 83.95,
#   'Humidity': 88,
#   'Cloudiness': 20,
#   'Wind Speed': 0,
#   'Current Description': 'few clouds'},
#  {'City': 'Ushuaia',
#   'Country': 'AR',
#   'Lat': -54.8,
#   'Lng': -68.3,
#   'Max Temp': 44.26,
#   'Humidity': 57,
#   'Cloudiness': 75,
#   'Wind Speed': 6.91,
#   'Current Description': 'broken clouds'},
#  {'City': 'Narsaq',
#   'Country': 'GL',
#   'Lat': 60.9167,
#   'Lng': -46.05,
#   'Max Temp': 34.3,
#   'Humidity': 41,
#   'Cloudiness': 100,
#   'Wind Speed': 2.53,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Kapaa',
#   'Country': 'US',
#   'Lat': 22.0752,
#   'Lng': -159.319,
#   'Max Temp': 73.47,
#   'Humidity': 91,
#   'Cloudiness': 75,
#   'Wind Speed': 17.27,
#   'Current Description': 'broken clouds'},
#  {'City': 'Touros',
#   'Country': 'BR',
#   'Lat': -5.1989,
#   'Lng': -35.4608,
#   'Max Temp': 86.88,
#   'Humidity': 58,
#   'Cloudiness': 57,
#   'Wind Speed': 14.85,
#   'Current Description': 'broken clouds'},
#  {'City': 'Nikolskoye',
#   'Country': 'RU',
#   'Lat': 59.7035,
#   'Lng': 30.7861,
#   'Max Temp': 42.69,
#   'Humidity': 82,
#   'Cloudiness': 62,
#   'Wind Speed': 9.55,
#   'Current Description': 'broken clouds'},
#  {'City': 'Sao Filipe',
#   'Country': 'CV',
#   'Lat': 14.8961,
#   'Lng': -24.4956,
#   'Max Temp': 73.83,
#   'Humidity': 75,
#   'Cloudiness': 11,
#   'Wind Speed': 15.61,
#   'Current Description': 'few clouds'},
#  {'City': 'Thompson',
#   'Country': 'CA',
#   'Lat': 55.7435,
#   'Lng': -97.8558,
#   'Max Temp': 33.96,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 8.05,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Tonj',
#   'Country': 'SS',
#   'Lat': 7.2737,
#   'Lng': 28.6822,
#   'Max Temp': 91.67,
#   'Humidity': 32,
#   'Cloudiness': 84,
#   'Wind Speed': 2.73,
#   'Current Description': 'light rain'},
#  {'City': 'Anadyr',
#   'Country': 'RU',
#   'Lat': 64.75,
#   'Lng': 177.4833,
#   'Max Temp': 19.9,
#   'Humidity': 92,
#   'Cloudiness': 20,
#   'Wind Speed': 6.71,
#   'Current Description': 'few clouds'},
#  {'City': 'Constitucion',
#   'Country': 'CL',
#   'Lat': -35.3333,
#   'Lng': -72.4167,
#   'Max Temp': 57.94,
#   'Humidity': 66,
#   'Cloudiness': 17,
#   'Wind Speed': 8.75,
#   'Current Description': 'few clouds'},
#  {'City': 'Waipawa',
#   'Country': 'NZ',
#   'Lat': -41.4122,
#   'Lng': 175.5153,
#   'Max Temp': 47.97,
#   'Humidity': 92,
#   'Cloudiness': 8,
#   'Wind Speed': 6.08,
#   'Current Description': 'clear sky'},
#  {'City': 'Rikitea',
#   'Country': 'PF',
#   'Lat': -23.1203,
#   'Lng': -134.9692,
#   'Max Temp': 78.93,
#   'Humidity': 73,
#   'Cloudiness': 4,
#   'Wind Speed': 17.13,
#   'Current Description': 'light rain'},
#  {'City': 'Sao Jose Da Coroa Grande',
#   'Country': 'BR',
#   'Lat': -8.8978,
#   'Lng': -35.1478,
#   'Max Temp': 83.48,
#   'Humidity': 66,
#   'Cloudiness': 54,
#   'Wind Speed': 10.13,
#   'Current Description': 'broken clouds'},
#  {'City': 'Severnoye',
#   'Country': 'RU',
#   'Lat': 56.3491,
#   'Lng': 78.3619,
#   'Max Temp': 20.71,
#   'Humidity': 90,
#   'Cloudiness': 11,
#   'Wind Speed': 2.15,
#   'Current Description': 'few clouds'},
#  {'City': 'Drayton Valley',
#   'Country': 'CA',
#   'Lat': 53.2168,
#   'Lng': -114.9854,
#   'Max Temp': 29.66,
#   'Humidity': 43,
#   'Cloudiness': 96,
#   'Wind Speed': 20.45,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Arraial Do Cabo',
#   'Country': 'BR',
#   'Lat': -22.9661,
#   'Lng': -42.0278,
#   'Max Temp': 84.06,
#   'Humidity': 70,
#   'Cloudiness': 40,
#   'Wind Speed': 12.66,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Port Elizabeth',
#   'Country': 'ZA',
#   'Lat': -33.918,
#   'Lng': 25.5701,
#   'Max Temp': 67.1,
#   'Humidity': 92,
#   'Cloudiness': 75,
#   'Wind Speed': 10.36,
#   'Current Description': 'broken clouds'},
#  {'City': 'Kulynychi',
#   'Country': 'UA',
#   'Lat': 49.9823,
#   'Lng': 36.3842,
#   'Max Temp': 56.28,
#   'Humidity': 66,
#   'Cloudiness': 100,
#   'Wind Speed': 4.43,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Karpogory',
#   'Country': 'RU',
#   'Lat': 64.0019,
#   'Lng': 44.4451,
#   'Max Temp': 38.23,
#   'Humidity': 99,
#   'Cloudiness': 100,
#   'Wind Speed': 10.07,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Nanortalik',
#   'Country': 'GL',
#   'Lat': 60.1432,
#   'Lng': -45.2371,
#   'Max Temp': 32.94,
#   'Humidity': 72,
#   'Cloudiness': 100,
#   'Wind Speed': 2.95,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Provideniya',
#   'Country': 'RU',
#   'Lat': 64.3833,
#   'Lng': -173.3,
#   'Max Temp': 22.08,
#   'Humidity': 99,
#   'Cloudiness': 98,
#   'Wind Speed': 6.11,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Yellowknife',
#   'Country': 'CA',
#   'Lat': 62.456,
#   'Lng': -114.3525,
#   'Max Temp': 12.42,
#   'Humidity': 78,
#   'Cloudiness': 40,
#   'Wind Speed': 19.57,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Karratha',
#   'Country': 'AU',
#   'Lat': -20.7377,
#   'Lng': 116.8463,
#   'Max Temp': 82.9,
#   'Humidity': 34,
#   'Cloudiness': 7,
#   'Wind Speed': 11.21,
#   'Current Description': 'clear sky'},
#  {'City': 'Ilulissat',
#   'Country': 'GL',
#   'Lat': 69.2167,
#   'Lng': -51.1,
#   'Max Temp': 19.78,
#   'Humidity': 65,
#   'Cloudiness': 100,
#   'Wind Speed': 1.48,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Plainview',
#   'Country': 'US',
#   'Lat': 40.7765,
#   'Lng': -73.4673,
#   'Max Temp': 49.75,
#   'Humidity': 47,
#   'Cloudiness': 40,
#   'Wind Speed': 17.27,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Bethel',
#   'Country': 'US',
#   'Lat': 41.3712,
#   'Lng': -73.414,
#   'Max Temp': 47.48,
#   'Humidity': 59,
#   'Cloudiness': 100,
#   'Wind Speed': 13.8,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Kampala',
#   'Country': 'UG',
#   'Lat': 0.3163,
#   'Lng': 32.5822,
#   'Max Temp': 78.19,
#   'Humidity': 79,
#   'Cloudiness': 79,
#   'Wind Speed': 0.34,
#   'Current Description': 'light rain'},
#  {'City': 'Mahebourg',
#   'Country': 'MU',
#   'Lat': -20.4081,
#   'Lng': 57.7,
#   'Max Temp': 77.29,
#   'Humidity': 88,
#   'Cloudiness': 75,
#   'Wind Speed': 8.05,
#   'Current Description': 'broken clouds'},
#  {'City': 'Katsuura',
#   'Country': 'JP',
#   'Lat': 35.1333,
#   'Lng': 140.3,
#   'Max Temp': 60.94,
#   'Humidity': 91,
#   'Cloudiness': 44,
#   'Wind Speed': 10.07,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Tasiilaq',
#   'Country': 'GL',
#   'Lat': 65.6145,
#   'Lng': -37.6368,
#   'Max Temp': 20.8,
#   'Humidity': 70,
#   'Cloudiness': 43,
#   'Wind Speed': 1.12,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Aktash',
#   'Country': 'RU',
#   'Lat': 50.3,
#   'Lng': 87.7333,
#   'Max Temp': 13.33,
#   'Humidity': 86,
#   'Cloudiness': 23,
#   'Wind Speed': 1.74,
#   'Current Description': 'few clouds'},
#  {'City': 'Jijiga',
#   'Country': 'ET',
#   'Lat': 9.35,
#   'Lng': 42.8,
#   'Max Temp': 72.86,
#   'Humidity': 51,
#   'Cloudiness': 83,
#   'Wind Speed': 10.09,
#   'Current Description': 'broken clouds'},
#  {'City': 'Zaykovo',
#   'Country': 'RU',
#   'Lat': 57.5613,
#   'Lng': 62.7568,
#   'Max Temp': 34.79,
#   'Humidity': 96,
#   'Cloudiness': 92,
#   'Wind Speed': 7.23,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Arlit',
#   'Country': 'NE',
#   'Lat': 18.7369,
#   'Lng': 7.3853,
#   'Max Temp': 103.03,
#   'Humidity': 4,
#   'Cloudiness': 1,
#   'Wind Speed': 6.11,
#   'Current Description': 'clear sky'},
#  {'City': 'Vaini',
#   'Country': 'TO',
#   'Lat': -21.2,
#   'Lng': -175.2,
#   'Max Temp': 77.16,
#   'Humidity': 88,
#   'Cloudiness': 20,
#   'Wind Speed': 8.05,
#   'Current Description': 'few clouds'},
#  {'City': 'Cape Town',
#   'Country': 'ZA',
#   'Lat': -33.9258,
#   'Lng': 18.4232,
#   'Max Temp': 70.92,
#   'Humidity': 64,
#   'Cloudiness': 0,
#   'Wind Speed': 12.66,
#   'Current Description': 'clear sky'},
#  {'City': 'Esperance',
#   'Country': 'AU',
#   'Lat': -33.8667,
#   'Lng': 121.9,
#   'Max Temp': 60.64,
#   'Humidity': 90,
#   'Cloudiness': 6,
#   'Wind Speed': 13.09,
#   'Current Description': 'clear sky'},
#  {'City': 'Leona Vicario',
#   'Country': 'MX',
#   'Lat': 20.9667,
#   'Lng': -87.1917,
#   'Max Temp': 76.98,
#   'Humidity': 39,
#   'Cloudiness': 25,
#   'Wind Speed': 7.14,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Urdoma',
#   'Country': 'RU',
#   'Lat': 61.7533,
#   'Lng': 48.5442,
#   'Max Temp': 39.07,
#   'Humidity': 98,
#   'Cloudiness': 100,
#   'Wind Speed': 10.51,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Pevek',
#   'Country': 'RU',
#   'Lat': 69.7008,
#   'Lng': 170.3133,
#   'Max Temp': -22.43,
#   'Humidity': 100,
#   'Cloudiness': 86,
#   'Wind Speed': 3.02,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Punta Arenas',
#   'Country': 'CL',
#   'Lat': -53.15,
#   'Lng': -70.9167,
#   'Max Temp': 48.31,
#   'Humidity': 61,
#   'Cloudiness': 0,
#   'Wind Speed': 4.61,
#   'Current Description': 'clear sky'},
#  {'City': 'Carnarvon',
#   'Country': 'AU',
#   'Lat': -24.8667,
#   'Lng': 113.6333,
#   'Max Temp': 69.87,
#   'Humidity': 68,
#   'Cloudiness': 0,
#   'Wind Speed': 13.8,
#   'Current Description': 'clear sky'},
#  {'City': 'Meulaboh',
#   'Country': 'ID',
#   'Lat': 4.1363,
#   'Lng': 96.1285,
#   'Max Temp': 78.3,
#   'Humidity': 86,
#   'Cloudiness': 91,
#   'Wind Speed': 0.38,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Sanming',
#   'Country': 'CN',
#   'Lat': 26.2486,
#   'Lng': 117.6186,
#   'Max Temp': 67.06,
#   'Humidity': 63,
#   'Cloudiness': 19,
#   'Wind Speed': 1.97,
#   'Current Description': 'few clouds'},
#  {'City': 'Mar Del Plata',
#   'Country': 'AR',
#   'Lat': -38.0023,
#   'Lng': -57.5575,
#   'Max Temp': 69.82,
#   'Humidity': 96,
#   'Cloudiness': 40,
#   'Wind Speed': 14,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Saint George',
#   'Country': 'US',
#   'Lat': 37.1041,
#   'Lng': -113.5841,
#   'Max Temp': 61.63,
#   'Humidity': 13,
#   'Cloudiness': 0,
#   'Wind Speed': 5.75,
#   'Current Description': 'clear sky'},
#  {'City': 'Yulara',
#   'Country': 'AU',
#   'Lat': -25.2406,
#   'Lng': 130.9889,
#   'Max Temp': 60.64,
#   'Humidity': 31,
#   'Cloudiness': 0,
#   'Wind Speed': 0,
#   'Current Description': 'clear sky'},
#  {'City': 'Atuona',
#   'Country': 'PF',
#   'Lat': -9.8,
#   'Lng': -139.0333,
#   'Max Temp': 78.78,
#   'Humidity': 77,
#   'Cloudiness': 16,
#   'Wind Speed': 17.98,
#   'Current Description': 'few clouds'},
#  {'City': 'Busselton',
#   'Country': 'AU',
#   'Lat': -33.65,
#   'Lng': 115.3333,
#   'Max Temp': 54.32,
#   'Humidity': 79,
#   'Cloudiness': 76,
#   'Wind Speed': 5.48,
#   'Current Description': 'light rain'},
#  {'City': 'Bengkulu',
#   'Country': 'ID',
#   'Lat': -3.8004,
#   'Lng': 102.2655,
#   'Max Temp': 76.26,
#   'Humidity': 87,
#   'Cloudiness': 91,
#   'Wind Speed': 2.46,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Colac',
#   'Country': 'AU',
#   'Lat': -38.3333,
#   'Lng': 143.5833,
#   'Max Temp': 57.16,
#   'Humidity': 82,
#   'Cloudiness': 100,
#   'Wind Speed': 7.81,
#   'Current Description': 'light rain'},
#  {'City': 'Anqing',
#   'Country': 'CN',
#   'Lat': 30.5092,
#   'Lng': 117.0506,
#   'Max Temp': 69.28,
#   'Humidity': 58,
#   'Cloudiness': 0,
#   'Wind Speed': 2.42,
#   'Current Description': 'clear sky'},
#  {'City': 'Mandalgovi',
#   'Country': 'MN',
#   'Lat': 45.7625,
#   'Lng': 106.2708,
#   'Max Temp': 26.15,
#   'Humidity': 89,
#   'Cloudiness': 61,
#   'Wind Speed': 32.48,
#   'Current Description': 'snow'},
#  {'City': 'Gusau',
#   'Country': 'NG',
#   'Lat': 12.1628,
#   'Lng': 6.6614,
#   'Max Temp': 101.5,
#   'Humidity': 14,
#   'Cloudiness': 76,
#   'Wind Speed': 4.9,
#   'Current Description': 'broken clouds'},
#  {'City': 'Albany',
#   'Country': 'US',
#   'Lat': 42.6001,
#   'Lng': -73.9662,
#   'Max Temp': 44.58,
#   'Humidity': 60,
#   'Cloudiness': 92,
#   'Wind Speed': 5.99,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Airai',
#   'Country': 'TL',
#   'Lat': -8.9266,
#   'Lng': 125.4092,
#   'Max Temp': 57.63,
#   'Humidity': 74,
#   'Cloudiness': 19,
#   'Wind Speed': 1.74,
#   'Current Description': 'few clouds'},
#  {'City': 'Brae',
#   'Country': 'GB',
#   'Lat': 60.3964,
#   'Lng': -1.353,
#   'Max Temp': 38.8,
#   'Humidity': 55,
#   'Cloudiness': 99,
#   'Wind Speed': 11.14,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Klaksvik',
#   'Country': 'FO',
#   'Lat': 62.2266,
#   'Lng': -6.589,
#   'Max Temp': 36.52,
#   'Humidity': 61,
#   'Cloudiness': 91,
#   'Wind Speed': 9.95,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Kovdor',
#   'Country': 'RU',
#   'Lat': 67.5662,
#   'Lng': 30.4758,
#   'Max Temp': 31.17,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 6.26,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Port Alfred',
#   'Country': 'ZA',
#   'Lat': -33.5906,
#   'Lng': 26.891,
#   'Max Temp': 64.18,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 5.99,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Fare',
#   'Country': 'PF',
#   'Lat': -16.7,
#   'Lng': -151.0167,
#   'Max Temp': 82.02,
#   'Humidity': 75,
#   'Cloudiness': 3,
#   'Wind Speed': 16.53,
#   'Current Description': 'clear sky'},
#  {'City': 'Kamenka',
#   'Country': 'RU',
#   'Lat': 51.3223,
#   'Lng': 42.7678,
#   'Max Temp': 56.46,
#   'Humidity': 69,
#   'Cloudiness': 100,
#   'Wind Speed': 8.68,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Copperas Cove',
#   'Country': 'US',
#   'Lat': 31.1241,
#   'Lng': -97.9031,
#   'Max Temp': 77.31,
#   'Humidity': 56,
#   'Cloudiness': 0,
#   'Wind Speed': 19.57,
#   'Current Description': 'clear sky'},
#  {'City': 'Rajgarh',
#   'Country': 'IN',
#   'Lat': 28.6333,
#   'Lng': 75.3833,
#   'Max Temp': 91.2,
#   'Humidity': 9,
#   'Cloudiness': 18,
#   'Wind Speed': 10.13,
#   'Current Description': 'few clouds'},
#  {'City': 'Saint-Joseph',
#   'Country': 'RE',
#   'Lat': -21.3667,
#   'Lng': 55.6167,
#   'Max Temp': 77.38,
#   'Humidity': 81,
#   'Cloudiness': 44,
#   'Wind Speed': 14.63,
#   'Current Description': 'light rain'},
#  {'City': 'Quatre Cocos',
#   'Country': 'MU',
#   'Lat': -20.2078,
#   'Lng': 57.7625,
#   'Max Temp': 77.11,
#   'Humidity': 80,
#   'Cloudiness': 50,
#   'Wind Speed': 14.92,
#   'Current Description': 'light rain'},
#  {'City': 'Altamira',
#   'Country': 'BR',
#   'Lat': -3.2033,
#   'Lng': -52.2064,
#   'Max Temp': 87.89,
#   'Humidity': 70,
#   'Cloudiness': 75,
#   'Wind Speed': 6.91,
#   'Current Description': 'broken clouds'},
#  {'City': 'Bocaiuva',
#   'Country': 'BR',
#   'Lat': -17.1078,
#   'Lng': -43.815,
#   'Max Temp': 91.11,
#   'Humidity': 46,
#   'Cloudiness': 60,
#   'Wind Speed': 4.14,
#   'Current Description': 'broken clouds'},
#  {'City': 'Qaanaaq',
#   'Country': 'GL',
#   'Lat': 77.484,
#   'Lng': -69.3632,
#   'Max Temp': -0.27,
#   'Humidity': 81,
#   'Cloudiness': 55,
#   'Wind Speed': 5.5,
#   'Current Description': 'broken clouds'},
#  {'City': 'East London',
#   'Country': 'ZA',
#   'Lat': -33.0153,
#   'Lng': 27.9116,
#   'Max Temp': 68.94,
#   'Humidity': 88,
#   'Cloudiness': 75,
#   'Wind Speed': 11.5,
#   'Current Description': 'broken clouds'},
#  {'City': 'Shetpe',
#   'Country': 'KZ',
#   'Lat': 44.1667,
#   'Lng': 52.1167,
#   'Max Temp': 61.25,
#   'Humidity': 46,
#   'Cloudiness': 25,
#   'Wind Speed': 8.61,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Puerto Ayora',
#   'Country': 'EC',
#   'Lat': -0.7393,
#   'Lng': -90.3518,
#   'Max Temp': 82.36,
#   'Humidity': 89,
#   'Cloudiness': 94,
#   'Wind Speed': 7,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Khani',
#   'Country': 'GE',
#   'Lat': 41.9563,
#   'Lng': 42.9566,
#   'Max Temp': 56.77,
#   'Humidity': 67,
#   'Cloudiness': 100,
#   'Wind Speed': 8.79,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Aloleng',
#   'Country': 'PH',
#   'Lat': 16.1307,
#   'Lng': 119.7824,
#   'Max Temp': 80.98,
#   'Humidity': 77,
#   'Cloudiness': 92,
#   'Wind Speed': 3.8,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Salinopolis',
#   'Country': 'BR',
#   'Lat': -0.6136,
#   'Lng': -47.3561,
#   'Max Temp': 75.56,
#   'Humidity': 91,
#   'Cloudiness': 100,
#   'Wind Speed': 6.17,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Tuktoyaktuk',
#   'Country': 'CA',
#   'Lat': 69.4541,
#   'Lng': -133.0374,
#   'Max Temp': -7.6,
#   'Humidity': 77,
#   'Cloudiness': 75,
#   'Wind Speed': 11.5,
#   'Current Description': 'broken clouds'},
#  {'City': 'Alofi',
#   'Country': 'NU',
#   'Lat': -19.0595,
#   'Lng': -169.9187,
#   'Max Temp': 73.29,
#   'Humidity': 100,
#   'Cloudiness': 10,
#   'Wind Speed': 2.3,
#   'Current Description': 'clear sky'},
#  {'City': 'Lufilufi',
#   'Country': 'WS',
#   'Lat': -13.8745,
#   'Lng': -171.5986,
#   'Max Temp': 73.18,
#   'Humidity': 79,
#   'Cloudiness': 39,
#   'Wind Speed': 11.92,
#   'Current Description': 'light rain'},
#  {'City': 'Saskylakh',
#   'Country': 'RU',
#   'Lat': 71.9167,
#   'Lng': 114.0833,
#   'Max Temp': -17.09,
#   'Humidity': 100,
#   'Cloudiness': 13,
#   'Wind Speed': 3.13,
#   'Current Description': 'few clouds'},
#  {'City': 'Hobart',
#   'Country': 'AU',
#   'Lat': -42.8794,
#   'Lng': 147.3294,
#   'Max Temp': 54.01,
#   'Humidity': 63,
#   'Cloudiness': 75,
#   'Wind Speed': 8.05,
#   'Current Description': 'broken clouds'},
#  {'City': 'Hirara',
#   'Country': 'JP',
#   'Lat': 24.8,
#   'Lng': 125.2833,
#   'Max Temp': 73.85,
#   'Humidity': 91,
#   'Cloudiness': 84,
#   'Wind Speed': 14.97,
#   'Current Description': 'broken clouds'},
#  {'City': 'Sao Joao Da Barra',
#   'Country': 'BR',
#   'Lat': -21.6403,
#   'Lng': -41.0511,
#   'Max Temp': 86.09,
#   'Humidity': 76,
#   'Cloudiness': 44,
#   'Wind Speed': 8.01,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Rocha',
#   'Country': 'UY',
#   'Lat': -34.4833,
#   'Lng': -54.3333,
#   'Max Temp': 81.57,
#   'Humidity': 41,
#   'Cloudiness': 2,
#   'Wind Speed': 13.11,
#   'Current Description': 'clear sky'},
#  {'City': 'Bilma',
#   'Country': 'NE',
#   'Lat': 18.6853,
#   'Lng': 12.9164,
#   'Max Temp': 97.97,
#   'Humidity': 4,
#   'Cloudiness': 0,
#   'Wind Speed': 3.18,
#   'Current Description': 'clear sky'},
#  {'City': 'Mataura',
#   'Country': 'NZ',
#   'Lat': -46.1927,
#   'Lng': 168.8643,
#   'Max Temp': 40.6,
#   'Humidity': 99,
#   'Cloudiness': 17,
#   'Wind Speed': 3,
#   'Current Description': 'few clouds'},
#  {'City': 'Brindisi',
#   'Country': 'IT',
#   'Lat': 40.5833,
#   'Lng': 17.6667,
#   'Max Temp': 53.96,
#   'Humidity': 54,
#   'Cloudiness': 19,
#   'Wind Speed': 29.8,
#   'Current Description': 'few clouds'},
#  {'City': 'Farah',
#   'Country': 'AF',
#   'Lat': 32.5,
#   'Lng': 62.5,
#   'Max Temp': 80.76,
#   'Humidity': 8,
#   'Cloudiness': 100,
#   'Wind Speed': 3.56,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Dutse',
#   'Country': 'NG',
#   'Lat': 11.7594,
#   'Lng': 9.3392,
#   'Max Temp': 96.6,
#   'Humidity': 13,
#   'Cloudiness': 99,
#   'Wind Speed': 3.85,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Liberty',
#   'Country': 'US',
#   'Lat': 31.8335,
#   'Lng': -81.5004,
#   'Max Temp': 69.28,
#   'Humidity': 30,
#   'Cloudiness': 0,
#   'Wind Speed': 11.5,
#   'Current Description': 'clear sky'},
#  {'City': 'Iskateley',
#   'Country': 'RU',
#   'Lat': 67.6803,
#   'Lng': 53.1512,
#   'Max Temp': 35.49,
#   'Humidity': 100,
#   'Cloudiness': 100,
#   'Wind Speed': 13.6,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Khatanga',
#   'Country': 'RU',
#   'Lat': 71.9667,
#   'Lng': 102.5,
#   'Max Temp': 1.22,
#   'Humidity': 98,
#   'Cloudiness': 98,
#   'Wind Speed': 2.13,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Vila Velha',
#   'Country': 'BR',
#   'Lat': -20.3297,
#   'Lng': -40.2925,
#   'Max Temp': 85.95,
#   'Humidity': 78,
#   'Cloudiness': 40,
#   'Wind Speed': 12.66,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Verkhnevilyuysk',
#   'Country': 'RU',
#   'Lat': 63.4453,
#   'Lng': 120.3167,
#   'Max Temp': 1.24,
#   'Humidity': 100,
#   'Cloudiness': 71,
#   'Wind Speed': 2.39,
#   'Current Description': 'broken clouds'},
#  {'City': 'West Plains',
#   'Country': 'US',
#   'Lat': 36.7281,
#   'Lng': -91.8524,
#   'Max Temp': 72.82,
#   'Humidity': 46,
#   'Cloudiness': 67,
#   'Wind Speed': 11.99,
#   'Current Description': 'broken clouds'},
#  {'City': 'Hervey Bay',
#   'Country': 'AU',
#   'Lat': -25.2986,
#   'Lng': 152.8535,
#   'Max Temp': 72.61,
#   'Humidity': 79,
#   'Cloudiness': 47,
#   'Wind Speed': 12.01,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Mayor Pablo Lagerenza',
#   'Country': 'PY',
#   'Lat': -19.9309,
#   'Lng': -60.7718,
#   'Max Temp': 100.42,
#   'Humidity': 28,
#   'Cloudiness': 6,
#   'Wind Speed': 16.42,
#   'Current Description': 'clear sky'},
#  {'City': 'Minudasht',
#   'Country': 'IR',
#   'Lat': 37.2289,
#   'Lng': 55.3747,
#   'Max Temp': 53.92,
#   'Humidity': 100,
#   'Cloudiness': 100,
#   'Wind Speed': 4.61,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Butaritari',
#   'Country': 'KI',
#   'Lat': 3.0707,
#   'Lng': 172.7902,
#   'Max Temp': 80.65,
#   'Humidity': 75,
#   'Cloudiness': 99,
#   'Wind Speed': 7.7,
#   'Current Description': 'light rain'},
#  {'City': 'Las Matas De Farfan',
#   'Country': 'DO',
#   'Lat': 18.8731,
#   'Lng': -71.5166,
#   'Max Temp': 87.49,
#   'Humidity': 41,
#   'Cloudiness': 68,
#   'Wind Speed': 4.52,
#   'Current Description': 'broken clouds'},
#  {'City': 'Bud',
#   'Country': 'US',
#   'Lat': 39.447,
#   'Lng': -86.1758,
#   'Max Temp': 58.41,
#   'Humidity': 44,
#   'Cloudiness': 30,
#   'Wind Speed': 11.99,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Bluff',
#   'Country': 'NZ',
#   'Lat': -46.6,
#   'Lng': 168.3333,
#   'Max Temp': 47.79,
#   'Humidity': 87,
#   'Cloudiness': 24,
#   'Wind Speed': 10.27,
#   'Current Description': 'few clouds'},
#  {'City': 'Talara',
#   'Country': 'PE',
#   'Lat': -4.5772,
#   'Lng': -81.2719,
#   'Max Temp': 77.77,
#   'Humidity': 67,
#   'Cloudiness': 89,
#   'Wind Speed': 16.26,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Kavieng',
#   'Country': 'PG',
#   'Lat': -2.5744,
#   'Lng': 150.7967,
#   'Max Temp': 81.79,
#   'Humidity': 77,
#   'Cloudiness': 100,
#   'Wind Speed': 10.65,
#   'Current Description': 'light rain'},
#  {'City': 'Hermanus',
#   'Country': 'ZA',
#   'Lat': -34.4187,
#   'Lng': 19.2345,
#   'Max Temp': 67.8,
#   'Humidity': 71,
#   'Cloudiness': 0,
#   'Wind Speed': 13.04,
#   'Current Description': 'clear sky'},
#  {'City': 'Potiskum',
#   'Country': 'NG',
#   'Lat': 11.7091,
#   'Lng': 11.0694,
#   'Max Temp': 98.22,
#   'Humidity': 13,
#   'Cloudiness': 92,
#   'Wind Speed': 4.23,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Hamilton',
#   'Country': 'US',
#   'Lat': 39.1834,
#   'Lng': -84.5333,
#   'Max Temp': 58.08,
#   'Humidity': 45,
#   'Cloudiness': 0,
#   'Wind Speed': 9.22,
#   'Current Description': 'clear sky'},
#  {'City': 'Bambous Virieux',
#   'Country': 'MU',
#   'Lat': -20.3428,
#   'Lng': 57.7575,
#   'Max Temp': 77.25,
#   'Humidity': 88,
#   'Cloudiness': 75,
#   'Wind Speed': 8.05,
#   'Current Description': 'light rain'},
#  {'City': 'Aragarcas',
#   'Country': 'BR',
#   'Lat': -15.8975,
#   'Lng': -52.2508,
#   'Max Temp': 92.08,
#   'Humidity': 47,
#   'Cloudiness': 6,
#   'Wind Speed': 2.48,
#   'Current Description': 'clear sky'},
#  {'City': 'Pacific Grove',
#   'Country': 'US',
#   'Lat': 36.6177,
#   'Lng': -121.9166,
#   'Max Temp': 64.45,
#   'Humidity': 68,
#   'Cloudiness': 79,
#   'Wind Speed': 5.99,
#   'Current Description': 'broken clouds'},
#  {'City': 'Gobabis',
#   'Country': 'NA',
#   'Lat': -22.45,
#   'Lng': 18.9667,
#   'Max Temp': 75.2,
#   'Humidity': 18,
#   'Cloudiness': 0,
#   'Wind Speed': 7.2,
#   'Current Description': 'clear sky'},
#  {'City': 'Hornepayne',
#   'Country': 'CA',
#   'Lat': 49.2138,
#   'Lng': -84.7705,
#   'Max Temp': 37.49,
#   'Humidity': 88,
#   'Cloudiness': 97,
#   'Wind Speed': 3.4,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Sioux Lookout',
#   'Country': 'CA',
#   'Lat': 50.1001,
#   'Lng': -91.917,
#   'Max Temp': 42.87,
#   'Humidity': 45,
#   'Cloudiness': 100,
#   'Wind Speed': 9.22,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Pisco',
#   'Country': 'PE',
#   'Lat': -13.7,
#   'Lng': -76.2167,
#   'Max Temp': 72.01,
#   'Humidity': 78,
#   'Cloudiness': 87,
#   'Wind Speed': 7.23,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Tiksi',
#   'Country': 'RU',
#   'Lat': 71.6872,
#   'Lng': 128.8694,
#   'Max Temp': -15.12,
#   'Humidity': 100,
#   'Cloudiness': 100,
#   'Wind Speed': 1.81,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Isa Khel',
#   'Country': 'AF',
#   'Lat': 36.6702,
#   'Lng': 68.8443,
#   'Max Temp': 77.83,
#   'Humidity': 30,
#   'Cloudiness': 100,
#   'Wind Speed': 4.25,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Menongue',
#   'Country': 'AO',
#   'Lat': -14.6585,
#   'Lng': 17.691,
#   'Max Temp': 68.27,
#   'Humidity': 80,
#   'Cloudiness': 95,
#   'Wind Speed': 6.58,
#   'Current Description': 'light rain'},
#  {'City': 'Pratapgarh',
#   'Country': 'IN',
#   'Lat': 24.0333,
#   'Lng': 74.7833,
#   'Max Temp': 88.79,
#   'Humidity': 16,
#   'Cloudiness': 1,
#   'Wind Speed': 7.23,
#   'Current Description': 'clear sky'},
#  {'City': 'Clyde River',
#   'Country': 'CA',
#   'Lat': 70.4692,
#   'Lng': -68.5914,
#   'Max Temp': 1.63,
#   'Humidity': 92,
#   'Cloudiness': 75,
#   'Wind Speed': 6.91,
#   'Current Description': 'light snow'},
#  {'City': 'Clarence Town',
#   'Country': 'AU',
#   'Lat': -32.5833,
#   'Lng': 151.7833,
#   'Max Temp': 65.8,
#   'Humidity': 97,
#   'Cloudiness': 1,
#   'Wind Speed': 2.8,
#   'Current Description': 'clear sky'},
#  {'City': 'Muroto',
#   'Country': 'JP',
#   'Lat': 33.2833,
#   'Lng': 134.15,
#   'Max Temp': 62.6,
#   'Humidity': 77,
#   'Cloudiness': 99,
#   'Wind Speed': 4.74,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Thinadhoo',
#   'Country': 'MV',
#   'Lat': 0.5333,
#   'Lng': 72.9333,
#   'Max Temp': 84.52,
#   'Humidity': 65,
#   'Cloudiness': 20,
#   'Wind Speed': 9.4,
#   'Current Description': 'few clouds'},
#  {'City': 'Huntsville',
#   'Country': 'US',
#   'Lat': 34.7304,
#   'Lng': -86.5861,
#   'Max Temp': 70.83,
#   'Humidity': 35,
#   'Cloudiness': 0,
#   'Wind Speed': 14.97,
#   'Current Description': 'clear sky'},
#  {'City': 'Leningradskiy',
#   'Country': 'RU',
#   'Lat': 69.3833,
#   'Lng': 178.4167,
#   'Max Temp': -13.81,
#   'Humidity': 92,
#   'Cloudiness': 65,
#   'Wind Speed': 5.03,
#   'Current Description': 'broken clouds'},
#  {'City': 'Barrow',
#   'Country': 'US',
#   'Lat': 71.2906,
#   'Lng': -156.7887,
#   'Max Temp': -3.96,
#   'Humidity': 93,
#   'Cloudiness': 98,
#   'Wind Speed': 9.82,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Kruisfontein',
#   'Country': 'ZA',
#   'Lat': -34.0033,
#   'Lng': 24.7314,
#   'Max Temp': 64.89,
#   'Humidity': 83,
#   'Cloudiness': 87,
#   'Wind Speed': 11.59,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Luderitz',
#   'Country': 'NA',
#   'Lat': -26.6481,
#   'Lng': 15.1594,
#   'Max Temp': 70.41,
#   'Humidity': 61,
#   'Cloudiness': 0,
#   'Wind Speed': 10.11,
#   'Current Description': 'clear sky'},
#  {'City': 'Schonenwerd',
#   'Country': 'CH',
#   'Lat': 47.3691,
#   'Lng': 8.0017,
#   'Max Temp': 54.18,
#   'Humidity': 46,
#   'Cloudiness': 23,
#   'Wind Speed': 5.01,
#   'Current Description': 'few clouds'},
#  {'City': 'Gravdal',
#   'Country': 'NO',
#   'Lat': 68.1214,
#   'Lng': 13.5031,
#   'Max Temp': 35.49,
#   'Humidity': 87,
#   'Cloudiness': 75,
#   'Wind Speed': 2.3,
#   'Current Description': 'broken clouds'},
#  {'City': 'Lompoc',
#   'Country': 'US',
#   'Lat': 34.6391,
#   'Lng': -120.4579,
#   'Max Temp': 72.84,
#   'Humidity': 82,
#   'Cloudiness': 40,
#   'Wind Speed': 14,
#   'Current Description': 'haze'},
#  {'City': 'Rio Grande',
#   'Country': 'BR',
#   'Lat': -32.035,
#   'Lng': -52.0986,
#   'Max Temp': 82.51,
#   'Humidity': 75,
#   'Cloudiness': 30,
#   'Wind Speed': 17.36,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Bekovo',
#   'Country': 'RU',
#   'Lat': 52.4663,
#   'Lng': 43.712,
#   'Max Temp': 53.92,
#   'Humidity': 74,
#   'Cloudiness': 100,
#   'Wind Speed': 7.96,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Sitka',
#   'Country': 'US',
#   'Lat': 57.0531,
#   'Lng': -135.33,
#   'Max Temp': 40.44,
#   'Humidity': 66,
#   'Cloudiness': 7,
#   'Wind Speed': 4.5,
#   'Current Description': 'clear sky'},
#  {'City': 'Roros',
#   'Country': 'NO',
#   'Lat': 62.5747,
#   'Lng': 11.3842,
#   'Max Temp': 31.84,
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 13.8,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Ribeira Grande',
#   'Country': 'PT',
#   'Lat': 38.5167,
#   'Lng': -28.7,
#   'Max Temp': 57.6,
#   'Humidity': 62,
#   'Cloudiness': 40,
#   'Wind Speed': 27.63,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Gokak',
#   'Country': 'IN',
#   'Lat': 16.1667,
#   'Lng': 74.8333,
#   'Max Temp': 75.94,
#   'Humidity': 62,
#   'Cloudiness': 100,
#   'Wind Speed': 9.62,
#   'Current Description': 'heavy intensity rain'},
#  {'City': 'Paamiut',
#   'Country': 'GL',
#   'Lat': 61.994,
#   'Lng': -49.6678,
#   'Max Temp': 31.64,
#   'Humidity': 80,
#   'Cloudiness': 100,
#   'Wind Speed': 15.28,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Cabo San Lucas',
#   'Country': 'MX',
#   'Lat': 22.8909,
#   'Lng': -109.9124,
#   'Max Temp': 78.62,
#   'Humidity': 57,
#   'Cloudiness': 22,
#   'Wind Speed': 5.01,
#   'Current Description': 'few clouds'},
#  {'City': 'New Norfolk',
#   'Country': 'AU',
#   'Lat': -42.7826,
#   'Lng': 147.0587,
#   'Max Temp': 53.65,
#   'Humidity': 41,
#   'Cloudiness': 68,
#   'Wind Speed': 4.79,
#   'Current Description': 'broken clouds'},
#  {'City': 'Mandla',
#   'Country': 'IN',
#   'Lat': 22.6,
#   'Lng': 80.3833,
#   'Max Temp': 87.85,
#   'Humidity': 14,
#   'Cloudiness': 32,
#   'Wind Speed': 2.17,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Kaitangata',
#   'Country': 'NZ',
#   'Lat': -46.2817,
#   'Lng': 169.8464,
#   'Max Temp': 44.37,
#   'Humidity': 96,
#   'Cloudiness': 14,
#   'Wind Speed': 4.99,
#   'Current Description': 'few clouds'},
#  {'City': 'Athens',
#   'Country': 'GR',
#   'Lat': 37.9795,
#   'Lng': 23.7162,
#   'Max Temp': 67.21,
#   'Humidity': 41,
#   'Cloudiness': 20,
#   'Wind Speed': 17,
#   'Current Description': 'few clouds'},
#  {'City': 'Bahia Blanca',
#   'Country': 'AR',
#   'Lat': -38.7196,
#   'Lng': -62.2724,
#   'Max Temp': 62.02,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 9.06,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Deputatskiy',
#   'Country': 'RU',
#   'Lat': 69.3,
#   'Lng': 139.9,
#   'Max Temp': -15.32,
#   'Humidity': 92,
#   'Cloudiness': 57,
#   'Wind Speed': 2.42,
#   'Current Description': 'broken clouds'},
#  {'City': 'Hailar',
#   'Country': 'CN',
#   'Lat': 49.2,
#   'Lng': 119.7,
#   'Max Temp': 28.06,
#   'Humidity': 73,
#   'Cloudiness': 100,
#   'Wind Speed': 6.31,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Kemijarvi',
#   'Country': 'FI',
#   'Lat': 66.7131,
#   'Lng': 27.4306,
#   'Max Temp': 29.98,
#   'Humidity': 92,
#   'Cloudiness': 55,
#   'Wind Speed': 2.77,
#   'Current Description': 'broken clouds'},
#  {'City': 'Fairbanks',
#   'Country': 'US',
#   'Lat': 64.8378,
#   'Lng': -147.7164,
#   'Max Temp': 15.22,
#   'Humidity': 62,
#   'Cloudiness': 100,
#   'Wind Speed': 1.01,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Shuangyang',
#   'Country': 'CN',
#   'Lat': 43.5242,
#   'Lng': 125.6736,
#   'Max Temp': 60.62,
#   'Humidity': 54,
#   'Cloudiness': 95,
#   'Wind Speed': 8.97,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Candolim',
#   'Country': 'IN',
#   'Lat': 15.5181,
#   'Lng': 73.7626,
#   'Max Temp': 84.2,
#   'Humidity': 79,
#   'Cloudiness': 40,
#   'Wind Speed': 4.61,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Ponta Do Sol',
#   'Country': 'PT',
#   'Lat': 32.6667,
#   'Lng': -17.1,
#   'Max Temp': 69.01,
#   'Humidity': 74,
#   'Cloudiness': 38,
#   'Wind Speed': 14.45,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Dezhou',
#   'Country': 'CN',
#   'Lat': 37.4486,
#   'Lng': 116.2925,
#   'Max Temp': 75.18,
#   'Humidity': 49,
#   'Cloudiness': 0,
#   'Wind Speed': 16.73,
#   'Current Description': 'clear sky'},
#  {'City': 'Hilo',
#   'Country': 'US',
#   'Lat': 19.7297,
#   'Lng': -155.09,
#   'Max Temp': 70.25,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 3,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Dikson',
#   'Country': 'RU',
#   'Lat': 73.5069,
#   'Lng': 80.5464,
#   'Max Temp': -5.28,
#   'Humidity': 100,
#   'Cloudiness': 76,
#   'Wind Speed': 2.48,
#   'Current Description': 'broken clouds'},
#  {'City': 'Kande',
#   'Country': 'TG',
#   'Lat': 9.9578,
#   'Lng': 1.0447,
#   'Max Temp': 97.14,
#   'Humidity': 40,
#   'Cloudiness': 84,
#   'Wind Speed': 10.42,
#   'Current Description': 'light rain'},
#  {'City': 'Lebu',
#   'Country': 'CL',
#   'Lat': -37.6167,
#   'Lng': -73.65,
#   'Max Temp': 56.08,
#   'Humidity': 76,
#   'Cloudiness': 50,
#   'Wind Speed': 10.33,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Shimoda',
#   'Country': 'JP',
#   'Lat': 34.6667,
#   'Lng': 138.95,
#   'Max Temp': 60.1,
#   'Humidity': 81,
#   'Cloudiness': 94,
#   'Wind Speed': 7.2,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Namibe',
#   'Country': 'AO',
#   'Lat': -15.1961,
#   'Lng': 12.1522,
#   'Max Temp': 72.7,
#   'Humidity': 78,
#   'Cloudiness': 36,
#   'Wind Speed': 7.78,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Bogande',
#   'Country': 'BF',
#   'Lat': 12.9714,
#   'Lng': -0.1436,
#   'Max Temp': 105.12,
#   'Humidity': 14,
#   'Cloudiness': 96,
#   'Wind Speed': 3.13,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Muzhi',
#   'Country': 'RU',
#   'Lat': 65.3667,
#   'Lng': 64.6667,
#   'Max Temp': 34.29,
#   'Humidity': 99,
#   'Cloudiness': 100,
#   'Wind Speed': 10.27,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Guerrero Negro',
#   'Country': 'MX',
#   'Lat': 27.9769,
#   'Lng': -114.0611,
#   'Max Temp': 68.22,
#   'Humidity': 63,
#   'Cloudiness': 18,
#   'Wind Speed': 1.92,
#   'Current Description': 'few clouds'},
#  {'City': 'Sumbe',
#   'Country': 'AO',
#   'Lat': -11.2061,
#   'Lng': 13.8437,
#   'Max Temp': 78.4,
#   'Humidity': 87,
#   'Cloudiness': 89,
#   'Wind Speed': 4.99,
#   'Current Description': 'moderate rain'},
#  {'City': 'Tuatapere',
#   'Country': 'NZ',
#   'Lat': -46.1333,
#   'Lng': 167.6833,
#   'Max Temp': 44.22,
#   'Humidity': 90,
#   'Cloudiness': 4,
#   'Wind Speed': 6.17,
#   'Current Description': 'clear sky'},
#  {'City': 'Puerto Penasco',
#   'Country': 'MX',
#   'Lat': 31.3167,
#   'Lng': -113.5333,
#   'Max Temp': 68.92,
#   'Humidity': 84,
#   'Cloudiness': 0,
#   'Wind Speed': 15.01,
#   'Current Description': 'clear sky'},
#  {'City': 'Vardo',
#   'Country': 'NO',
#   'Lat': 70.3705,
#   'Lng': 31.1107,
#   'Max Temp': 36.73,
#   'Humidity': 87,
#   'Cloudiness': 81,
#   'Wind Speed': 22.28,
#   'Current Description': 'broken clouds'},
#  {'City': 'Hithadhoo',
#   'Country': 'MV',
#   'Lat': -0.6,
#   'Lng': 73.0833,
#   'Max Temp': 83.84,
#   'Humidity': 72,
#   'Cloudiness': 26,
#   'Wind Speed': 9.89,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Yatou',
#   'Country': 'CN',
#   'Lat': 37.15,
#   'Lng': 122.3833,
#   'Max Temp': 51.6,
#   'Humidity': 95,
#   'Cloudiness': 13,
#   'Wind Speed': 13.04,
#   'Current Description': 'few clouds'},
#  {'City': 'Kloulklubed',
#   'Country': 'PW',
#   'Lat': 7.0419,
#   'Lng': 134.2556,
#   'Max Temp': 82.83,
#   'Humidity': 83,
#   'Cloudiness': 100,
#   'Wind Speed': 25.12,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Beausejour',
#   'Country': 'CA',
#   'Lat': 50.0622,
#   'Lng': -96.5167,
#   'Max Temp': 45.81,
#   'Humidity': 71,
#   'Cloudiness': 100,
#   'Wind Speed': 4.74,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Victoria',
#   'Country': 'HK',
#   'Lat': 22.2855,
#   'Lng': 114.1577,
#   'Max Temp': 77.18,
#   'Humidity': 86,
#   'Cloudiness': 1,
#   'Wind Speed': 1.01,
#   'Current Description': 'clear sky'},
#  {'City': 'Lagoa',
#   'Country': 'PT',
#   'Lat': 39.05,
#   'Lng': -27.9833,
#   'Max Temp': 55.71,
#   'Humidity': 60,
#   'Cloudiness': 100,
#   'Wind Speed': 33.24,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Codrington',
#   'Country': 'AU',
#   'Lat': -38.2667,
#   'Lng': 141.9667,
#   'Max Temp': 58.41,
#   'Humidity': 64,
#   'Cloudiness': 100,
#   'Wind Speed': 11.61,
#   'Current Description': 'light rain'},
#  {'City': 'Jamestown',
#   'Country': 'US',
#   'Lat': 42.097,
#   'Lng': -79.2353,
#   'Max Temp': 37.53,
#   'Humidity': 48,
#   'Cloudiness': 100,
#   'Wind Speed': 5.99,
#   'Current Description': 'overcast clouds'},
#  {'City': 'College',
#   'Country': 'US',
#   'Lat': 64.8569,
#   'Lng': -147.8028,
#   'Max Temp': 15.21,
#   'Humidity': 61,
#   'Cloudiness': 100,
#   'Wind Speed': 0,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Hofn',
#   'Country': 'IS',
#   'Lat': 64.2539,
#   'Lng': -15.2082,
#   'Max Temp': 39.22,
#   'Humidity': 56,
#   'Cloudiness': 40,
#   'Wind Speed': 8.05,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Kiunga',
#   'Country': 'PG',
#   'Lat': -6.1219,
#   'Lng': 141.2906,
#   'Max Temp': 73.36,
#   'Humidity': 99,
#   'Cloudiness': 97,
#   'Wind Speed': 0.94,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Hovd',
#   'Country': 'MN',
#   'Lat': 48.0056,
#   'Lng': 91.6419,
#   'Max Temp': 28.9,
#   'Humidity': 37,
#   'Cloudiness': 8,
#   'Wind Speed': 5.3,
#   'Current Description': 'clear sky'},
#  {'City': 'Mnogovershinnyy',
#   'Country': 'RU',
#   'Lat': 53.9353,
#   'Lng': 139.9242,
#   'Max Temp': 13.89,
#   'Humidity': 85,
#   'Cloudiness': 97,
#   'Wind Speed': 3.83,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Cape Canaveral',
#   'Country': 'US',
#   'Lat': 28.4058,
#   'Lng': -80.6048,
#   'Max Temp': 73.08,
#   'Humidity': 40,
#   'Cloudiness': 0,
#   'Wind Speed': 10,
#   'Current Description': 'clear sky'},
#  {'City': 'Umm Lajj',
#   'Country': 'SA',
#   'Lat': 25.0213,
#   'Lng': 37.2685,
#   'Max Temp': 79.34,
#   'Humidity': 53,
#   'Cloudiness': 4,
#   'Wind Speed': 5.68,
#   'Current Description': 'clear sky'},
#  {'City': 'Dunedin',
#   'Country': 'NZ',
#   'Lat': -45.8742,
#   'Lng': 170.5036,
#   'Max Temp': 51.8,
#   'Humidity': 90,
#   'Cloudiness': 6,
#   'Wind Speed': 1.99,
#   'Current Description': 'clear sky'},
#  {'City': 'Killybegs',
#   'Country': 'IE',
#   'Lat': 54.6333,
#   'Lng': -8.45,
#   'Max Temp': 51.51,
#   'Humidity': 80,
#   'Cloudiness': 100,
#   'Wind Speed': 19.62,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Letnica',
#   'Country': 'PL',
#   'Lat': 51.8981,
#   'Lng': 15.333,
#   'Max Temp': 44.33,
#   'Humidity': 42,
#   'Cloudiness': 97,
#   'Wind Speed': 10.11,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Vila Do Maio',
#   'Country': 'CV',
#   'Lat': 15.1333,
#   'Lng': -23.2167,
#   'Max Temp': 79.59,
#   'Humidity': 80,
#   'Cloudiness': 14,
#   'Wind Speed': 18.63,
#   'Current Description': 'few clouds'},
#  {'City': 'Vestmannaeyjar',
#   'Country': 'IS',
#   'Lat': 63.4427,
#   'Lng': -20.2734,
#   'Max Temp': 40.19,
#   'Humidity': 75,
#   'Cloudiness': 20,
#   'Wind Speed': 28.77,
#   'Current Description': 'few clouds'},
#  {'City': 'Sao Felix Do Xingu',
#   'Country': 'BR',
#   'Lat': -6.6447,
#   'Lng': -51.995,
#   'Max Temp': 86.45,
#   'Humidity': 62,
#   'Cloudiness': 97,
#   'Wind Speed': 3.29,
#   'Current Description': 'light rain'},
#  {'City': 'Samarai',
#   'Country': 'PG',
#   'Lat': -10.6167,
#   'Lng': 150.6667,
#   'Max Temp': 83.77,
#   'Humidity': 75,
#   'Cloudiness': 46,
#   'Wind Speed': 14.67,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Vestmanna',
#   'Country': 'FO',
#   'Lat': 62.1564,
#   'Lng': -7.1664,
#   'Max Temp': 34.72,
#   'Humidity': 64,
#   'Cloudiness': 87,
#   'Wind Speed': 5.75,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Vuktyl',
#   'Country': 'RU',
#   'Lat': 63.8567,
#   'Lng': 57.3094,
#   'Max Temp': 38.43,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 10.8,
#   'Current Description': 'overcast clouds'},
#  {'City': 'San Cristobal',
#   'Country': 'VE',
#   'Lat': 7.7669,
#   'Lng': -72.225,
#   'Max Temp': 77.18,
#   'Humidity': 39,
#   'Cloudiness': 96,
#   'Wind Speed': 8.12,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Sistranda',
#   'Country': 'NO',
#   'Lat': 63.7256,
#   'Lng': 8.834,
#   'Max Temp': 40.96,
#   'Humidity': 75,
#   'Cloudiness': 100,
#   'Wind Speed': 34.38,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Grootfontein',
#   'Country': 'NA',
#   'Lat': -19.5667,
#   'Lng': 18.1167,
#   'Max Temp': 69.37,
#   'Humidity': 88,
#   'Cloudiness': 54,
#   'Wind Speed': 6.91,
#   'Current Description': 'broken clouds'},
#  {'City': 'Nizwa',
#   'Country': 'OM',
#   'Lat': 22.9333,
#   'Lng': 57.5333,
#   'Max Temp': 87.28,
#   'Humidity': 9,
#   'Cloudiness': 91,
#   'Wind Speed': 9.08,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Khonsa',
#   'Country': 'IN',
#   'Lat': 27.0167,
#   'Lng': 95.5667,
#   'Max Temp': 58.59,
#   'Humidity': 90,
#   'Cloudiness': 58,
#   'Wind Speed': 5.06,
#   'Current Description': 'broken clouds'},
#  {'City': 'Cherskiy',
#   'Country': 'RU',
#   'Lat': 68.75,
#   'Lng': 161.3,
#   'Max Temp': -15.02,
#   'Humidity': 100,
#   'Cloudiness': 100,
#   'Wind Speed': 2.26,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Marawi',
#   'Country': 'PH',
#   'Lat': 7.9986,
#   'Lng': 124.2928,
#   'Max Temp': 69.1,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 5.1,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Oromocto',
#   'Country': 'CA',
#   'Lat': 45.8351,
#   'Lng': -66.4792,
#   'Max Temp': 42.73,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 5.75,
#   'Current Description': 'mist'},
#  {'City': 'Nabire',
#   'Country': 'ID',
#   'Lat': -3.3667,
#   'Lng': 135.4833,
#   'Max Temp': 74.57,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 4.05,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Dongfeng',
#   'Country': 'CN',
#   'Lat': 42.6403,
#   'Lng': 125.5118,
#   'Max Temp': 57.42,
#   'Humidity': 48,
#   'Cloudiness': 98,
#   'Wind Speed': 14.25,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Sinegorye',
#   'Country': 'RU',
#   'Lat': 62.0788,
#   'Lng': 150.477,
#   'Max Temp': -15.54,
#   'Humidity': 97,
#   'Cloudiness': 93,
#   'Wind Speed': 2.89,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Saint-Philippe',
#   'Country': 'RE',
#   'Lat': -21.3585,
#   'Lng': 55.7679,
#   'Max Temp': 78.39,
#   'Humidity': 83,
#   'Cloudiness': 68,
#   'Wind Speed': 14,
#   'Current Description': 'light rain'},
#  {'City': 'Atambua',
#   'Country': 'ID',
#   'Lat': -9.1061,
#   'Lng': 124.8925,
#   'Max Temp': 71.73,
#   'Humidity': 88,
#   'Cloudiness': 50,
#   'Wind Speed': 3.94,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Broken Hill',
#   'Country': 'AU',
#   'Lat': -31.95,
#   'Lng': 141.4333,
#   'Max Temp': 62.31,
#   'Humidity': 59,
#   'Cloudiness': 0,
#   'Wind Speed': 6.91,
#   'Current Description': 'clear sky'},
#  {'City': 'Don Sak',
#   'Country': 'TH',
#   'Lat': 9.3168,
#   'Lng': 99.6918,
#   'Max Temp': 79.97,
#   'Humidity': 79,
#   'Cloudiness': 53,
#   'Wind Speed': 1.68,
#   'Current Description': 'broken clouds'},
#  {'City': 'Mareeba',
#   'Country': 'AU',
#   'Lat': -17,
#   'Lng': 145.4333,
#   'Max Temp': 74.44,
#   'Humidity': 91,
#   'Cloudiness': 60,
#   'Wind Speed': 2.98,
#   'Current Description': 'broken clouds'},
#  {'City': 'Faya',
#   'Country': 'SA',
#   'Lat': 18.3851,
#   'Lng': 42.4509,
#   'Max Temp': 71.71,
#   'Humidity': 40,
#   'Cloudiness': 1,
#   'Wind Speed': 5.23,
#   'Current Description': 'clear sky'},
#  {'City': 'Choya',
#   'Country': 'RU',
#   'Lat': 52.0108,
#   'Lng': 86.5467,
#   'Max Temp': 31.53,
#   'Humidity': 97,
#   'Cloudiness': 97,
#   'Wind Speed': 2.04,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Sigli',
#   'Country': 'ID',
#   'Lat': 5.3848,
#   'Lng': 95.9609,
#   'Max Temp': 80.8,
#   'Humidity': 80,
#   'Cloudiness': 74,
#   'Wind Speed': 3.58,
#   'Current Description': 'broken clouds'},
#  {'City': 'Castro',
#   'Country': 'BR',
#   'Lat': -24.7911,
#   'Lng': -50.0119,
#   'Max Temp': 77.14,
#   'Humidity': 50,
#   'Cloudiness': 100,
#   'Wind Speed': 0.96,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Tambovka',
#   'Country': 'RU',
#   'Lat': 50.0969,
#   'Lng': 128.0489,
#   'Max Temp': 36.12,
#   'Humidity': 82,
#   'Cloudiness': 32,
#   'Wind Speed': 10.13,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Prince Rupert',
#   'Country': 'CA',
#   'Lat': 54.3161,
#   'Lng': -130.3201,
#   'Max Temp': 38.89,
#   'Humidity': 87,
#   'Cloudiness': 0,
#   'Wind Speed': 4.61,
#   'Current Description': 'clear sky'},
#  {'City': 'Padang',
#   'Country': 'ID',
#   'Lat': -0.9492,
#   'Lng': 100.3543,
#   'Max Temp': 78.85,
#   'Humidity': 88,
#   'Cloudiness': 100,
#   'Wind Speed': 3.65,
#   'Current Description': 'light rain'},
#  {'City': 'Tabas',
#   'Country': 'IR',
#   'Lat': 33.5959,
#   'Lng': 56.9244,
#   'Max Temp': 82.62,
#   'Humidity': 15,
#   'Cloudiness': 2,
#   'Wind Speed': 13.8,
#   'Current Description': 'clear sky'},
#  {'City': 'Nizhniy Kuranakh',
#   'Country': 'RU',
#   'Lat': 58.8353,
#   'Lng': 125.4869,
#   'Max Temp': 10.6,
#   'Humidity': 96,
#   'Cloudiness': 79,
#   'Wind Speed': 2.8,
#   'Current Description': 'broken clouds'},
#  {'City': 'Omboue',
#   'Country': 'GA',
#   'Lat': -1.5746,
#   'Lng': 9.2618,
#   'Max Temp': 79.38,
#   'Humidity': 81,
#   'Cloudiness': 100,
#   'Wind Speed': 7.02,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Hauterive',
#   'Country': 'FR',
#   'Lat': 46.0901,
#   'Lng': 3.4459,
#   'Max Temp': 61.56,
#   'Humidity': 47,
#   'Cloudiness': 65,
#   'Wind Speed': 4.9,
#   'Current Description': 'broken clouds'},
#  {'City': 'Vostok',
#   'Country': 'RU',
#   'Lat': 46.4856,
#   'Lng': 135.8833,
#   'Max Temp': 29.75,
#   'Humidity': 95,
#   'Cloudiness': 98,
#   'Wind Speed': 5.53,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Synya',
#   'Country': 'RU',
#   'Lat': 65.3718,
#   'Lng': 58.0387,
#   'Max Temp': 39.87,
#   'Humidity': 95,
#   'Cloudiness': 99,
#   'Wind Speed': 10.92,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Zyryanka',
#   'Country': 'RU',
#   'Lat': 65.75,
#   'Lng': 150.85,
#   'Max Temp': -3.24,
#   'Humidity': 98,
#   'Cloudiness': 100,
#   'Wind Speed': 2.89,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Wolfenbuttel',
#   'Country': 'DE',
#   'Lat': 52.1667,
#   'Lng': 10.55,
#   'Max Temp': 47.66,
#   'Humidity': 49,
#   'Cloudiness': 0,
#   'Wind Speed': 13.8,
#   'Current Description': 'clear sky'},
#  {'City': 'Talcahuano',
#   'Country': 'CL',
#   'Lat': -36.7167,
#   'Lng': -73.1167,
#   'Max Temp': 56.88,
#   'Humidity': 67,
#   'Cloudiness': 75,
#   'Wind Speed': 13.8,
#   'Current Description': 'broken clouds'},
#  {'City': 'Northam',
#   'Country': 'GB',
#   'Lat': 51.0333,
#   'Lng': -4.2167,
#   'Max Temp': 52.61,
#   'Humidity': 55,
#   'Cloudiness': 100,
#   'Wind Speed': 18.59,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Kigoma',
#   'Country': 'TZ',
#   'Lat': -4.8769,
#   'Lng': 29.6267,
#   'Max Temp': 77.05,
#   'Humidity': 74,
#   'Cloudiness': 51,
#   'Wind Speed': 7,
#   'Current Description': 'broken clouds'},
#  {'City': 'Vao',
#   'Country': 'NC',
#   'Lat': -22.6667,
#   'Lng': 167.4833,
#   'Max Temp': 77.11,
#   'Humidity': 84,
#   'Cloudiness': 86,
#   'Wind Speed': 21.34,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Saldanha',
#   'Country': 'ZA',
#   'Lat': -33.0117,
#   'Lng': 17.9442,
#   'Max Temp': 80.65,
#   'Humidity': 73,
#   'Cloudiness': 0,
#   'Wind Speed': 8.23,
#   'Current Description': 'clear sky'},
#  {'City': 'Nove Mesto Na Morave',
#   'Country': 'CZ',
#   'Lat': 49.5614,
#   'Lng': 16.0742,
#   'Max Temp': 39.42,
#   'Humidity': 68,
#   'Cloudiness': 79,
#   'Wind Speed': 1.99,
#   'Current Description': 'broken clouds'},
#  {'City': 'Kahului',
#   'Country': 'US',
#   'Lat': 20.8947,
#   'Lng': -156.47,
#   'Max Temp': 75.85,
#   'Humidity': 82,
#   'Cloudiness': 80,
#   'Wind Speed': 11.99,
#   'Current Description': 'broken clouds'},
#  {'City': 'Svetlogorsk',
#   'Country': 'BY',
# ...
#   'Max Temp': 58.73,
#   'Humidity': 21,
#   'Cloudiness': 0,
#   'Wind Speed': 3.83,
#   'Current Description': 'clear sky'},
#  {'City': 'Mpika',
#   'Country': 'ZM',
#   'Lat': -11.8343,
#   'Lng': 31.4529,
#   'Max Temp': 61.52,
#   'Humidity': 99,
#   'Cloudiness': 84,
#   'Wind Speed': 4.5,
#   'Current Description': 'broken clouds'},
#  {'City': 'Caceres',
#   'Country': 'ES',
#   'Lat': 39.522,
#   'Lng': -6.3748,
#   'Max Temp': 72.48,
#   'Humidity': 41,
#   'Cloudiness': 10,
#   'Wind Speed': 14.43,
#   'Current Description': 'clear sky'},
#  {'City': 'Charlestown',
#   'Country': 'AU',
#   'Lat': -32.95,
#   'Lng': 151.6667,
#   'Max Temp': 65.68,
#   'Humidity': 94,
#   'Cloudiness': 1,
#   'Wind Speed': 1.01,
#   'Current Description': 'clear sky'},
#  {'City': 'Geraldton',
#   'Country': 'AU',
#   'Lat': -28.7667,
#   'Lng': 114.6,
#   'Max Temp': 63.01,
#   'Humidity': 88,
#   'Cloudiness': 75,
#   'Wind Speed': 5.75,
#   'Current Description': 'broken clouds'},
#  {'City': 'Flinders',
#   'Country': 'AU',
#   'Lat': -34.5833,
#   'Lng': 150.8552,
#   'Max Temp': 63.37,
#   'Humidity': 91,
#   'Cloudiness': 30,
#   'Wind Speed': 8.01,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Vysokaya Gora',
#   'Country': 'RU',
#   'Lat': 55.9128,
#   'Lng': 49.3017,
#   'Max Temp': 37.58,
#   'Humidity': 100,
#   'Cloudiness': 100,
#   'Wind Speed': 3.22,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Tignere',
#   'Country': 'CM',
#   'Lat': 7.3667,
#   'Lng': 12.65,
#   'Max Temp': 72.07,
#   'Humidity': 67,
#   'Cloudiness': 96,
#   'Wind Speed': 2.89,
#   'Current Description': 'light rain'},
#  {'City': 'Kathu',
#   'Country': 'TH',
#   'Lat': 7.9178,
#   'Lng': 98.3332,
#   'Max Temp': 86.7,
#   'Humidity': 92,
#   'Cloudiness': 74,
#   'Wind Speed': 9.75,
#   'Current Description': 'broken clouds'},
#  {'City': 'Isangel',
#   'Country': 'VU',
#   'Lat': -19.55,
#   'Lng': 169.2667,
#   'Max Temp': 79.23,
#   'Humidity': 86,
#   'Cloudiness': 62,
#   'Wind Speed': 8.01,
#   'Current Description': 'broken clouds'},
#  {'City': 'Yinchuan',
#   'Country': 'CN',
#   'Lat': 38.4681,
#   'Lng': 106.2731,
#   'Max Temp': 63.68,
#   'Humidity': 12,
#   'Cloudiness': 94,
#   'Wind Speed': 19.44,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Oskarshamn',
#   'Country': 'SE',
#   'Lat': 57.2645,
#   'Lng': 16.4484,
#   'Max Temp': 46.98,
#   'Humidity': 55,
#   'Cloudiness': 100,
#   'Wind Speed': 6.6,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Krasnyy Kut',
#   'Country': 'RU',
#   'Lat': 50.95,
#   'Lng': 46.9667,
#   'Max Temp': 56.71,
#   'Humidity': 67,
#   'Cloudiness': 18,
#   'Wind Speed': 6.08,
#   'Current Description': 'few clouds'},
#  {'City': 'Diffa',
#   'Country': 'NE',
#   'Lat': 13.3154,
#   'Lng': 12.6113,
#   'Max Temp': 99.54,
#   'Humidity': 8,
#   'Cloudiness': 32,
#   'Wind Speed': 9.73,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Awash',
#   'Country': 'ET',
#   'Lat': 8.9833,
#   'Lng': 40.1667,
#   'Max Temp': 83.05,
#   'Humidity': 38,
#   'Cloudiness': 31,
#   'Wind Speed': 11.61,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Sorland',
#   'Country': 'NO',
#   'Lat': 67.667,
#   'Lng': 12.6934,
#   'Max Temp': 37.26,
#   'Humidity': 76,
#   'Cloudiness': 99,
#   'Wind Speed': 16.93,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Mocuba',
#   'Country': 'MZ',
#   'Lat': -16.8392,
#   'Lng': 36.9856,
#   'Max Temp': 71.65,
#   'Humidity': 92,
#   'Cloudiness': 17,
#   'Wind Speed': 4.21,
#   'Current Description': 'few clouds'},
#  {'City': 'Labuhan',
#   'Country': 'ID',
#   'Lat': -6.8844,
#   'Lng': 112.2051,
#   'Max Temp': 79.16,
#   'Humidity': 81,
#   'Cloudiness': 86,
#   'Wind Speed': 4.18,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Talakan',
#   'Country': 'RU',
#   'Lat': 50.3167,
#   'Lng': 130.3667,
#   'Max Temp': 34.63,
#   'Humidity': 92,
#   'Cloudiness': 93,
#   'Wind Speed': 7.7,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Biltine',
#   'Country': 'TD',
#   'Lat': 14.5333,
#   'Lng': 20.9167,
#   'Max Temp': 95.52,
#   'Humidity': 11,
#   'Cloudiness': 50,
#   'Wind Speed': 2.68,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Mildura',
#   'Country': 'AU',
#   'Lat': -34.2,
#   'Lng': 142.15,
#   'Max Temp': 67.98,
#   'Humidity': 47,
#   'Cloudiness': 41,
#   'Wind Speed': 8.59,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Boa Vista',
#   'Country': 'BR',
#   'Lat': 2.8197,
#   'Lng': -60.6733,
#   'Max Temp': 85.98,
#   'Humidity': 62,
#   'Cloudiness': 75,
#   'Wind Speed': 10.36,
#   'Current Description': 'broken clouds'},
#  {'City': 'Nome',
#   'Country': 'US',
#   'Lat': 64.5011,
#   'Lng': -165.4064,
#   'Max Temp': 28.47,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 13.8,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Zafra',
#   'Country': 'ES',
#   'Lat': 38.4167,
#   'Lng': -6.4167,
#   'Max Temp': 70.09,
#   'Humidity': 40,
#   'Cloudiness': 32,
#   'Wind Speed': 17.25,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Montrose',
#   'Country': 'US',
#   'Lat': 38.4166,
#   'Lng': -108.2673,
#   'Max Temp': 35.44,
#   'Humidity': 28,
#   'Cloudiness': 61,
#   'Wind Speed': 6.44,
#   'Current Description': 'broken clouds'},
#  {'City': 'Banda Aceh',
#   'Country': 'ID',
#   'Lat': 5.5577,
#   'Lng': 95.3222,
#   'Max Temp': 80.76,
#   'Humidity': 78,
#   'Cloudiness': 79,
#   'Wind Speed': 1.41,
#   'Current Description': 'broken clouds'},
#  {'City': 'Beaumont',
#   'Country': 'US',
#   'Lat': 30.0861,
#   'Lng': -94.1019,
#   'Max Temp': 78.84,
#   'Humidity': 55,
#   'Cloudiness': 75,
#   'Wind Speed': 27.63,
#   'Current Description': 'broken clouds'},
#  {'City': 'Sillod',
#   'Country': 'IN',
#   'Lat': 20.3,
#   'Lng': 75.65,
#   'Max Temp': 89.33,
#   'Humidity': 19,
#   'Cloudiness': 39,
#   'Wind Speed': 8.68,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Jinchang',
#   'Country': 'CN',
#   'Lat': 38.4953,
#   'Lng': 102.1739,
#   'Max Temp': 48.02,
#   'Humidity': 29,
#   'Cloudiness': 91,
#   'Wind Speed': 18.88,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Kuruman',
#   'Country': 'ZA',
#   'Lat': -27.4524,
#   'Lng': 23.4325,
#   'Max Temp': 54.99,
#   'Humidity': 84,
#   'Cloudiness': 100,
#   'Wind Speed': 10.6,
#   'Current Description': 'light rain'},
#  {'City': 'Yar-Sale',
#   'Country': 'RU',
#   'Lat': 66.8333,
#   'Lng': 70.8333,
#   'Max Temp': 32.9,
#   'Humidity': 100,
#   'Cloudiness': 100,
#   'Wind Speed': 8.28,
#   'Current Description': 'light snow'},
#  {'City': 'Ville-Marie',
#   'Country': 'CA',
#   'Lat': 47.3335,
#   'Lng': -79.433,
#   'Max Temp': 32.81,
#   'Humidity': 74,
#   'Cloudiness': 99,
#   'Wind Speed': 8.77,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Tete',
#   'Country': 'MZ',
#   'Lat': -16.1564,
#   'Lng': 33.5867,
#   'Max Temp': 78.89,
#   'Humidity': 83,
#   'Cloudiness': 75,
#   'Wind Speed': 3.44,
#   'Current Description': 'broken clouds'},
#  {'City': 'Dhanera',
#   'Country': 'IN',
#   'Lat': 24.5167,
#   'Lng': 72.0167,
#   'Max Temp': 85.91,
#   'Humidity': 15,
#   'Cloudiness': 80,
#   'Wind Speed': 6.89,
#   'Current Description': 'broken clouds'},
#  {'City': 'Eyl',
#   'Country': 'SO',
#   'Lat': 7.9803,
#   'Lng': 49.8164,
#   'Max Temp': 81.59,
#   'Humidity': 77,
#   'Cloudiness': 4,
#   'Wind Speed': 12.5,
#   'Current Description': 'clear sky'},
#  {'City': 'Port Macquarie',
#   'Country': 'AU',
#   'Lat': -31.4333,
#   'Lng': 152.9167,
#   'Max Temp': 62.89,
#   'Humidity': 92,
#   'Cloudiness': 9,
#   'Wind Speed': 5.01,
#   'Current Description': 'clear sky'},
#  {'City': 'Saint-Pierre',
#   'Country': 'RE',
#   'Lat': -21.3393,
#   'Lng': 55.4781,
#   'Max Temp': 78.48,
#   'Humidity': 82,
#   'Cloudiness': 100,
#   'Wind Speed': 19.57,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Huarmey',
#   'Country': 'PE',
#   'Lat': -10.0681,
#   'Lng': -78.1522,
#   'Max Temp': 73.78,
#   'Humidity': 76,
#   'Cloudiness': 42,
#   'Wind Speed': 11.59,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Mukhen',
#   'Country': 'RU',
#   'Lat': 48.1,
#   'Lng': 136.1,
#   'Max Temp': 36.21,
#   'Humidity': 93,
#   'Cloudiness': 85,
#   'Wind Speed': 3.49,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Mayo',
#   'Country': 'US',
#   'Lat': 38.8876,
#   'Lng': -76.5119,
#   'Max Temp': 50.67,
#   'Humidity': 49,
#   'Cloudiness': 100,
#   'Wind Speed': 23,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Strezhevoy',
#   'Country': 'RU',
#   'Lat': 60.7333,
#   'Lng': 77.5889,
#   'Max Temp': 11.01,
#   'Humidity': 90,
#   'Cloudiness': 94,
#   'Wind Speed': 4.65,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Haines Junction',
#   'Country': 'CA',
#   'Lat': 60.7522,
#   'Lng': -137.5108,
#   'Max Temp': 14.85,
#   'Humidity': 78,
#   'Cloudiness': 64,
#   'Wind Speed': 4.94,
#   'Current Description': 'broken clouds'},
#  {'City': 'Harnosand',
#   'Country': 'SE',
#   'Lat': 62.6323,
#   'Lng': 17.9379,
#   'Max Temp': 41,
#   'Humidity': 78,
#   'Cloudiness': 100,
#   'Wind Speed': 23.22,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Talas',
#   'Country': 'TR',
#   'Lat': 38.6908,
#   'Lng': 35.5538,
#   'Max Temp': 54.27,
#   'Humidity': 58,
#   'Cloudiness': 20,
#   'Wind Speed': 2.3,
#   'Current Description': 'few clouds'},
#  {'City': 'Pochutla',
#   'Country': 'MX',
#   'Lat': 15.7432,
#   'Lng': -96.4661,
#   'Max Temp': 89.82,
#   'Humidity': 37,
#   'Cloudiness': 7,
#   'Wind Speed': 7.36,
#   'Current Description': 'clear sky'},
#  {'City': 'Hanzhong',
#   'Country': 'CN',
#   'Lat': 33.0728,
#   'Lng': 107.0303,
#   'Max Temp': 65.34,
#   'Humidity': 66,
#   'Cloudiness': 5,
#   'Wind Speed': 0.58,
#   'Current Description': 'clear sky'},
#  {'City': 'Koslan',
#   'Country': 'RU',
#   'Lat': 63.4564,
#   'Lng': 48.8989,
#   'Max Temp': 38.01,
#   'Humidity': 98,
#   'Cloudiness': 100,
#   'Wind Speed': 11.23,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Shelburne',
#   'Country': 'CA',
#   'Lat': 44.0787,
#   'Lng': -80.2041,
#   'Max Temp': 40.12,
#   'Humidity': 74,
#   'Cloudiness': 98,
#   'Wind Speed': 14.09,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Buchanan',
#   'Country': 'LR',
#   'Lat': 5.8808,
#   'Lng': -10.0467,
#   'Max Temp': 84.56,
#   'Humidity': 66,
#   'Cloudiness': 36,
#   'Wind Speed': 8.79,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Novo Aripuana',
#   'Country': 'BR',
#   'Lat': -5.1206,
#   'Lng': -60.3797,
#   'Max Temp': 82.36,
#   'Humidity': 89,
#   'Cloudiness': 99,
#   'Wind Speed': 4.34,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Neuquen',
#   'Country': 'AR',
#   'Lat': -38.9516,
#   'Lng': -68.0591,
#   'Max Temp': 58.89,
#   'Humidity': 55,
#   'Cloudiness': 75,
#   'Wind Speed': 6.91,
#   'Current Description': 'broken clouds'},
#  {'City': 'Motala',
#   'Country': 'SE',
#   'Lat': 58.5371,
#   'Lng': 15.0365,
#   'Max Temp': 47.97,
#   'Humidity': 67,
#   'Cloudiness': 79,
#   'Wind Speed': 5.48,
#   'Current Description': 'broken clouds'},
#  {'City': 'Kampot',
#   'Country': 'KH',
#   'Lat': 10.6167,
#   'Lng': 104.1833,
#   'Max Temp': 77.05,
#   'Humidity': 81,
#   'Cloudiness': 97,
#   'Wind Speed': 5.95,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Mezen',
#   'Country': 'RU',
#   'Lat': 65.8522,
#   'Lng': 44.24,
#   'Max Temp': 38.34,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 13.47,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Rumonge',
#   'Country': 'BI',
#   'Lat': -3.9736,
#   'Lng': 29.4386,
#   'Max Temp': 74.37,
#   'Humidity': 80,
#   'Cloudiness': 9,
#   'Wind Speed': 3.94,
#   'Current Description': 'clear sky'},
#  {'City': 'Puri',
#   'Country': 'IN',
#   'Lat': 19.8,
#   'Lng': 85.85,
#   'Max Temp': 82.92,
#   'Humidity': 87,
#   'Cloudiness': 13,
#   'Wind Speed': 22.97,
#   'Current Description': 'few clouds'},
#  {'City': 'Tigil',
#   'Country': 'RU',
#   'Lat': 57.8,
#   'Lng': 158.6667,
#   'Max Temp': 4.46,
#   'Humidity': 99,
#   'Cloudiness': 68,
#   'Wind Speed': 3.51,
#   'Current Description': 'broken clouds'},
#  {'City': 'Saint-Augustin',
#   'Country': 'CA',
#   'Lat': 51.226,
#   'Lng': -58.6502,
#   'Max Temp': 35.62,
#   'Humidity': 100,
#   'Cloudiness': 100,
#   'Wind Speed': 5.64,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Goundam',
#   'Country': 'ML',
#   'Lat': 16.4145,
#   'Lng': -3.6708,
#   'Max Temp': 104.41,
#   'Humidity': 6,
#   'Cloudiness': 1,
#   'Wind Speed': 8.05,
#   'Current Description': 'clear sky'},
#  {'City': 'Sinazongwe',
#   'Country': 'ZM',
#   'Lat': -17.2614,
#   'Lng': 27.4618,
#   'Max Temp': 74.34,
#   'Humidity': 77,
#   'Cloudiness': 100,
#   'Wind Speed': 1.92,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Gasa',
#   'Country': 'PS',
#   'Lat': 31.5,
#   'Lng': 34.4667,
#   'Max Temp': 64.89,
#   'Humidity': 82,
#   'Cloudiness': 19,
#   'Wind Speed': 9.06,
#   'Current Description': 'few clouds'},
#  {'City': 'Emet',
#   'Country': 'TR',
#   'Lat': 39.343,
#   'Lng': 29.2585,
#   'Max Temp': 55,
#   'Humidity': 47,
#   'Cloudiness': 2,
#   'Wind Speed': 11.72,
#   'Current Description': 'clear sky'},
#  {'City': 'Nelson Bay',
#   'Country': 'AU',
#   'Lat': -32.7167,
#   'Lng': 152.15,
#   'Max Temp': 64,
#   'Humidity': 96,
#   'Cloudiness': 6,
#   'Wind Speed': 6.22,
#   'Current Description': 'clear sky'},
#  {'City': 'Agirish',
#   'Country': 'RU',
#   'Lat': 61.9247,
#   'Lng': 63.0231,
#   'Max Temp': 37.29,
#   'Humidity': 99,
#   'Cloudiness': 100,
#   'Wind Speed': 9.46,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Camacha',
#   'Country': 'PT',
#   'Lat': 33.0833,
#   'Lng': -16.3333,
#   'Max Temp': 62.02,
#   'Humidity': 77,
#   'Cloudiness': 40,
#   'Wind Speed': 18.41,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Pasighat',
#   'Country': 'IN',
#   'Lat': 28.0667,
#   'Lng': 95.3333,
#   'Max Temp': 70.11,
#   'Humidity': 94,
#   'Cloudiness': 97,
#   'Wind Speed': 4.38,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Reconquista',
#   'Country': 'AR',
#   'Lat': -29.15,
#   'Lng': -59.65,
#   'Max Temp': 72.01,
#   'Humidity': 93,
#   'Cloudiness': 90,
#   'Wind Speed': 6.96,
#   'Current Description': 'moderate rain'},
#  {'City': 'Port Hawkesbury',
#   'Country': 'CA',
#   'Lat': 45.6169,
#   'Lng': -61.3485,
#   'Max Temp': 42.96,
#   'Humidity': 99,
#   'Cloudiness': 100,
#   'Wind Speed': 1.01,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Novyy Urengoy',
#   'Country': 'RU',
#   'Lat': 66.0833,
#   'Lng': 76.6333,
#   'Max Temp': 24.01,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 12.95,
#   'Current Description': 'light snow'},
#  {'City': 'Gushikawa',
#   'Country': 'JP',
#   'Lat': 26.3544,
#   'Lng': 127.8686,
#   'Max Temp': 72.99,
#   'Humidity': 91,
#   'Cloudiness': 75,
#   'Wind Speed': 13.8,
#   'Current Description': 'broken clouds'},
#  {'City': 'Palmaner',
#   'Country': 'IN',
#   'Lat': 13.2,
#   'Lng': 78.75,
#   'Max Temp': 75.83,
#   'Humidity': 78,
#   'Cloudiness': 99,
#   'Wind Speed': 8.23,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Srandakan',
#   'Country': 'ID',
#   'Lat': -7.9386,
#   'Lng': 110.2506,
#   'Max Temp': 76.6,
#   'Humidity': 88,
#   'Cloudiness': 97,
#   'Wind Speed': 3.4,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Olinda',
#   'Country': 'BR',
#   'Lat': -8.0089,
#   'Lng': -34.8553,
#   'Max Temp': 83.93,
#   'Humidity': 74,
#   'Cloudiness': 40,
#   'Wind Speed': 13.8,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Mimongo',
#   'Country': 'GA',
#   'Lat': -1.6195,
#   'Lng': 11.6068,
#   'Max Temp': 76.64,
#   'Humidity': 82,
#   'Cloudiness': 85,
#   'Wind Speed': 4.79,
#   'Current Description': 'light rain'},
#  {'City': 'Ulaangom',
#   'Country': 'MN',
#   'Lat': 49.9811,
#   'Lng': 92.0667,
#   'Max Temp': 35.71,
#   'Humidity': 38,
#   'Cloudiness': 54,
#   'Wind Speed': 11.99,
#   'Current Description': 'broken clouds'},
#  {'City': 'Bom Jesus',
#   'Country': 'BR',
#   'Lat': -9.0744,
#   'Lng': -44.3586,
#   'Max Temp': 100.22,
#   'Humidity': 25,
#   'Cloudiness': 36,
#   'Wind Speed': 0.76,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Darab',
#   'Country': 'IR',
#   'Lat': 28.7519,
#   'Lng': 54.5444,
#   'Max Temp': 71.4,
#   'Humidity': 13,
#   'Cloudiness': 0,
#   'Wind Speed': 3.87,
#   'Current Description': 'clear sky'},
#  {'City': 'Zhuanghe',
#   'Country': 'CN',
#   'Lat': 39.7008,
#   'Lng': 122.9911,
#   'Max Temp': 46.99,
#   'Humidity': 92,
#   'Cloudiness': 54,
#   'Wind Speed': 12.93,
#   'Current Description': 'broken clouds'},
#  {'City': 'Mulege',
#   'Country': 'MX',
#   'Lat': 26.8833,
#   'Lng': -111.9833,
#   'Max Temp': 79.81,
#   'Humidity': 29,
#   'Cloudiness': 7,
#   'Wind Speed': 4.27,
#   'Current Description': 'clear sky'},
#  {'City': 'Calama',
#   'Country': 'CL',
#   'Lat': -22.4667,
#   'Lng': -68.9333,
#   'Max Temp': 72.09,
#   'Humidity': 14,
#   'Cloudiness': 0,
#   'Wind Speed': 16.11,
#   'Current Description': 'clear sky'}]

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Avarua      CK -21.2078 -159.7750     77.05        94          97
# 1        Berlevag      NO  70.8578   29.0864     37.40        87          44
# 2          Kodiak      US  57.7900 -152.4072     33.31        47           0
# 3          Laguna      US  38.4210 -121.4238     64.15        26           0
# 4    San Jeronimo      PE -11.9472  -75.2829     56.88        63          99
# 5      Bredasdorp      ZA -34.5322   20.0403     64.94        86           0
# 6     Cherepanovo      RU  54.2222   83.3810     17.06        96          51
# 7         Iqaluit      CA  63.7506  -68.5145     26.33        79         100
# 8           Mayya      RU  61.7333  130.2811     20.52        93         100
# 9  Severo-Kurilsk      RU  50.6789  156.1250     29.70        78          98
#
#    Wind Speed Current Description
# 0        2.30     overcast clouds
# 1       16.46    scattered clouds
# 2        8.05           clear sky
# 3       16.11           clear sky
# 4        0.38     overcast clouds
# 5       14.61           clear sky
# 6        4.83       broken clouds
# 7        2.30          light snow
# 8        4.68     overcast clouds
# 9       17.76     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
