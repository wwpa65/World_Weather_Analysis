# %%
# Import the random module.
import random
# Import the NumPy module.
import numpy as np
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import requests
from citipy import citipy
from config import weather_api_key
import time
from datetime import datetime

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 728

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=31796aa84bcbb3cbeeb51914e16b61e6

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    

    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        city_description = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | ushuaia
# Processing Record 2 of Set 1 | jamestown
# Processing Record 3 of Set 1 | rikitea
# Processing Record 4 of Set 1 | cabo san lucas
# Processing Record 5 of Set 1 | avarua
# Processing Record 6 of Set 1 | camabatela
# Processing Record 7 of Set 1 | padang
# Processing Record 8 of Set 1 | albany
# Processing Record 9 of Set 1 | bredasdorp
# Processing Record 10 of Set 1 | aklavik
# Processing Record 11 of Set 1 | prata
# Processing Record 12 of Set 1 | hithadhoo
# Processing Record 13 of Set 1 | bengkulu
# Processing Record 14 of Set 1 | hermanus
# Processing Record 15 of Set 1 | kaeo
# Processing Record 16 of Set 1 | butaritari
# Processing Record 17 of Set 1 | hobart
# Processing Record 18 of Set 1 | bethel
# Processing Record 19 of Set 1 | port blair
# Processing Record 20 of Set 1 | ribeira grande
# Processing Record 21 of Set 1 | porto velho
# Processing Record 22 of Set 1 | punta arenas
# Processing Record 23 of Set 1 | chakrata
# Processing Record 24 of Set 1 | mocuba
# Processing Record 25 of Set 1 | hilo
# Processing Record 26 of Set 1 | lockport
# Processing Record 27 of Set 1 | acapulco
# Processing Record 28 of Set 1 | faya
# Processing Record 29 of Set 1 | bambanglipuro
# Processing Record 30 of Set 1 | halalo
# City not found. Skipping...
# Processing Record 31 of Set 1 | singaraja
# Processing Record 32 of Set 1 | rabo de peixe
# Processing Record 33 of Set 1 | busselton
# Processing Record 34 of Set 1 | cape town
# Processing Record 35 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 36 of Set 1 | narsaq
# Processing Record 37 of Set 1 | vaini
# Processing Record 38 of Set 1 | karangampel
# Processing Record 39 of Set 1 | qaanaaq
# Processing Record 40 of Set 1 | galich
# Processing Record 41 of Set 1 | tual
# Processing Record 42 of Set 1 | boa vista
# Processing Record 43 of Set 1 | chuy
# Processing Record 44 of Set 1 | sola
# Processing Record 45 of Set 1 | tahoua
# Processing Record 46 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 47 of Set 1 | morondava
# Processing Record 48 of Set 1 | pacific grove
# Processing Record 49 of Set 1 | nanortalik
# Processing Record 50 of Set 1 | mataura
# Processing Record 1 of Set 2 | moranbah
# Processing Record 2 of Set 2 | dorchester
# Processing Record 3 of Set 2 | kahului
# Processing Record 4 of Set 2 | puerto escondido
# Processing Record 5 of Set 2 | port alfred
# Processing Record 6 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 7 of Set 2 | port elizabeth
# Processing Record 8 of Set 2 | arraial do cabo
# Processing Record 9 of Set 2 | fortuna
# Processing Record 10 of Set 2 | saint-augustin
# Processing Record 11 of Set 2 | east london
# Processing Record 12 of Set 2 | husavik
# Processing Record 13 of Set 2 | norman wells
# Processing Record 14 of Set 2 | katobu
# Processing Record 15 of Set 2 | yellowknife
# Processing Record 16 of Set 2 | vestmannaeyjar
# Processing Record 17 of Set 2 | castro
# Processing Record 18 of Set 2 | sandwick
# Processing Record 19 of Set 2 | kamina
# Processing Record 20 of Set 2 | bilma
# Processing Record 21 of Set 2 | nikolskoye
# Processing Record 22 of Set 2 | mahebourg
# Processing Record 23 of Set 2 | daru
# Processing Record 24 of Set 2 | luchegorsk
# Processing Record 25 of Set 2 | ustka
# Processing Record 26 of Set 2 | arawa
# Processing Record 27 of Set 2 | barrow
# Processing Record 28 of Set 2 | almaznyy
# Processing Record 29 of Set 2 | nouadhibou
# Processing Record 30 of Set 2 | kapaa
# Processing Record 31 of Set 2 | miguel alves
# Processing Record 32 of Set 2 | clyde river
# Processing Record 33 of Set 2 | puerto ayora
# Processing Record 34 of Set 2 | provideniya
# Processing Record 35 of Set 2 | vranestica
# Processing Record 36 of Set 2 | phan rang
# City not found. Skipping...
# Processing Record 37 of Set 2 | hearst
# Processing Record 38 of Set 2 | arman
# Processing Record 39 of Set 2 | eseka
# Processing Record 40 of Set 2 | lhuntshi
# City not found. Skipping...
# Processing Record 41 of Set 2 | hambantota
# Processing Record 42 of Set 2 | mount isa
# Processing Record 43 of Set 2 | isangel
# Processing Record 44 of Set 2 | san carlos de bariloche
# Processing Record 45 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 46 of Set 2 | tuatapere
# Processing Record 47 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 48 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 49 of Set 2 | miramar
# Processing Record 50 of Set 2 | sayyan
# Processing Record 1 of Set 3 | bluff
# Processing Record 2 of Set 3 | bambous virieux
# Processing Record 3 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 4 of Set 3 | palana
# Processing Record 5 of Set 3 | lazaro cardenas
# Processing Record 6 of Set 3 | seoul
# Processing Record 7 of Set 3 | bilibino
# Processing Record 8 of Set 3 | gusau
# Processing Record 9 of Set 3 | mehamn
# Processing Record 10 of Set 3 | sitka
# Processing Record 11 of Set 3 | miquelon
# Processing Record 12 of Set 3 | nokaneng
# Processing Record 13 of Set 3 | kloulklubed
# Processing Record 14 of Set 3 | igarka
# Processing Record 15 of Set 3 | new norfolk
# Processing Record 16 of Set 3 | jacareacanga
# Processing Record 17 of Set 3 | bababe
# City not found. Skipping...
# Processing Record 18 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 19 of Set 3 | torbay
# Processing Record 20 of Set 3 | sorland
# Processing Record 21 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 22 of Set 3 | batsfjord
# Processing Record 23 of Set 3 | aswan
# Processing Record 24 of Set 3 | skibbereen
# Processing Record 25 of Set 3 | jalu
# Processing Record 26 of Set 3 | tanout
# Processing Record 27 of Set 3 | sioux lookout
# Processing Record 28 of Set 3 | alice springs
# Processing Record 29 of Set 3 | launceston
# Processing Record 30 of Set 3 | tasiilaq
# Processing Record 31 of Set 3 | petropavlovsk-kamchatskiy
# Processing Record 32 of Set 3 | esperance
# Processing Record 33 of Set 3 | hamilton
# Processing Record 34 of Set 3 | schwerin
# Processing Record 35 of Set 3 | poum
# Processing Record 36 of Set 3 | hudson bay
# Processing Record 37 of Set 3 | outlook
# Processing Record 38 of Set 3 | ancud
# Processing Record 39 of Set 3 | faanui
# Processing Record 40 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 41 of Set 3 | hami
# Processing Record 42 of Set 3 | katsuura
# Processing Record 43 of Set 3 | erenhot
# Processing Record 44 of Set 3 | yulara
# Processing Record 45 of Set 3 | carman
# Processing Record 46 of Set 3 | sao miguel do oeste
# City not found. Skipping...
# Processing Record 47 of Set 3 | karratha
# Processing Record 48 of Set 3 | phayakkhaphum phisai
# Processing Record 49 of Set 3 | georgetown
# Processing Record 50 of Set 3 | ponta do sol
# Processing Record 1 of Set 4 | vytegra
# Processing Record 2 of Set 4 | balaguer
# Processing Record 3 of Set 4 | new waterford
# Processing Record 4 of Set 4 | pisco
# Processing Record 5 of Set 4 | arantangi
# Processing Record 6 of Set 4 | yingshang
# City not found. Skipping...
# Processing Record 7 of Set 4 | tuktoyaktuk
# Processing Record 8 of Set 4 | paamiut
# Processing Record 9 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 10 of Set 4 | terrace
# Processing Record 11 of Set 4 | mayumba
# Processing Record 12 of Set 4 | ulaangom
# Processing Record 13 of Set 4 | cherskiy
# Processing Record 14 of Set 4 | sao joao da barra
# Processing Record 15 of Set 4 | asau
# Processing Record 16 of Set 4 | fushun
# Processing Record 17 of Set 4 | ilulissat
# Processing Record 18 of Set 4 | brae
# Processing Record 19 of Set 4 | vostok
# Processing Record 20 of Set 4 | thompson
# Processing Record 21 of Set 4 | dekoa
# City not found. Skipping...
# Processing Record 22 of Set 4 | san cristobal
# Processing Record 23 of Set 4 | liverpool
# Processing Record 24 of Set 4 | ruatoria
# City not found. Skipping...
# Processing Record 25 of Set 4 | tolaga bay
# Processing Record 26 of Set 4 | bani
# Processing Record 27 of Set 4 | kaitangata
# Processing Record 28 of Set 4 | hasaki
# Processing Record 29 of Set 4 | zharkent
# Processing Record 30 of Set 4 | palmer
# Processing Record 31 of Set 4 | nizwa
# Processing Record 32 of Set 4 | kavieng
# Processing Record 33 of Set 4 | vardo
# Processing Record 34 of Set 4 | san rafael del sur
# Processing Record 35 of Set 4 | qaqortoq
# Processing Record 36 of Set 4 | babanusah
# City not found. Skipping...
# Processing Record 37 of Set 4 | palu
# Processing Record 38 of Set 4 | moron
# Processing Record 39 of Set 4 | keningau
# Processing Record 40 of Set 4 | saint anthony
# Processing Record 41 of Set 4 | sarlat-la-caneda
# Processing Record 42 of Set 4 | kyra
# Processing Record 43 of Set 4 | tessalit
# Processing Record 44 of Set 4 | geraldton
# Processing Record 45 of Set 4 | airai
# Processing Record 46 of Set 4 | chokurdakh
# Processing Record 47 of Set 4 | lompoc
# Processing Record 48 of Set 4 | kununurra
# Processing Record 49 of Set 4 | ambilobe
# Processing Record 50 of Set 4 | beloha
# Processing Record 1 of Set 5 | kirakira
# Processing Record 2 of Set 5 | gangotri
# City not found. Skipping...
# Processing Record 3 of Set 5 | awassa
# Processing Record 4 of Set 5 | poltavka
# Processing Record 5 of Set 5 | mogadishu
# Processing Record 6 of Set 5 | kars
# Processing Record 7 of Set 5 | abu kamal
# Processing Record 8 of Set 5 | miri
# Processing Record 9 of Set 5 | mayo
# Processing Record 10 of Set 5 | upernavik
# Processing Record 11 of Set 5 | simao
# Processing Record 12 of Set 5 | darnah
# Processing Record 13 of Set 5 | vila do maio
# Processing Record 14 of Set 5 | ampanihy
# Processing Record 15 of Set 5 | shitanjing
# Processing Record 16 of Set 5 | yichun
# Processing Record 17 of Set 5 | severnyy
# Processing Record 18 of Set 5 | dongli
# Processing Record 19 of Set 5 | atuona
# Processing Record 20 of Set 5 | zhangye
# Processing Record 21 of Set 5 | buerarema
# Processing Record 22 of Set 5 | mont-dore
# Processing Record 23 of Set 5 | athabasca
# Processing Record 24 of Set 5 | luderitz
# Processing Record 25 of Set 5 | dikson
# Processing Record 26 of Set 5 | verkhnevilyuysk
# Processing Record 27 of Set 5 | ostrovnoy
# Processing Record 28 of Set 5 | ocala
# Processing Record 29 of Set 5 | vilyuysk
# Processing Record 30 of Set 5 | labuhan
# Processing Record 31 of Set 5 | saint george
# Processing Record 32 of Set 5 | inuvik
# Processing Record 33 of Set 5 | vila franca do campo
# Processing Record 34 of Set 5 | hwange
# Processing Record 35 of Set 5 | krasnyy yar
# Processing Record 36 of Set 5 | grand gaube
# Processing Record 37 of Set 5 | caravelas
# Processing Record 38 of Set 5 | formoso do araguaia
# City not found. Skipping...
# Processing Record 39 of Set 5 | sonqar
# City not found. Skipping...
# Processing Record 40 of Set 5 | mar del plata
# Processing Record 41 of Set 5 | port-gentil
# Processing Record 42 of Set 5 | kavaratti
# Processing Record 43 of Set 5 | okhotsk
# Processing Record 44 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 45 of Set 5 | talnakh
# Processing Record 46 of Set 5 | coihaique
# Processing Record 47 of Set 5 | ratnagiri
# Processing Record 48 of Set 5 | maceio
# Processing Record 49 of Set 5 | heihe
# Processing Record 50 of Set 5 | tocopilla
# Processing Record 1 of Set 6 | port hueneme
# Processing Record 2 of Set 6 | bathsheba
# Processing Record 3 of Set 6 | bose
# Processing Record 4 of Set 6 | kongolo
# Processing Record 5 of Set 6 | omboue
# Processing Record 6 of Set 6 | peniche
# Processing Record 7 of Set 6 | north bend
# Processing Record 8 of Set 6 | alanya
# Processing Record 9 of Set 6 | vila
# Processing Record 10 of Set 6 | salalah
# Processing Record 11 of Set 6 | maralal
# Processing Record 12 of Set 6 | arlit
# Processing Record 13 of Set 6 | mecca
# Processing Record 14 of Set 6 | nerja
# Processing Record 15 of Set 6 | christchurch
# Processing Record 16 of Set 6 | diamantino
# Processing Record 17 of Set 6 | rock springs
# Processing Record 18 of Set 6 | moerai
# Processing Record 19 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 20 of Set 6 | port hedland
# Processing Record 21 of Set 6 | cleethorpes
# Processing Record 22 of Set 6 | kot samaba
# Processing Record 23 of Set 6 | sao marcos
# Processing Record 24 of Set 6 | yar-sale
# Processing Record 25 of Set 6 | bubaque
# Processing Record 26 of Set 6 | xapuri
# Processing Record 27 of Set 6 | guozhen
# Processing Record 28 of Set 6 | kytlym
# City not found. Skipping...
# Processing Record 29 of Set 6 | constitucion
# Processing Record 30 of Set 6 | cody
# Processing Record 31 of Set 6 | victoria
# Processing Record 32 of Set 6 | beaumont
# Processing Record 33 of Set 6 | george town
# Processing Record 34 of Set 6 | kodiak
# Processing Record 35 of Set 6 | evanston
# Processing Record 36 of Set 6 | carnarvon
# Processing Record 37 of Set 6 | balabac
# Processing Record 38 of Set 6 | valley station
# Processing Record 39 of Set 6 | osmena
# Processing Record 40 of Set 6 | najran
# Processing Record 41 of Set 6 | margate
# Processing Record 42 of Set 6 | lodwar
# Processing Record 43 of Set 6 | karakol
# Processing Record 44 of Set 6 | solnechnyy
# Processing Record 45 of Set 6 | nishihara
# Processing Record 46 of Set 6 | coromandel
# Processing Record 47 of Set 6 | koungheul
# Processing Record 48 of Set 6 | bonthe
# Processing Record 49 of Set 6 | waingapu
# Processing Record 50 of Set 6 | eureka
# Processing Record 1 of Set 7 | warka
# Processing Record 2 of Set 7 | souillac
# Processing Record 3 of Set 7 | hudiksvall
# Processing Record 4 of Set 7 | payakumbuh
# Processing Record 5 of Set 7 | elmira
# Processing Record 6 of Set 7 | adrar
# Processing Record 7 of Set 7 | bargal
# City not found. Skipping...
# Processing Record 8 of Set 7 | altamira
# Processing Record 9 of Set 7 | ukiah
# Processing Record 10 of Set 7 | vila velha
# Processing Record 11 of Set 7 | lolua
# City not found. Skipping...
# Processing Record 12 of Set 7 | nara
# Processing Record 13 of Set 7 | aljezur
# Processing Record 14 of Set 7 | akividu
# Processing Record 15 of Set 7 | karkaralinsk
# City not found. Skipping...
# Processing Record 16 of Set 7 | ust-maya
# Processing Record 17 of Set 7 | laguna
# Processing Record 18 of Set 7 | tiksi
# Processing Record 19 of Set 7 | dodge city
# Processing Record 20 of Set 7 | sokoni
# Processing Record 21 of Set 7 | kulu
# Processing Record 22 of Set 7 | ibra
# Processing Record 23 of Set 7 | shibetsu
# Processing Record 24 of Set 7 | saskylakh
# Processing Record 25 of Set 7 | talavera de la reina
# Processing Record 26 of Set 7 | iqaluit
# Processing Record 27 of Set 7 | san patricio
# Processing Record 28 of Set 7 | shingu
# Processing Record 29 of Set 7 | lamar
# Processing Record 30 of Set 7 | betioky
# Processing Record 31 of Set 7 | dudinka
# Processing Record 32 of Set 7 | nemuro
# Processing Record 33 of Set 7 | ambovombe
# Processing Record 34 of Set 7 | san policarpo
# Processing Record 35 of Set 7 | prainha
# Processing Record 36 of Set 7 | aguimes
# Processing Record 37 of Set 7 | madhogarh
# Processing Record 38 of Set 7 | half moon bay
# Processing Record 39 of Set 7 | lagoa
# Processing Record 40 of Set 7 | iralaya
# Processing Record 41 of Set 7 | nouakchott
# Processing Record 42 of Set 7 | chirongui
# Processing Record 43 of Set 7 | aizpute
# Processing Record 44 of Set 7 | necochea
# Processing Record 45 of Set 7 | dunda
# Processing Record 46 of Set 7 | marovoay
# Processing Record 47 of Set 7 | bismil
# Processing Record 48 of Set 7 | khatanga
# Processing Record 49 of Set 7 | gushikawa
# Processing Record 50 of Set 7 | fairbanks
# Processing Record 1 of Set 8 | saint-joseph
# Processing Record 2 of Set 8 | iquique
# Processing Record 3 of Set 8 | karaul
# City not found. Skipping...
# Processing Record 4 of Set 8 | komsomolskiy
# Processing Record 5 of Set 8 | peleduy
# Processing Record 6 of Set 8 | port lincoln
# Processing Record 7 of Set 8 | viramgam
# Processing Record 8 of Set 8 | gat
# Processing Record 9 of Set 8 | yining
# Processing Record 10 of Set 8 | zhongshu
# Processing Record 11 of Set 8 | sinnamary
# Processing Record 12 of Set 8 | hartford
# Processing Record 13 of Set 8 | mantua
# Processing Record 14 of Set 8 | nguiu
# City not found. Skipping...
# Processing Record 15 of Set 8 | luena
# Processing Record 16 of Set 8 | thunder bay
# Processing Record 17 of Set 8 | longyearbyen
# Processing Record 18 of Set 8 | deputatskiy
# Processing Record 19 of Set 8 | namatanai
# Processing Record 20 of Set 8 | hihifo
# City not found. Skipping...
# Processing Record 21 of Set 8 | thinadhoo
# Processing Record 22 of Set 8 | camacha
# Processing Record 23 of Set 8 | lorengau
# Processing Record 24 of Set 8 | rungata
# City not found. Skipping...
# Processing Record 25 of Set 8 | eyl
# Processing Record 26 of Set 8 | marsh harbour
# Processing Record 27 of Set 8 | tadine
# Processing Record 28 of Set 8 | alyangula
# Processing Record 29 of Set 8 | sindou
# Processing Record 30 of Set 8 | biak
# Processing Record 31 of Set 8 | vestbygda
# City not found. Skipping...
# Processing Record 32 of Set 8 | naze
# Processing Record 33 of Set 8 | waipawa
# Processing Record 34 of Set 8 | yatou
# Processing Record 35 of Set 8 | srednekolymsk
# Processing Record 36 of Set 8 | ahipara
# Processing Record 37 of Set 8 | cobija
# Processing Record 38 of Set 8 | havelock
# Processing Record 39 of Set 8 | dolgoye
# Processing Record 40 of Set 8 | udachnyy
# Processing Record 41 of Set 8 | nome
# Processing Record 42 of Set 8 | balkhash
# Processing Record 43 of Set 8 | dibombari
# Processing Record 44 of Set 8 | makakilo city
# Processing Record 45 of Set 8 | haines junction
# Processing Record 46 of Set 8 | chumikan
# Processing Record 47 of Set 8 | lokosovo
# Processing Record 48 of Set 8 | wattegama
# Processing Record 49 of Set 8 | umm lajj
# Processing Record 50 of Set 8 | rio grande
# Processing Record 1 of Set 9 | dombarovskiy
# Processing Record 2 of Set 9 | toftir
# City not found. Skipping...
# Processing Record 3 of Set 9 | hofn
# Processing Record 4 of Set 9 | anori
# Processing Record 5 of Set 9 | popondetta
# Processing Record 6 of Set 9 | la orilla
# Processing Record 7 of Set 9 | seduva
# Processing Record 8 of Set 9 | ocos
# Processing Record 9 of Set 9 | harper
# Processing Record 10 of Set 9 | sao filipe
# Processing Record 11 of Set 9 | flin flon
# Processing Record 12 of Set 9 | ust-kuyga
# Processing Record 13 of Set 9 | wanning
# Processing Record 14 of Set 9 | saryg-sep
# Processing Record 15 of Set 9 | maningrida
# Processing Record 16 of Set 9 | bafq
# Processing Record 17 of Set 9 | baykit
# Processing Record 18 of Set 9 | perakhora
# City not found. Skipping...
# Processing Record 19 of Set 9 | contai
# Processing Record 20 of Set 9 | nylstroom
# City not found. Skipping...
# Processing Record 21 of Set 9 | alofi
# Processing Record 22 of Set 9 | zhireken
# Processing Record 23 of Set 9 | ugoofaaru
# Processing Record 24 of Set 9 | nueva gerona
# Processing Record 25 of Set 9 | jizan
# Processing Record 26 of Set 9 | parfenyevo
# Processing Record 27 of Set 9 | olinda
# Processing Record 28 of Set 9 | waupun
# Processing Record 29 of Set 9 | tomatlan
# Processing Record 30 of Set 9 | venado tuerto
# Processing Record 31 of Set 9 | sarahan
# Processing Record 32 of Set 9 | tautira
# Processing Record 33 of Set 9 | paraiso
# Processing Record 34 of Set 9 | berlevag
# Processing Record 35 of Set 9 | la ronge
# Processing Record 36 of Set 9 | luis correia
# Processing Record 37 of Set 9 | arbuzynka
# Processing Record 38 of Set 9 | swan hill
# Processing Record 39 of Set 9 | black river
# Processing Record 40 of Set 9 | taltal
# Processing Record 41 of Set 9 | ati
# Processing Record 42 of Set 9 | sao miguel
# Processing Record 43 of Set 9 | ruyigi
# Processing Record 44 of Set 9 | kenai
# Processing Record 45 of Set 9 | kattivakkam
# Processing Record 46 of Set 9 | vitim
# Processing Record 47 of Set 9 | pevek
# Processing Record 48 of Set 9 | atar
# Processing Record 49 of Set 9 | birnin kebbi
# Processing Record 50 of Set 9 | rio chiquito
# Processing Record 1 of Set 10 | mandalgovi
# Processing Record 2 of Set 10 | meulaboh
# Processing Record 3 of Set 10 | fort wellington
# Processing Record 4 of Set 10 | yerbogachen
# Processing Record 5 of Set 10 | cidreira
# Processing Record 6 of Set 10 | nancha
# Processing Record 7 of Set 10 | great yarmouth
# Processing Record 8 of Set 10 | kelvington
# Processing Record 9 of Set 10 | antalaha
# Processing Record 10 of Set 10 | saint-philippe
# Processing Record 11 of Set 10 | fort-shevchenko
# Processing Record 12 of Set 10 | tumbotino
# Processing Record 13 of Set 10 | neftcala
# Processing Record 14 of Set 10 | lebu
# Processing Record 15 of Set 10 | bantogon
# Processing Record 16 of Set 10 | lavrentiya
# Processing Record 17 of Set 10 | bay roberts
# Processing Record 18 of Set 10 | ayan
# Processing Record 19 of Set 10 | warqla
# City not found. Skipping...
# Processing Record 20 of Set 10 | chimbote
# Processing Record 21 of Set 10 | gadarwara
# Processing Record 22 of Set 10 | alekseyevka
# Processing Record 23 of Set 10 | abha
# Processing Record 24 of Set 10 | vao
# Processing Record 25 of Set 10 | byron bay
# Processing Record 26 of Set 10 | salinopolis
# Processing Record 27 of Set 10 | burnie
# Processing Record 28 of Set 10 | boueni
# Processing Record 29 of Set 10 | puerto carreno
# Processing Record 30 of Set 10 | ornskoldsvik
# Processing Record 31 of Set 10 | trincomalee
# Processing Record 32 of Set 10 | san rafael
# Processing Record 33 of Set 10 | beeville
# Processing Record 34 of Set 10 | marzuq
# Processing Record 35 of Set 10 | graaff-reinet
# Processing Record 36 of Set 10 | pingzhuang
# Processing Record 37 of Set 10 | sangar
# Processing Record 38 of Set 10 | champoton
# Processing Record 39 of Set 10 | cuiluan
# Processing Record 40 of Set 10 | ilheus
# Processing Record 41 of Set 10 | gravdal
# Processing Record 42 of Set 10 | hammerfest
# Processing Record 43 of Set 10 | lasa
# Processing Record 44 of Set 10 | lianzhou
# Processing Record 45 of Set 10 | oranjestad
# Processing Record 46 of Set 10 | kulhudhuffushi
# Processing Record 47 of Set 10 | cigand
# Processing Record 48 of Set 10 | rio gallegos
# Processing Record 49 of Set 10 | grand river south east
# City not found. Skipping...
# Processing Record 50 of Set 10 | lac du bonnet
# Processing Record 1 of Set 11 | lashio
# Processing Record 2 of Set 11 | yenagoa
# Processing Record 3 of Set 11 | quixada
# Processing Record 4 of Set 11 | severo-kurilsk
# Processing Record 5 of Set 11 | gryazovets
# Processing Record 6 of Set 11 | puerto suarez
# Processing Record 7 of Set 11 | tambul
# City not found. Skipping...
# Processing Record 8 of Set 11 | aitape
# Processing Record 9 of Set 11 | parrita
# Processing Record 10 of Set 11 | westport
# Processing Record 11 of Set 11 | fort nelson
# Processing Record 12 of Set 11 | salta
# Processing Record 13 of Set 11 | richards bay
# Processing Record 14 of Set 11 | carutapera
# Processing Record 15 of Set 11 | belyy yar
# Processing Record 16 of Set 11 | kharp
# Processing Record 17 of Set 11 | ipixuna
# Processing Record 18 of Set 11 | cabedelo
# Processing Record 19 of Set 11 | barentsburg
# City not found. Skipping...
# Processing Record 20 of Set 11 | chunskiy
# Processing Record 21 of Set 11 | quatre cocos
# Processing Record 22 of Set 11 | tigzirt
# Processing Record 23 of Set 11 | caucaia
# Processing Record 24 of Set 11 | beira
# Processing Record 25 of Set 11 | ucluelet
# Processing Record 26 of Set 11 | chiredzi
# Processing Record 27 of Set 11 | auki
# Processing Record 28 of Set 11 | san juan
# Processing Record 29 of Set 11 | balykshi
# Processing Record 30 of Set 11 | bud
# Processing Record 31 of Set 11 | yumen
# Processing Record 32 of Set 11 | anadyr
# Processing Record 33 of Set 11 | walvis bay
# Processing Record 34 of Set 11 | malartic
# Processing Record 35 of Set 11 | tura
# Processing Record 36 of Set 11 | colares
# Processing Record 37 of Set 11 | olafsvik
# Processing Record 38 of Set 11 | morant bay
# Processing Record 39 of Set 11 | bowen
# Processing Record 40 of Set 11 | viedma
# Processing Record 41 of Set 11 | hella
# Processing Record 42 of Set 11 | mainaguri
# Processing Record 43 of Set 11 | baghdad
# Processing Record 44 of Set 11 | bandarbeyla
# Processing Record 45 of Set 11 | prince rupert
# Processing Record 46 of Set 11 | kazalinsk
# City not found. Skipping...
# Processing Record 47 of Set 11 | yakima
# Processing Record 48 of Set 11 | sur
# Processing Record 49 of Set 11 | puerto leguizamo
# Processing Record 50 of Set 11 | bam
# Processing Record 1 of Set 12 | catuday
# Processing Record 2 of Set 12 | prachuap khiri khan
# Processing Record 3 of Set 12 | zhezkazgan
# Processing Record 4 of Set 12 | nizhneyansk
# City not found. Skipping...
# Processing Record 5 of Set 12 | mount gambier
# Processing Record 6 of Set 12 | amga
# Processing Record 7 of Set 12 | ulaanbaatar
# Processing Record 8 of Set 12 | arrifes
# Processing Record 9 of Set 12 | utiroa
# City not found. Skipping...
# Processing Record 10 of Set 12 | araouane
# Processing Record 11 of Set 12 | dzhebariki-khaya
# Processing Record 12 of Set 12 | male
# Processing Record 13 of Set 12 | kawana waters
# City not found. Skipping...
# Processing Record 14 of Set 12 | verkhoyansk
# Processing Record 15 of Set 12 | kangaatsiaq
# Processing Record 16 of Set 12 | remanso
# Processing Record 17 of Set 12 | cheney
# Processing Record 18 of Set 12 | broome
# Processing Record 19 of Set 12 | artyk
# City not found. Skipping...
# Processing Record 20 of Set 12 | kadykchan
# City not found. Skipping...
# Processing Record 21 of Set 12 | akhtubinsk
# Processing Record 22 of Set 12 | jiblah
# Processing Record 23 of Set 12 | gorontalo
# Processing Record 24 of Set 12 | ginda
# Processing Record 25 of Set 12 | hare bay
# Processing Record 26 of Set 12 | goderich
# Processing Record 27 of Set 12 | chapais
# Processing Record 28 of Set 12 | awbari
# Processing Record 29 of Set 12 | longlac
# City not found. Skipping...
# Processing Record 30 of Set 12 | belluru
# Processing Record 31 of Set 12 | mountain home
# Processing Record 32 of Set 12 | prado
# Processing Record 33 of Set 12 | macusani
# Processing Record 34 of Set 12 | ayr
# Processing Record 35 of Set 12 | bundaberg
# Processing Record 36 of Set 12 | cross lanes
# Processing Record 37 of Set 12 | liwonde
# Processing Record 38 of Set 12 | payo
# Processing Record 39 of Set 12 | kargopol
# Processing Record 40 of Set 12 | vestmanna
# Processing Record 41 of Set 12 | barentu
# Processing Record 42 of Set 12 | pangoa
# Processing Record 43 of Set 12 | santa rosa
# Processing Record 44 of Set 12 | hanmer springs
# Processing Record 45 of Set 12 | mangan
# Processing Record 46 of Set 12 | castanos
# Processing Record 47 of Set 12 | tavira
# Processing Record 48 of Set 12 | pangnirtung
# Processing Record 49 of Set 12 | tanete
# Processing Record 50 of Set 12 | otradnoye
# Processing Record 1 of Set 13 | porto walter
# Processing Record 2 of Set 13 | guerrero negro
# Processing Record 3 of Set 13 | kiunga
# Processing Record 4 of Set 13 | canete
# Processing Record 5 of Set 13 | nantucket
# Processing Record 6 of Set 13 | korla
# Processing Record 7 of Set 13 | alta floresta
# Processing Record 8 of Set 13 | port augusta
# Processing Record 9 of Set 13 | shitkino
# Processing Record 10 of Set 13 | tezu
# Processing Record 11 of Set 13 | chegdomyn
# Processing Record 12 of Set 13 | rongcheng
# Processing Record 13 of Set 13 | neuquen
# Processing Record 14 of Set 13 | porto novo
# Processing Record 15 of Set 13 | namibe
# Processing Record 16 of Set 13 | pascagoula
# Processing Record 17 of Set 13 | bonavista
# Processing Record 18 of Set 13 | sawtell
# Processing Record 19 of Set 13 | storsteinnes
# Processing Record 20 of Set 13 | uberaba
# Processing Record 21 of Set 13 | skhisma
# Processing Record 22 of Set 13 | tiarei
# Processing Record 23 of Set 13 | qinzhou
# Processing Record 24 of Set 13 | tumannyy
# City not found. Skipping...
# Processing Record 25 of Set 13 | uige
# Processing Record 26 of Set 13 | palagiano
# Processing Record 27 of Set 13 | henties bay
# Processing Record 28 of Set 13 | leningradskiy
# Processing Record 29 of Set 13 | saint-georges
# Processing Record 30 of Set 13 | acajutla
# Processing Record 31 of Set 13 | sao gabriel da cachoeira
# Processing Record 32 of Set 13 | itarema
# Processing Record 33 of Set 13 | rafaela
# Processing Record 34 of Set 13 | tecoanapa
# Processing Record 35 of Set 13 | mendi
# Processing Record 36 of Set 13 | gornopravdinsk
# Processing Record 37 of Set 13 | niono
# Processing Record 38 of Set 13 | cap malheureux
# Processing Record 39 of Set 13 | hauterive
# Processing Record 40 of Set 13 | la romana
# Processing Record 41 of Set 13 | tulum
# Processing Record 42 of Set 13 | ambanja
# Processing Record 43 of Set 13 | rocha
# Processing Record 44 of Set 13 | egvekinot
# Processing Record 45 of Set 13 | buraydah
# Processing Record 46 of Set 13 | ha tinh
# Processing Record 47 of Set 13 | kokopo
# Processing Record 48 of Set 13 | miranda de ebro
# Processing Record 49 of Set 13 | katha
# City not found. Skipping...
# Processing Record 50 of Set 13 | imeni poliny osipenko
# Processing Record 1 of Set 14 | vodnyy
# Processing Record 2 of Set 14 | bellevue
# Processing Record 3 of Set 14 | san quintin
# Processing Record 4 of Set 14 | khandagayty
# Processing Record 5 of Set 14 | saldanha
# Processing Record 6 of Set 14 | coquimbo
# Processing Record 7 of Set 14 | kyabe
# Processing Record 8 of Set 14 | rawah
# Processing Record 9 of Set 14 | harur
# Processing Record 10 of Set 14 | shelopugino
# Processing Record 11 of Set 14 | mutare
# Processing Record 12 of Set 14 | celestun
# Processing Record 13 of Set 14 | port hardy
# Processing Record 14 of Set 14 | doume
# Processing Record 15 of Set 14 | ngunguru
# Processing Record 16 of Set 14 | nirmali
# Processing Record 17 of Set 14 | ames
# Processing Record 18 of Set 14 | skelleftea
# Processing Record 19 of Set 14 | nabire
# Processing Record 20 of Set 14 | louisbourg
# City not found. Skipping...
# Processing Record 21 of Set 14 | havre-saint-pierre
# Processing Record 22 of Set 14 | sabang
# Processing Record 23 of Set 14 | sonepur
# Processing Record 24 of Set 14 | labytnangi
# Processing Record 25 of Set 14 | beringovskiy
# Processing Record 26 of Set 14 | dwarka
# Processing Record 27 of Set 14 | sobolevo
# Processing Record 28 of Set 14 | te anau
# Processing Record 29 of Set 14 | turukhansk
# Processing Record 30 of Set 14 | portland
# Processing Record 31 of Set 14 | taonan
# Processing Record 32 of Set 14 | roma
# Processing Record 33 of Set 14 | sabzevar
# Processing Record 34 of Set 14 | idlib
# Processing Record 35 of Set 14 | mbaiki
# Processing Record 36 of Set 14 | matinhos
# Processing Record 37 of Set 14 | pimentel
# Processing Record 38 of Set 14 | vitoria
# Processing Record 39 of Set 14 | ascension
# Processing Record 40 of Set 14 | hobbs
# Processing Record 41 of Set 14 | sampit
# Processing Record 42 of Set 14 | valparaiso
# Processing Record 43 of Set 14 | noumea
# Processing Record 44 of Set 14 | toora-khem
# Processing Record 45 of Set 14 | biritiba-mirim
# Processing Record 46 of Set 14 | mahadday weyne
# City not found. Skipping...
# Processing Record 47 of Set 14 | marienburg
# Processing Record 48 of Set 14 | churapcha
# Processing Record 49 of Set 14 | kuytun
# Processing Record 50 of Set 14 | temaraia
# City not found. Skipping...
# Processing Record 1 of Set 15 | pitimbu
# Processing Record 2 of Set 15 | muhos
# Processing Record 3 of Set 15 | lishan
# Processing Record 4 of Set 15 | praia da vitoria
# Processing Record 5 of Set 15 | abapo
# Processing Record 6 of Set 15 | nedjo
# Processing Record 7 of Set 15 | ballina
# Processing Record 8 of Set 15 | buzmeyin
# Processing Record 9 of Set 15 | annau
# Processing Record 10 of Set 15 | bloomsburg
# Processing Record 11 of Set 15 | labuan
# Processing Record 12 of Set 15 | rorvik
# Processing Record 13 of Set 15 | fort saint john
# City not found. Skipping...
# Processing Record 14 of Set 15 | providencia
# Processing Record 15 of Set 15 | imbituba
# Processing Record 16 of Set 15 | kissamos
# Processing Record 17 of Set 15 | todos santos
# Processing Record 18 of Set 15 | beruwala
# Processing Record 19 of Set 15 | ambulu
# Processing Record 20 of Set 15 | dunedin
# Processing Record 21 of Set 15 | barra do garcas
# Processing Record 22 of Set 15 | cayenne
# Processing Record 23 of Set 15 | itamaraca
# Processing Record 24 of Set 15 | ingham
# Processing Record 25 of Set 15 | campbellsville
# Processing Record 26 of Set 15 | kuah
# Processing Record 27 of Set 15 | makat
# Processing Record 28 of Set 15 | klaksvik
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Ushuaia -54.8000  -68.3000     40.91        97         100
# 1       Jamestown  42.0970  -79.2353     30.52        76         100
# 2         Rikitea -23.1203 -134.9692     78.06        68           7
# 3  Cabo San Lucas  22.8909 -109.9124     75.51        28          97
# 4          Avarua -21.2078 -159.7750     75.25        94          90
# 5      Camabatela  -8.1881   15.3750     77.88        61          60
# 6          Padang  -0.9492  100.3543     86.05        81          80
# 7          Albany  42.6001  -73.9662     34.39        71          27
# 8      Bredasdorp -34.5322   20.0403     69.12        45           4
# 9         Aklavik  68.2191 -135.0107     -1.23        83          32
#
#    Wind Speed Country                 Date Current Description
# 0       10.76      AR  2022-04-17 10:00:55     overcast clouds
# 1       13.80      US  2022-04-17 10:05:33          light snow
# 2       12.57      PF  2022-04-17 10:05:33           clear sky
# 3       12.57      MX  2022-04-17 10:04:32     overcast clouds
# 4        4.61      CK  2022-04-17 10:05:35     overcast clouds
# 5        4.23      AO  2022-04-17 10:05:35       broken clouds
# 6        2.53      ID  2022-04-17 10:05:35       broken clouds
# 7        5.99      US  2022-04-17 10:05:36    scattered clouds
# 8       10.20      ZA  2022-04-17 10:05:36           clear sky
# 9       12.44      CA  2022-04-17 10:05:36    scattered clouds

# %%
new_column_order = ["City", "Country", "Date", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]

# %%
city_data_df = city_data_df[new_column_order]
city_data_df.head()
# Out:
#              City Country                 Date      Lat       Lng  Max Temp  \
# 0         Ushuaia      AR  2022-04-17 10:00:55 -54.8000  -68.3000     40.91
# 1       Jamestown      US  2022-04-17 10:05:33  42.0970  -79.2353     30.52
# 2         Rikitea      PF  2022-04-17 10:05:33 -23.1203 -134.9692     78.06
# 3  Cabo San Lucas      MX  2022-04-17 10:04:32  22.8909 -109.9124     75.51
# 4          Avarua      CK  2022-04-17 10:05:35 -21.2078 -159.7750     75.25
#
#    Humidity  Cloudiness  Wind Speed Current Description
# 0        97         100       10.76     overcast clouds
# 1        76         100       13.80          light snow
# 2        68           7       12.57           clear sky
# 3        28          97       12.57     overcast clouds
# 4        94          90        4.61     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
